# %% [markdown]
# # Description

# %% [markdown]
# ## Business Problem

# %% [markdown]
# This project was created to solve a real business problem. The company had a table of customers whose addresses were in string field where the users could write the whole addresses themselves. After some changes in business needs, the company had to split this field into proper columns: suburb, postcode, state, street name, street number, etc.
#
# Since the company had more than 10k customers in the table, the script was created to help with this task. Also, the system used by the company would continue to be the same, that is, just one big string field for the address, so the script would still have to be used to continue to split the addresses into the columns.
#
# To be able to complete the task, the fields had to be split, there was a separate address table to store the addresses and generate an ID that would also be used. To store the addresses in this table, I had to use other dimension tables to get the ID of the suburb and postcode.
#
# The expected address format in the string was:
#
# ```
#                 {Address1}
#                 {Address2}
# {StreetNumber} {StreetName} {StreetType}
#        {Suburb} {State} {Postcode}
# ```
#
# One example of this would be:
#
# ```
# {P/L & GS Engineering & Constructions Australia P/L & Webuild SPA}        ---> Address1
#                     {T/As Spark NEL DC JV}                                ---> Address2
#             {Level 1, 436-438} {Johnston} {Street}                        ---> StreetNo, Name and Type
#                     {Abbotsford} {VIC} {3067}                             ---> Suburb, State, Postcode
# ```
# We also had the PO Boxes and Privete Bags addresses:
#
# ```
#   PO Box 1182
# Rosebery NSW 1445
# ```
#
# The only difference is that the whole first line of PO Boxes was intended to be in a specific column.
#
# If the address was not in this format, the script would not work for it, and it should be updated.
#
# The sript was able to update more than 90% of the cases.

# %% [markdown]
# ## Problems found while developing the project

# %% [markdown]
# ### Problems that could be fixed creating functions

# %% [markdown]
# As the field was a big whole field, where the users could write the addresses as a whole, it was very easy to make mistakes and typos.
#
# Here are some examples of challenging existing cases:
#
# - Name of the suburb right but with the wrong postcode:
#
# ```
#    PO Box 6499
# Shepparton VIC 3631  ---> correct postcode would be 3630
# ```
#
# - Name of the suburb wrong but with the correct postcode:
#
# ```
#    PO Box 6499
# Sheppaton VIC 3630  ---> correct suburb would be Shepparton
# ```
#
# This problem happened because to split the fields, I needed to find the ID of the suburb and postcode in a table, so if they did not match, I had a problem.
#
# - Order of the suburb name is different:
#
# ```
#         PO Box W223
# WESTFIELD PARRAMATTA NSW 2150   ---> it should be PARRAMATTA WESTFIELD
# ```
#
# - Number of words of the suburb did not match the number of words the system had for that suburb and postcode:
#
# ```
#     28 Peachtree Road
# WESTFIELD PENRITH NSW 2750     ---> it should be PENRITH
# ```
#
# To fix these problems, 3 functions were created:
#
# 1. find_matching_suburb:
#
# If there was no exact match with postcode and suburb in the system's list, the code uses this function to try to find a suburb with a similar name. It uses the fuzzywuzzy library, which allows me to find a percentage of match between 2 words. I set that the words had to have at least 80% of a match for the suburb to be chosen.
#
# For this one, the number of words in the suburb had to be the same. For example, WESTFIELD PENRITH would not match with PENRITH.
#
# 2. find_matching_suburb_split
#
# If the first function did not work, the code tries to find the same percentage of match, but now taking into account that the suburb could have more or less words than what was written by the user. So it tries to find the best match for postcode and suburb.
#
# 3. find_matching_suburb_split_state
#
# The last step if the first 2 ones do not work is to also use the state to try to find the best match. Now the code uses both suburb and state to try to find the best match.
#
# If none of these work, the code generates an error and adds the customer to the skip list, and moves on to the next one.

# %% [markdown]
# ### Problems that caused the script to skip the address

# %% [markdown]
# Here are some examples of problems that the code could not fix, so when they happened, the code generates an error, add the error and the customer id to the error dataset.
#
# - No postcodes
#
# ```
# Level 18 Darling Park
# 2/201 Sussex Street
#  Sydney NSW
# ```
#
# - Structure of the address incorrect:
# ```
# Level 20
# 1 Market Street
# Sydney NSW 2000 Australia
# ```
#
# - No state found
#
# ```
# 17 Wilga Road
# Caringbah South 2229
# ```
#
# - No street number
#
# ```
# Robertson Street
# Kurrajong NSW 2754
# ```
#
# - No street name
#
# ```
# Bldg 505, Room 281
# Darlington  NSW  2006
# ```
#
# These are just some cases, we had much more, but it's enough to ilustrate the problems.

# %% [markdown]
# # Importing the libraries

# %%
import pandas as pd
import pyodbc
import re
from fuzzywuzzy import fuzz
from datetime import datetime
import os
import time
import xlsxwriter
import requests

# %% [markdown]
# # Creating the functions

# %%
# Defining the function the will be used to find the the index of the last number of the string

# The street name starts after the last number

def find_last_number_index(input_string):
    # Find all numbers and single letters right after numbers in the string
    matches = re.finditer(r'(\d+[A-Za-z]?)(?![A-Za-z])', input_string)
    
    # If there are no matches, return -1
    if not matches:
        return -1

    # Find the last match
    last_match = None
    for match in matches:
        last_match = match
    
    if last_match:
        last_value = last_match.group()
        last_value_index = input_string.rfind(last_value)
        return last_value_index + len(last_value) - 1
    else:
        return -1

# %%
# Function to find a suburb match based on fuzzy matching
def find_matching_suburb(suburb, postcode, suburbs):
    best_match = None
    best_match_score = 0
    
    # Tokenize and sort the words in the input suburb
    input_suburb_words = sorted(suburb.split())

    for index, row in suburbs.iterrows():
        current_suburb = row['SuburbName']
        current_postcode = row['Postcode']
        
        # Tokenize and sort the words in the current suburb
        current_suburb_words = sorted(current_suburb.upper().split())

        suburb_match_score = fuzz.partial_ratio(input_suburb_words, current_suburb_words)
        
        # You can adjust this threshold as needed to consider a match
        if suburb_match_score > best_match_score and suburb_match_score >= 80 and postcode == current_postcode and len(current_suburb.split()) == len(suburb.split()):
            best_match = current_suburb
            best_match_score = suburb_match_score

    return best_match

# %%
# Function to find a suburb match based on fuzzy matching
def find_matching_suburb_split(suburb, postcode, suburbs):
    best_match = None
    best_match_score = 0

    for index, row in suburbs.iterrows():
        current_suburb = row['SuburbName']
        current_postcode = row['Postcode']

        suburb_match_score = fuzz.partial_ratio(suburb, current_suburb.upper())
        
        # You can adjust this threshold as needed to consider a match
        if suburb_match_score > best_match_score and suburb_match_score >= 80 and postcode == current_postcode:
            best_match = current_suburb
            best_match_score = suburb_match_score

    return best_match

# %%
# Function to find a suburb match based on fuzzy matching
def find_matching_suburb_split_state(suburb, state, postcode, suburbs):
    best_match = None
    best_post_code = None
    best_match_score = 0
    best_postcode_diff = float('inf')  # Initialize with positive infinity

    for index, row in suburbs.iterrows():
        current_suburb = row['SuburbName']
        current_state = row['StateName']
        current_postcode = row['Postcode']

        # Calculate the similarity score between the input suburb and the current suburb
        suburb_match_score = fuzz.partial_ratio(suburb, current_suburb.upper())
                
        # You can adjust this threshold as needed to consider a match
        if (
            suburb_match_score >= best_match_score
            and suburb_match_score >= 80
            and current_state == state
        ):
            # Calculate the absolute difference between the current postcode and the target postcode
            postcode_diff = abs(int(current_postcode) - int(postcode))
            
            # Check if the current suburb has a postcode closer to the target postcode
            if postcode_diff < best_postcode_diff:
                best_match = current_suburb
                best_match_score = suburb_match_score
                best_postcode_diff = postcode_diff
                best_post_code = current_postcode

    return best_match, best_post_code

# %% [markdown]
# # Creating the objects that will be used in the code

# %% [markdown]
# ## Connection settings

# %%
server = 'sampleserver'
database = 'sample_database'
username = 'sampleUser'
password = 'SamplePassword'

# %% [markdown]
# ## Columns for the datasets

# %%
columns = ['Customer_Code', 'ID', 'Billing_ADR_Address_ID', 'Billing_Address', 'Billing_StreetNo', 'Billing_StreetName', 'Billing_StreetType',
           'Billing_Suburb', 'Billing_State', 'Billing_Postcode', 'Billing_Customisable_Value', 'Billing_Address2', 
           
           'Delivery_ADR_Address_ID', 'Delivery_Address', 'Delivery_StreetNo','Delivery_StreetName', 'Delivery_StreetType', 'Delivery_Suburb',
           'Delivery_State', 'Delivery_Postcode','Delivery_Customisable_Value' ,'Delivery_Address2']

columns
# Out:
# ['Customer_Code',
#  'ID',
#  'Billing_ADR_Address_ID',
#  'Billing_Address',
#  'Billing_StreetNo',
#  'Billing_StreetName',
#  'Billing_StreetType',
#  'Billing_Suburb',
#  'Billing_State',
#  'Billing_Postcode',
#  'Billing_Customisable_Value',
#  'Billing_Address2',
#  'Delivery_ADR_Address_ID',
#  'Delivery_Address',
#  'Delivery_StreetNo',
#  'Delivery_StreetName',
#  'Delivery_StreetType',
#  'Delivery_Suburb',
#  'Delivery_State',
#  'Delivery_Postcode',
#  'Delivery_Customisable_Value',
#  'Delivery_Address2']

# %% [markdown]
# ## Error Report Dataset

# %%
billing_error_columns = ['Customer_Code', 'ID', 'Billing_Address', 'Billing Error Type']

delivey_error_columns = ['Customer_Code', 'ID', 'Delivery_Address', 'Delivery Error Type']

Billing_Error_Report = pd.DataFrame(columns=billing_error_columns)

Delivery_Error_Report = pd.DataFrame(columns=delivey_error_columns)

Billing_Error_Report
# Out:
# Empty DataFrame
# Columns: [Customer_Code, ID, Billing_Address, Billing Error Type]
# Index: []

# %% [markdown]
# ## Start time and Last Modified Date in the TBL_DBT_Address_Updates_Log table

# %%
start_date = datetime.now()

# %% [markdown]
# To assist with the code, a table was created that would insert the information about the script runs. Every time the script runs, at the end, it inserts into a table information such as start datetime, end datetime, last modified datetime, number of rows affected, etc.
#
# This part would make a connection with SQL Server to get the information about the last time the customer table was modified when the script ran for the last time. So it would make a query to the customer table with the modifications after that time.
#
# I changed the connection to a file connection for studies proposes.

# %%
# Establish the connection with Windows authentication

#conn = pyodbc.connect(
#    f'DRIVER=ODBC Driver 17 for SQL Server;SERVER={server};DATABASE={database};UID={username};PWD={password};'
#)

# Create a cursor object to interact with the database
#cursor = conn.cursor()

select_last_date = """
SELECT MAX([Last_Modified_Date]) AS [Last_Modified_Date]
  FROM [sample_database].[dbo].[TBL_DBT_Address_Updates_Log]
"""

select_last_date = pd.read_excel("TBL_DBT_Address_Updates_Log.xlsx")

# Convert 'Last_Modified_Date' column to datetime format
select_last_date['Last_Modified_Date'] = pd.to_datetime(select_last_date['Last_Modified_Date'])

# Get the maximum date
select_last_date = select_last_date['Last_Modified_Date'].max()

#cursor.execute(select_last_date)
#last_finish_date = cursor.fetchone()[0]

#cursor.close()
#conn.close()

last_finish_date = select_last_date

last_finish_date = last_finish_date.strftime('%Y-%m-%d %H:%M:%S.%f')[:-3]

last_finish_date
# Out:
# '2025-01-22 16:30:32.123'

# %% [markdown]
# ## Last Modified Date

# %% [markdown]
# This part basically gets the last modified date from the audit table, which will be used to make some comparisons at the end.

# %%
# Establish the connection with Windows authentication
conn = pyodbc.connect(
    f'DRIVER=ODBC Driver 17 for SQL Server;SERVER={server};DATABASE={database};UID={username};PWD={password};'
)

# Create a cursor object to interact with the database
cursor = conn.cursor()


select_modified_dates = f"""
SELECT MAX([Audit_DateTime]) AS Max_Audit_DateTime
FROM [sample_database].[dbo].[VA_DBT_Master]
WHERE [Audited_Field] IN ('Billing_Address', 'Delivery_Address') 
AND Operation IN ('U', 'I') 
AND Audit_DateTime > '{last_finish_date}'
AND Audit_User NOT LIKE 'TableauAdminAccess'

"""

cursor.execute(select_modified_dates)
last_modified_date = cursor.fetchone()[0]

cursor.close()
conn.close()

if last_modified_date is None:
    last_modified_date = last_finish_date
else:
    last_modified_date = last_modified_date.strftime('%Y-%m-%d %H:%M:%S.%f')[:-3]

last_modified_date
# Out:
# '2025-01-24 15:13:29.240'

# %% [markdown]
# # Separating the addresses
#
# ## Billing Address

# %% [markdown]
# ### First Group: the standard data

# %% [markdown]
# This part would make a connection with the database to get the Billing Address of the customers. Some parts were replaced for studies purposes.
#
# The original data was modified to preserve sensitive information.

# %%
# Establish the connection with Windows authentication
#conn = pyodbc.connect(
#    f'DRIVER=ODBC Driver 17 for SQL Server;SERVER={server};DATABASE={database};UID={username};PWD={password};'
#)

# Create a cursor object to interact with the database
#cursor = conn.cursor()


select_billing_first = f"""

WITH UpdateSelection AS (

SELECT DISTINCT [Source_Id],[Audit_DateTime]
FROM [sample_database].[dbo].[VA_DBT_Master]
WHERE [Audited_Field] IN ('Billing_Address') 
AND Operation IN ('U', 'I') 
AND Audit_DateTime > '{last_finish_date}'
AND Audit_User NOT LIKE 'TableauAdminAccess'

AND [After_Value] IS NOT NULL AND [After_Value] NOT LIKE 'TBA%' AND NOT

([After_Value]  LIKE '%Locked Bag%' OR [After_Value] LIKE '%PO BOX%' OR [After_Value] LIKE '%P.O. BOX%' OR [After_Value] LIKE '%P.O BOX%'
 OR [After_Value] LIKE '%P O Box%' OR [After_Value] LIKE '%Private Bag%')

)

SELECT     
    [Customer_Code],
    [ID],
    REPLACE([Billing_Address],CHAR(13)+CHAR(10),'_') AS [Billing_Address]
FROM [sample_database].[dbo].[DBT_Master]

WHERE 

[Billing_Address] IS NOT NULL AND [Billing_Address] NOT LIKE 'TBA%' AND NOT

([Billing_Address]  LIKE '%Locked Bag%' OR [Billing_Address] LIKE '%PO BOX%' OR [Billing_Address] LIKE '%P.O. BOX%' OR [Billing_Address] LIKE '%P.O BOX%'
 OR [Billing_Address] LIKE '%P O Box%' OR [Billing_Address] LIKE '%Private Bag%')

AND [ID] IN (SELECT DISTINCT [Source_Id]
            FROM UpdateSelection)
            
        """


#df = pd.read_sql_query(select_billing_first, conn)

#cursor.close()
#conn.close()

df = pd.read_excel("Billing Address.xlsx")

df
# Out:
#               Customer_Code     ID  \
# 0    9NBRZAGLJDHKHFBUILDING  11551
# 1                   9UNFBFE  11505
# 2          9JZYZDTADNEKEACJ  11493
# 3       9LVRNBVZENGPROJECTS  11480
# 4       9ENWOUWMENGINEERING  11479
# ..                      ...    ...
# 136                CLQRGPUI    370
# 137       RUXHWWENGINEERING  10645
# 138          GYUFABBUILDING   4633
# 139     LTITRKTRZFQSERVICES   1175
# 140          KBCQXASERVICES    703
#
#                                        Billing_Address
# 0    Suite 4, Level 1, 374 Church Street _Parramatt...
# 1    Suite 802, Level 8, 24 Montgomery Street _Koga...
# 2                     Saltspray Close_Redhead NSW 2290
# 3                   50 Fitzroy Street_Carrington, 2294
# 4    Level 18 Darling Park_2/201 Sussex Street_ Syd...
# ..                                                 ...
# 136  48 Toh Guan Road East_#04-118, Enterprise Hub_...
# 137  National Parks and Wildlife Service_Locked Bag...
# 138  (T/As Lendlease Bouygues Joint Venture) _T/As ...
# 139              Locked Bag 18_Port Melbourne VIC 3207
# 140  Attn:United Group Infrastructure & Manidis Rob...
#
# [141 rows x 3 columns]

# %%
billing_first_group = pd.DataFrame(columns=columns)

billing_first_group['Customer_Code'] = df['Customer_Code']
billing_first_group['ID'] = df['ID']
billing_first_group['Billing_Address'] = df['Billing_Address']

billing_first_group
# Out:
#               Customer_Code     ID Billing_ADR_Address_ID  \
# 0    9NBRZAGLJDHKHFBUILDING  11551                    NaN
# 1                   9UNFBFE  11505                    NaN
# 2          9JZYZDTADNEKEACJ  11493                    NaN
# 3       9LVRNBVZENGPROJECTS  11480                    NaN
# 4       9ENWOUWMENGINEERING  11479                    NaN
# ..                      ...    ...                    ...
# 136                CLQRGPUI    370                    NaN
# 137       RUXHWWENGINEERING  10645                    NaN
# 138          GYUFABBUILDING   4633                    NaN
# 139     LTITRKTRZFQSERVICES   1175                    NaN
# 140          KBCQXASERVICES    703                    NaN
#
#                                        Billing_Address Billing_StreetNo  \
# 0    Suite 4, Level 1, 374 Church Street _Parramatt...              NaN
# 1    Suite 802, Level 8, 24 Montgomery Street _Koga...              NaN
# 2                     Saltspray Close_Redhead NSW 2290              NaN
# 3                   50 Fitzroy Street_Carrington, 2294              NaN
# 4    Level 18 Darling Park_2/201 Sussex Street_ Syd...              NaN
# ..                                                 ...              ...
# 136  48 Toh Guan Road East_#04-118, Enterprise Hub_...              NaN
# 137  National Parks and Wildlife Service_Locked Bag...              NaN
# 138  (T/As Lendlease Bouygues Joint Venture) _T/As ...              NaN
# 139              Locked Bag 18_Port Melbourne VIC 3207              NaN
# 140  Attn:United Group Infrastructure & Manidis Rob...              NaN
#
#     Billing_StreetName Billing_StreetType Billing_Suburb Billing_State  \
# 0                  NaN                NaN            NaN           NaN
# 1                  NaN                NaN            NaN           NaN
# 2                  NaN                NaN            NaN           NaN
# 3                  NaN                NaN            NaN           NaN
# 4                  NaN                NaN            NaN           NaN
# ..                 ...                ...            ...           ...
# 136                NaN                NaN            NaN           NaN
# 137                NaN                NaN            NaN           NaN
# 138                NaN                NaN            NaN           NaN
# 139                NaN                NaN            NaN           NaN
# 140                NaN                NaN            NaN           NaN
#
#     Billing_Postcode  ... Delivery_ADR_Address_ID Delivery_Address  \
# 0                NaN  ...                     NaN              NaN
# 1                NaN  ...                     NaN              NaN
# 2                NaN  ...                     NaN              NaN
# 3                NaN  ...                     NaN              NaN
# 4                NaN  ...                     NaN              NaN
# ..               ...  ...                     ...              ...
# 136              NaN  ...                     NaN              NaN
# 137              NaN  ...                     NaN              NaN
# 138              NaN  ...                     NaN              NaN
# 139              NaN  ...                     NaN              NaN
# 140              NaN  ...                     NaN              NaN
#
#     Delivery_StreetNo Delivery_StreetName Delivery_StreetType Delivery_Suburb  \
# 0                 NaN                 NaN                 NaN             NaN
# 1                 NaN                 NaN                 NaN             NaN
# 2                 NaN                 NaN                 NaN             NaN
# 3                 NaN                 NaN                 NaN             NaN
# 4                 NaN                 NaN                 NaN             NaN
# ..                ...                 ...                 ...             ...
# 136               NaN                 NaN                 NaN             NaN
# 137               NaN                 NaN                 NaN             NaN
# 138               NaN                 NaN                 NaN             NaN
# 139               NaN                 NaN                 NaN             NaN
# 140               NaN                 NaN                 NaN             NaN
#
#     Delivery_State Delivery_Postcode Delivery_Customisable_Value  \
# 0              NaN               NaN                         NaN
# 1              NaN               NaN                         NaN
# 2              NaN               NaN                         NaN
# 3              NaN               NaN                         NaN
# 4              NaN               NaN                         NaN
# ..             ...               ...                         ...
# 136            NaN               NaN                         NaN
# 137            NaN               NaN                         NaN
# 138            NaN               NaN                         NaN
# 139            NaN               NaN                         NaN
# 140            NaN               NaN                         NaN
#
#     Delivery_Address2
# 0                 NaN
# 1                 NaN
# 2                 NaN
# 3                 NaN
# 4                 NaN
# ..                ...
# 136               NaN
# 137               NaN
# 138               NaN
# 139               NaN
# 140               NaN
#
# [141 rows x 22 columns]

# %% [markdown]
# #### Post Code, State and Suburb

# %%
# testing if there's any row not in the pattern

Billing_IDs_To_Exclude = []

error_reason = ''

states = ['NSW', 'VIC', 'QLD', 'SA', 'WA', 'TAS', 'ACT', 'NT']

for index, row in df.iterrows():
    
    customer_ID = row['ID']
    
    parts = row['Billing_Address'].strip('_').strip('.').split('_') # spliting the string by _ that represents a line break
    
    
    #tests if the lenght of the Billing address is less than 2 lines, if yes, the address is not complete and it skips the rest of the code
    
    if len(parts) < 2:
        Billing_IDs_To_Exclude.append(customer_ID)
        error_reason += 'Address is not complete. It should have at least 2 lines!\n'
        
        new_line = pd.DataFrame.from_records([{'Customer_Code': row['Customer_Code'],
                                                    'ID': customer_ID,
                                                    'Billing_Address': row['Billing_Address'].replace("_", "\n"),
                                                    'Billing Error Type': error_reason
                        }])
        
        Billing_Error_Report = pd.concat([Billing_Error_Report, new_line],ignore_index=True)
        
        error_reason = ''
        
        continue
        
    # if no, it tests if the last line, which should be the suburb details, have at least 3 elements, if yes, it gets the state and the code continues
    # case it's less than 3 elements, it skips the rest of the code 
    
    else:

        suburb_details = parts[-1].split() # the last part is usually where the Suburb, post code and state are
        
        if len(suburb_details) > 2:
            state = suburb_details[-2].upper().strip(',').strip('`').strip('.')
        else:
            # Handle the case when the length is less than 3
            state = ''
            error_reason += 'Wrong Format. Please make sure the format looks like:\n{Address1}\n{Address2}\n{StreetNumber} {StreetName} {StreetType}\n{Suburb} {State} {Postcode}\n'
            Billing_IDs_To_Exclude.append(customer_ID)
            
            new_line = pd.DataFrame.from_records([{'Customer_Code': row['Customer_Code'],
                                                    'ID': customer_ID,
                                                    'Billing_Address': row['Billing_Address'].replace("_", "\n"),
                                                    'Billing Error Type': error_reason
                        }])
            
            Billing_Error_Report = pd.concat([Billing_Error_Report, new_line],ignore_index=True)
        
            error_reason = ''
        
            continue
            
           #----------------------------------------------------------------------------------------------------------------------------------------------------------# 
            

        post_code = suburb_details[-1].strip(',').strip('`').strip().strip('.') # the post code is normally the last word in the last line

        suburb = ' '.join(suburb_details[:-2]).upper().strip(',').strip('.') # suburb is the rest, it can be 2 or more words, so we join them with a space

        # Check if the post_code looks like 4 numbers
        is_post_code_valid = re.match(r'^\d{4}$', post_code) is not None

        # Check if the state looks like 3 or 2 letters
        is_state_valid = re.match(r'^[A-Za-z]{2,3}$', state) is not None
            
        
        if is_post_code_valid == False:
            
            if isinstance(post_code, int):
                error_reason += 'Postcode invalid. It should be 4 numbers.\n'
                Billing_IDs_To_Exclude.append(customer_ID)
                
                
            if not any(re.match(r'^\d{4}$', str(item)) is not None for item in suburb_details):
                error_reason += 'Postcode Missing.\n'
                Billing_IDs_To_Exclude.append(customer_ID)
                
                if not any(state in suburb_details for state in states):
                    error_reason += 'State Missing.\n'
                    
                    
                new_line = pd.DataFrame.from_records([{'Customer_Code': row['Customer_Code'],
                                                        'ID': customer_ID,
                                                        'Billing_Address': row['Billing_Address'].replace("_", "\n"),
                                                        'Billing Error Type': error_reason
                            }])

                Billing_Error_Report = pd.concat([Billing_Error_Report, new_line],ignore_index=True)

                error_reason = ''
                
                continue

                
            else:
                
                if not any(state in suburb_details for state in states):
                    error_reason += 'State Missing.\n'
                    Billing_IDs_To_Exclude.append(customer_ID)
                    
                    new_line = pd.DataFrame.from_records([{'Customer_Code': row['Customer_Code'],
                                                    'ID': customer_ID,
                                                    'Billing_Address': row['Billing_Address'].replace("_", "\n"),
                                                    'Billing Error Type': error_reason
                        }])
            
                    Billing_Error_Report = pd.concat([Billing_Error_Report, new_line],ignore_index=True)
                
                    error_reason = ''
                    
                    continue
                else:
                    error_reason += 'Wrong Format. Please make sure the format looks like:\n{Address1}\n{Address2}\n{StreetNumber} {StreetName} {StreetType}\n{Suburb} {State} {Postcode}\n'
                    Billing_IDs_To_Exclude.append(customer_ID)
                    
                    new_line = pd.DataFrame.from_records([{'Customer_Code': row['Customer_Code'],
                                                    'ID': customer_ID,
                                                    'Billing_Address': row['Billing_Address'].replace("_", "\n"),
                                                    'Billing Error Type': error_reason
                        }])
            
                    Billing_Error_Report = pd.concat([Billing_Error_Report, new_line],ignore_index=True)
                
                    error_reason = ''
                    
                    continue
                    
                    
        
        if is_state_valid == False:
            
            if not any(state in suburb_details for state in states):
                error_reason += 'State Missing.\n'
                Billing_IDs_To_Exclude.append(customer_ID)
            else:
                Billing_IDs_To_Exclude.append(customer_ID)
                error_reason += 'State invalid. It should be 2 or 3 characters.\n'
                
                
        if suburb == '':
            error_reason += 'Suburb is Missing.'
            Billing_IDs_To_Exclude.append(customer_ID)

            
        if is_post_code_valid is False or is_state_valid is False or suburb == '':
            new_line = pd.DataFrame.from_records([{'Customer_Code': row['Customer_Code'],
                                                    'ID': customer_ID,
                                                    'Billing_Address': row['Billing_Address'].replace("_", "\n"),
                                                    'Billing Error Type': error_reason
                        }])
            
            Billing_Error_Report = pd.concat([Billing_Error_Report, new_line],ignore_index=True)
                
        error_reason = ''

# %%
Billing_Error_Report
# Out:
#                  Customer_Code     ID  \
# 0          9LVRNBVZENGPROJECTS  11480
# 1          9ENWOUWMENGINEERING  11479
# 2     9DLLZHAWIBJMAEYSPROJECTS  11470
# 3           9IUJVKPENGINEERING  11469
# 4                    9FOHAIWOQ  11438
# 5          GUEGGMIBDNABUILDING  10579
# 6     9CBTYRQNXFRJICEWPLUMBING  10324
# 7               9TKFSNBUILDING  10252
# 8          9DRPNOLZENGINEERING  10171
# 9                      9PCHUNK   9978
# 10   YZPNSAWHVROFFCONSTRUCTION   9854
# 11                 9JMNANHXGVU   7279
# 12             9EEXULQPROJECTS   5913
# 13             KGPNZULPROJECTS   5489
# 14                  YBUFQGROUP   4458
# 15         XCLLVAVXPTJPLUMBING   4124
# 16             9XPDONLGZZGROUP   3947
# 17          9OTYAJSXBNPLUMBING   3654
# 18           9BEUVWENGINEERING   2221
# 19       9RERXFIZRXENGINEERING   2136
# 20  9ONJNNNLGDXFJECONSTRUCTION   2022
# 21          9EGDKZGTNNPROJECTS   1936
# 22     9SGBUUFBQXQNORPPLUMBING   1924
# 23                       RBQZZ   1761
# 24               AIBAFNUKGROUP   1485
# 25            9MIHLIJLGRDGROUP   1477
# 26             DVALLRFUYXCFULM   1413
# 27                 BAWJAHEWOTW   1412
# 28              NOWEVWNMESCJSS   1072
# 29              RFGOIUNHWGROUP   1015
# 30          LXKXDYDENGINEERING   1006
# 31        AGHKNYXAJTXHSERVICES    998
# 32   JMWECAIWANPMPNENGINEERING    996
# 33                   CLAQVIQTV    991
# 34         BTFQXYSMNPNBUILDING    990
# 35           UKCXVJINOSERVICES    982
# 36               CWCGBBUILDING    975
# 37                  EZXFQSZFUB    971
# 38              PWDSBSOLUTIONS    969
# 39              EYSZDGPLUMBING    966
# 40          LJDPKMWIEUVZKGROUP    961
# 41      IFDRKVBSPFOAXRPLUMBING    952
# 42                       YLCFG    945
# 43          QWLJJIUACKPROJECTS    934
# 44                BYEGXYYWNXFK    899
# 45                 RUVCRVFHVME    893
# 46               RLONTBUILDING    890
# 47                FPYLSPWVNFJC    886
# 48                      MHROOF    883
# 49         EZYMAGNFKWGHQGGROUP    875
# 50           PRPKZJENGINEERING    866
# 51                      YVOSFU    860
# 52      VGWDXAQQUOCONSTRUCTION    859
# 53   ILAXEIWAESAOVCONSTRUCTION    858
# 54          DKGZTGHLTDPROJECTS    855
# 55                     BCCMTJW    691
# 56          9XNTTVLNHCFHYGROUP    617
# 57                    CLQRGPUI    370
#
#                                       Billing_Address  \
# 0                 50 Fitzroy Street\nCarrington, 2294
# 1   Level 18 Darling Park\n2/201 Sussex Street\n S...
# 2                                 Westlake QLD 4074\n
# 3                   Contructors (Aust) Pty Ltd\nTBA\n
# 4   Level 20\n1 Market Street\nSydney NSW 2000 Aus...
# 5   C/- Ticketmaster Australiasia\nLevel 5 – 364 L...
# 6            800 Feld Way\nPalmetto Florida USA 34221
# 7                                             SA 5044
# 8            Lot 5, D'aguilar Highway\nMoore 4314 QLD
# 9   CRSI Ni Ltd\n136 Torman Road\nCarrickmore Ireland
# 10                17 Wilga Road\nCaringbah South 2229
# 11                                             Sydney
# 12                     22 Castella Ct\nMeadow Heights
# 13  Level 35 Tower One International Tower\n100 Ba...
# 14       Suite 802, Level 8\n117 York St\nSydney 2000
# 15          Retail C2 Neild Avenue\nDarlinghurst 2010
# 16          35 Annfield Street\nKellyville Ridge 2155
# 17  Cowes Waterfront Venture Quays\nCastle Street,...
# 18                        c/- Chris Vella\nShore Hire
# 19                                     T/As The Falls
# 20  52 Telok Blangah Road\n#02-09 Telok Blangah Ho...
# 21                                                 \n
# 22  \nDO NOT USE - REFER TO CUSTOMER CODE 'DSECE' ...
# 23                     14 Plateau Road\nReservoir VIC
# 24                    *Under External Administration*
# 25                            REFER TO ACCT 9MJAWNING
# 26                 North Sydney Level 5, 40 Miller St
# 27                  Level5/ 26 College St Sydney 2000
# 28             325 Georges River Rd Croydon Park 2133
# 29                   31 De Havilland Crs Ballina 2478
# 30                 U5/ 2a Herbert St St Leonards 2065
# 31                     Lvl4/ 33 Hunter St Sydney 2000
# 32          Level 5/ 476 Victoria Rd gladesville 2111
# 33       AMP Centre, Lvl 37, 50 Bridge St Sydney 2000
# 34              U1/ 8 Bellevue St Newcastle West 2302
# 35                      46 Hoskins Ave Bankstown 2200
# 36                     Taren Point 1A -18 Box Rd 2229
# 37         U17/70- 72 Captain Cook Drv Caringbah 2229
# 38                     6 Spireton Pl Pendle Hill 2145
# 39                       13 The Anchorage Dudley 2290
# 40                    21 Gillian Pde West Pymble 2073
# 41                   Drummoyne 172 -176 Lyons Rd 2047
# 42          Unit 34,11- 21 Underwood Rd Homebush 2140
# 43                           7 Wordie Pl Padstow 2211
# 44                     37 Silver St Marrickville 2204
# 45                       U3/5- 11 Mellor St West Ryde
# 46                 U C1/ 15 Narabang Way Belrose 2085
# 47                      21 Waterloo Ave Thornton 2322
# 48               U1/ 1 Prosperity Pde Warriewood 2102
# 49               211 Memorial Ave Ettalong Beach 2257
# 50        Milsons Point Ste1/ 3 Harbour View Crs 2061
# 51                      174 Morgan St Merewether 2291
# 52                   U2/ 31 Anvil Rd Seven Hills 2147
# 53        Prestons Unit 3/ 22 -24 Enterprise Cct 2170
# 54                      U 2/ 45 Sheppard St Hume 2620
# 55  Unit 1/14 George Young Street\nRegents Park\nN...
# 56  598-600 South Road\nAngle Park SA 5010\nAustralia
# 57  48 Toh Guan Road East\n#04-118, Enterprise Hub...
#
#                                    Billing Error Type
# 0   Wrong Format. Please make sure the format look...
# 1   Wrong Format. Please make sure the format look...
# 2   Address is not complete. It should have at lea...
# 3   Wrong Format. Please make sure the format look...
# 4   Wrong Format. Please make sure the format look...
# 5   Wrong Format. Please make sure the format look...
# 6                 Postcode Missing.\nState Missing.\n
# 7   Address is not complete. It should have at lea...
# 8   Wrong Format. Please make sure the format look...
# 9   Wrong Format. Please make sure the format look...
# 10                                   State Missing.\n
# 11  Address is not complete. It should have at lea...
# 12  Wrong Format. Please make sure the format look...
# 13  Wrong Format. Please make sure the format look...
# 14  Wrong Format. Please make sure the format look...
# 15  Wrong Format. Please make sure the format look...
# 16                                   State Missing.\n
# 17  Wrong Format. Please make sure the format look...
# 18  Wrong Format. Please make sure the format look...
# 19  Address is not complete. It should have at lea...
# 20  Wrong Format. Please make sure the format look...
# 21  Address is not complete. It should have at lea...
# 22                Postcode Missing.\nState Missing.\n
# 23  Wrong Format. Please make sure the format look...
# 24  Address is not complete. It should have at lea...
# 25  Address is not complete. It should have at lea...
# 26  Address is not complete. It should have at lea...
# 27  Address is not complete. It should have at lea...
# 28  Address is not complete. It should have at lea...
# 29  Address is not complete. It should have at lea...
# 30  Address is not complete. It should have at lea...
# 31  Address is not complete. It should have at lea...
# 32  Address is not complete. It should have at lea...
# 33  Address is not complete. It should have at lea...
# 34  Address is not complete. It should have at lea...
# 35  Address is not complete. It should have at lea...
# 36  Address is not complete. It should have at lea...
# 37  Address is not complete. It should have at lea...
# 38  Address is not complete. It should have at lea...
# 39  Address is not complete. It should have at lea...
# 40  Address is not complete. It should have at lea...
# 41  Address is not complete. It should have at lea...
# 42  Address is not complete. It should have at lea...
# 43  Address is not complete. It should have at lea...
# 44  Address is not complete. It should have at lea...
# 45  Address is not complete. It should have at lea...
# 46  Address is not complete. It should have at lea...
# 47  Address is not complete. It should have at lea...
# 48  Address is not complete. It should have at lea...
# 49  Address is not complete. It should have at lea...
# 50  Address is not complete. It should have at lea...
# 51  Address is not complete. It should have at lea...
# 52  Address is not complete. It should have at lea...
# 53  Address is not complete. It should have at lea...
# 54  Address is not complete. It should have at lea...
# 55  Wrong Format. Please make sure the format look...
# 56  Wrong Format. Please make sure the format look...
# 57  Wrong Format. Please make sure the format look...

# %%
# Firt, we separate the Suburb, Post Code and State and put them into the new dataset

# The pattern we are looking for is: Condell Park NSW 2200 (Suburb State Postcode)

for index, row in df.iterrows():
    
    customer_ID = row['ID']
    
    if customer_ID in Billing_IDs_To_Exclude:
        continue
        
    else:
    
        parts = row['Billing_Address'].strip('_').strip('.').split('_') # spliting the string by _ that represents a line break

        suburb_details = parts[-1].split() # the last part is usually where the Suburb, post code and state are

        post_code = suburb_details[-1].strip(',').strip('`').strip().strip('.') # the post code is normally the last word in the last line

        state = suburb_details[-2].upper().strip(',').strip('`').strip('.') # the state is normally the second to last

        suburb = ' '.join(suburb_details[:-2]).upper().strip(',').strip('.') # suburb is the rest, it can be 2 or more words, so we join them with a space

        billing_address = '\n'.join(parts[:-1])

        billing_address += f'\n{suburb} {state} {post_code}'

        billing_first_group.loc[billing_first_group['ID'] == customer_ID, 'Billing_Postcode'] = post_code
        billing_first_group.loc[billing_first_group['ID'] == customer_ID, 'Billing_State'] = state
        billing_first_group.loc[billing_first_group['ID'] == customer_ID, 'Billing_Suburb'] = suburb
        billing_first_group.loc[billing_first_group['ID'] == customer_ID, 'Billing_Address'] = billing_address

# %% [markdown]
# #### Street Number and Street Name

# %%
# testing if there's any row not in the pattern

error_reason = ''

for index, row in df.iterrows():
    
    customer_ID = row['ID']
    
    if customer_ID in Billing_IDs_To_Exclude:
        continue
        
    else:
    
        parts = row['Billing_Address'].strip('_').strip('.').split('_')

        street_details = parts[-2] # geting the second group of the split

        last_index = find_last_number_index(street_details) # geting the index of the last number, which represents the street number

        street_no = street_details[:last_index+1].strip(',').strip('.') # street no is everything until the index of the last number

        street_name = street_details[last_index+1:] # street name starts right after the last number

        street_name = street_name.strip(',').strip('`').strip().strip('.').title()
        
        if street_no == '':
            
            if not ("Cnr" in street_details or "Corner" in street_details):
                Billing_IDs_To_Exclude.append(customer_ID)
                error_reason += 'No street number found!\n'
            else:
                street_no = 'NULL'
            
        if street_name == '':
            Billing_IDs_To_Exclude.append(customer_ID)
            error_reason += 'No street name found!.\n'
            
            
        if street_no == '' or street_name == '':
            new_line = pd.DataFrame.from_records([{'Customer_Code': row['Customer_Code'],
                                                    'ID': customer_ID,
                                                    'Billing_Address': row['Billing_Address'].replace("_", "\n"),
                                                    'Billing Error Type': error_reason
                        }])
            
            Billing_Error_Report = pd.concat([Billing_Error_Report, new_line],ignore_index=True)
                
        error_reason = ''

# %%
# Second, we get the street detail, that is normally the second group of the split

for index, row in df.iterrows():
    
    customer_ID = row['ID']
    
    if customer_ID in Billing_IDs_To_Exclude:
        continue
        
    else:
    
        parts = row['Billing_Address'].strip('_').strip('.').split('_')

        street_details = parts[-2] # geting the second group of the split

        last_index = find_last_number_index(street_details) # geting the index of the last number, which represents the street number

        street_no = street_details[:last_index+1].strip(',').strip('.') # street no is everything until the index of the last number

        street_name = street_details[last_index+1:] # street name starts right after the last number

        street_name = street_name.strip(',').strip('`').strip().strip('.').strip(',').title()

        billing_first_group.loc[billing_first_group['ID'] == customer_ID, 'Billing_StreetNo'] = street_no
        billing_first_group.loc[billing_first_group['ID'] == customer_ID, 'Billing_StreetName'] = street_name

# %% [markdown]
# #### Billing Address 2

# %%
# Third, we get what we have in the third group for those who have something and put in the Billing Address 2 column
for index, row in df.iterrows():
    
    customer_ID = row['ID']
    
    if customer_ID in Billing_IDs_To_Exclude:
        continue
        
    else:
    
        parts = row['Billing_Address'].strip('_').strip('.').split('_')

        trading_as = []
        adress2 = []

        if len(parts) > 2:

            for part in parts[:-2]:
                if part.lower().startswith("t/a") or part.lower().startswith("t/as"):
                    trading_as.append(part.strip().strip(',').strip('.'))
                else:
                    adress2.append(part.strip().strip(',').strip('.'))

            if len(adress2) > 0:
                billing_address2 = '\n'.join(adress2) # geting the second group of the split
                billing_address2 = billing_address2.strip('\n').strip('.')
                billing_first_group.loc[billing_first_group['ID'] == customer_ID, 'Billing_Address2'] = billing_address2

            if len(trading_as) > 0:
                billing_ta = '\n'.join(trading_as)
                billing_ta = billing_ta.strip().strip(',').strip('.')
                billing_first_group.loc[billing_first_group['ID'] == customer_ID, 'Billing_Customisable_Value'] = billing_ta
                billing_ta = None

# %% [markdown]
# #### Updating the Billing Address

# %%
for index, row in df.iterrows():
    
    customer_ID = row['ID']

    if customer_ID in Billing_IDs_To_Exclude:
        continue
        
    else:
    
        parts = row['Billing_Address'].strip('_').strip('.').split('_') # spliting the string by _ that represents a line break

        suburb_details = parts[-1].split() # the last part is usually where the Suburb, post code and state are 

        post_code = suburb_details[-1] # the post code is normally the last word in the last line

        state = suburb_details[-2].upper() # the state is normally the second to last

        suburb = ' '.join(suburb_details[:-2]).upper().strip(',').strip('.') # suburb is the rest, it can be 2 or more words, so we join them with a space

        billing_address = '\n'.join(parts[:-1])

        billing_address += f'\n{suburb} {state} {post_code}'

        billing_first_group.loc[billing_first_group['ID'] == customer_ID, 'Billing_Address'] = billing_address

# %%
billing_first_group = billing_first_group[~billing_first_group['ID'].isin(Billing_IDs_To_Exclude)]

billing_first_group
# Out:
#                    Customer_Code     ID Billing_ADR_Address_ID  \
# 0         9NBRZAGLJDHKHFBUILDING  11551                    NaN
# 1                        9UNFBFE  11505                    NaN
# 9                 9NPMZBPLUMBING  11334                    NaN
# 10               MKGCMMEBAEIFSHB  11307                    NaN
# 11                      INNRSECW  11283                    NaN
# 12              BTMZFCGNBUILDING  10974                    NaN
# 14      9ISWLNDMKQPXHMKXPROJECTS  10718                    NaN
# 15       RTHQFYHWSTAEULZPROJECTS  10689                    NaN
# 17              XSZNYDXNBUILDING  10547                    NaN
# 25           XQSXTNKDYLCBUILDING   8853                    NaN
# 26                 SPOMZPLUMBING   8750                    NaN
# 27              NVVDTOMVBUILDING   8659                    NaN
# 28             PDBULBPESOLUTIONS   8658                    NaN
# 30             HJINCDHPQBUILDING   8209                    NaN
# 32               VNWATYUYKEWFMIS   7953                    NaN
# 33                9HHVLPPROJECTS   7853                    NaN
# 34              9HIENQMDJEKTMZNC   7763                    NaN
# 35             BEMLOJLOAPROJECTS   7721                    NaN
# 38                      SIPXSWAX   6992                    NaN
# 39   9KRNMYEUQCFYHVUCONSTRUCTION   6800                    NaN
# 42                WQCLWPMVWWVTXD   5905                    NaN
# 43                MFCYZQPLUMBING   5561                    NaN
# 44               ZUQBWLZNODGROUP   5544                    NaN
# 45            IEUIJUCONSTRUCTION   5516                    NaN
# 49                    NLRLLGROUP   4810                    NaN
# 50               EFSJLESOLUTIONS   4715                    NaN
# 51               QXZWIFABUILDING   4530                    NaN
# 52    YVUYCRVUVBKQAQCONSTRUCTION   4524                    NaN
# 55           9OREOMBLFFHLXDGROUP   4038                    NaN
# 56                   9LCHGGGROUP   3977                    NaN
# 58                   9HZACYMKSFS   3812                    NaN
# 63           JJKOHLYFPLDPROJECTS   3621                    NaN
# 65               9JMCKFTBUILDING   3259                    NaN
# 70            PQXCGOSXPLBUILDING   2597                    NaN
# 71     CRIMJNYAORSSBCONSTRUCTION   2432                    NaN
# 72                     9GQBPTOSR   2317                    NaN
# 76                    CNNMOGTJEW   2161                    NaN
# 79    TTTCSXWIICJRZILENGINEERING   2064                    NaN
# 84       CRHKCFLCOYLQENGINEERING   1841                    NaN
# 85         DOBHYDIQDCONSTRUCTION   1805                    NaN
# 87                 FOXJVBUILDING   1556                    NaN
# 97         YFFCGFJEGEENGINEERING   1005                    NaN
# 100     ALQRRTTFNMJDCONSTRUCTION    992                    NaN
# 104                    WNWLQNMMM    978                    NaN
# 116         BRVPHIKKHWVHPROJECTS    887                    NaN
# 126       DXFCKJUZMKIENGINEERING    777                    NaN
# 128                ODCUJVZZGROUP    688                    NaN
# 131        NAGBHADCFDENGINEERING    596                    NaN
# 135      PTPJMOKHYBBWENGINEERING    371                    NaN
#
#                                        Billing_Address  \
# 0    Suite 4, Level 1, 374 Church Street \nPARRAMAT...
# 1    Suite 802, Level 8, 24 Montgomery Street \nKOG...
# 9          88 Dobroyd Drive \nELIZABETH DRIVE NSW 2171
# 10      145A Hutton Road \nTHE ENTRANCE NORTH NSW 2261
# 11   P/L & GS Engineering & Constructions Australia...
# 12   Ground Floor Building 24 270 Ferntree Gully Ro...
# 14       Cnr Stockton & Dredge Ave\nMOOREBANK NSW 2170
# 15   Suite 1601 Level 16 100 William Street\nWOOLLO...
# 17   Ferrovial Agroman (Australia) Pty Ltd\nT/As Ne...
# 25   Utilities P/L & Programmed Facility Management...
# 26                5/1 Vuko Place\nWARRIEWOOD NSW, 2102
# 27   Suite 13.03 Level 13,12 Help Street \nCHATSWOO...
# 28   Suite 1B, Level 31, 100 Miller Street\nNORTH S...
# 30                    491 Kent Street\nSYDNEY NSW 2000
# 32   Unit 2A Building 2A\nLakes Business Park 2-12 ...
# 33   Suite 1, Level 1, 693 Burke Road\nCAMBERWELL V...
# 34   Independence Australia Group\nNational Office ...
# 35   & Ghella P/L & UGL Engineering P/L\nT/As CPB B...
# 38   Australia Pty Ltd & Stantec Australia Pty Ltd ...
# 39        3 Twelth Ave\nPALM BEACH GOLD COAST QLD 4221
# 42       20-26 Produce Drive\nDANDENONG SOUTH VIC 3175
# 43   Level 1, Suite 4, 82-86 New Canterbury Road\nP...
# 44   Attention: Finance & Administration Manager\nJ...
# 45   Level 8, Tower B, 799 Pacific Highway\nCHATSWO...
# 49   T/As JHCPB JV, Canberra Metro Construction, NR...
# 50   Adminstration Building\n116 Adelaide Street (O...
# 51   C & T Corporation T/As CPB Samsung John Hollan...
# 52   T/As JHCPB JV, Canberra Metro Construction, NR...
# 55   Cnr Great Broome Road & Alahambra Drive\nEPPIN...
# 56   55-59 Level 1, Suite 3 Parramatta Road\nLIDCOM...
# 58   Level 23, HWT Tower, 40 City Road\nSOUTHBANK V...
# 63   Suite 10.03, Level 10, 275 Alfred Street, \nNO...
# 65      9 Furber Road\nCENTENNIAL PARK SYDNEY NSW 2021
# 70   Level 14 International Towers Exchange Place T...
# 71        4/52 Wirraway Drive\nPORT MELBOURNE VIC 3207
# 72   Cnr Stockton Ave & Dredge Ave\nMOOREBANK NSW 2170
# 76   Financial Transaction Services/Accounts\n14B, ...
# 79   14B,  30 The Bond, 30 Hickson Road\nMILLERS PO...
# 84    Cnr Highlands & Delatite Roads\nSEYMOUR VIC 3660
# 85   Level 4 Building B 480 Victoria Road\nGLADESVI...
# 87   Cnr Hope Street & Hughes Avenue\nERMINGTON NSW...
# 97   Bldg B, Level 3, 33-35 Saunders Street\nPYRMON...
# 100  Cnr Northcliffe Drive & Princes Highway\nUNAND...
# 104  T/As Select Plant Hire \nAtt: Select Plant Hir...
# 116  Tower 2/ Level 21 101 Grafton St     \nBONDI J...
# 126  Suite 1, Level 1, 290 Botany Road\nALEXANDRIA ...
# 128  (Receivers & Managers Appointed) (in Liquidati...
# 131  C/-Broadcast Australia Transmitting Station\nF...
# 135    Cnr Jones Bay & Pirrama Roads\nPYRMONT NSW 2009
#
#                   Billing_StreetNo  \
# 0            Suite 4, Level 1, 374
# 1           Suite 802, Level 8, 24
# 9                               88
# 10                            145A
# 11                Level 1, 436-438
# 12    Ground Floor Building 24 270
# 14
# 15         Suite 1601 Level 16 100
# 17                      Level 9/32
# 25                      Level 4 11
# 26                             5/1
# 27         Suite 13.03 Level 13,12
# 28         Suite 1B, Level 31, 100
# 30                             491
# 32        Lakes Business Park 2-12
# 33           Suite 1, Level 1, 693
# 34   National Office Building 1, 9
# 35         Level 3 North Tower 339
# 38                           1/131
# 39                               3
# 42                           20-26
# 43         Level 1, Suite 4, 82-86
# 44                           L4 60
# 45           Level 8, Tower B, 799
# 49                              22
# 50                             116
# 51                     Level 2, 52
# 52                             330
# 55
# 56          55-59 Level 1, Suite 3
# 58         Level 23, HWT Tower, 40
# 63      Suite 10.03, Level 10, 275
# 65                               9
# 70                        Level 14
# 71                            4/52
# 72
# 76                         14B, 30
# 79           14B,  30 The Bond, 30
# 84
# 85          Level 4 Building B 480
# 87
# 97          Bldg B, Level 3, 33-35
# 100
# 104                            825
# 116          Tower 2/ Level 21 101
# 126          Suite 1, Level 1, 290
# 128                 Unit 32, 11-21
# 131                          2-148
# 135
#
#                                   Billing_StreetName Billing_StreetType  \
# 0                                      Church Street                NaN
# 1                                  Montgomery Street                NaN
# 9                                      Dobroyd Drive                NaN
# 10                                       Hutton Road                NaN
# 11                                   Johnston Street                NaN
# 12                               Ferntree Gully Road                NaN
# 14                         Cnr Stockton & Dredge Ave                NaN
# 15                                    William Street                NaN
# 17                                     Turbot Street                NaN
# 25                                Murray Rose Avenue                NaN
# 26                                        Vuko Place                NaN
# 27                                       Help Street                NaN
# 28                                     Miller Street                NaN
# 30                                       Kent Street                NaN
# 32                                       Lord Street                NaN
# 33                                        Burke Road                NaN
# 34                                     Ashley Street                NaN
# 35                                  Coronation Drive                NaN
# 38                                   Adderley Street                NaN
# 39                                        Twelth Ave                NaN
# 42                                     Produce Drive                NaN
# 43                               New Canterbury Road                NaN
# 44                                      Union Street                NaN
# 45                                   Pacific Highway                NaN
# 49                                      Giffnock Ave                NaN
# 50             Adelaide Street (Old Pacific Highway)                NaN
# 51                                    Railway Parade                NaN
# 52                                   Northbourne Ave                NaN
# 55           Cnr Great Broome Road & Alahambra Drive                NaN
# 56                                   Parramatta Road                NaN
# 58                                         City Road                NaN
# 63                                     Alfred Street                NaN
# 65                                       Furber Road                NaN
# 70   International Towers Exchange Place Tower Three                NaN
# 71                                    Wirraway Drive                NaN
# 72                     Cnr Stockton Ave & Dredge Ave                NaN
# 76                                          The Bond                NaN
# 79                                      Hickson Road                NaN
# 84                    Cnr Highlands & Delatite Roads                NaN
# 85                                     Victoria Road                NaN
# 87                   Cnr Hope Street & Hughes Avenue                NaN
# 97                                   Saunders Street                NaN
# 100          Cnr Northcliffe Drive & Princes Highway                NaN
# 104                                       Ann Street                NaN
# 116                                       Grafton St                NaN
# 126                                      Botany Road                NaN
# 128                                   Underwood Road                NaN
# 131                                    Sydenham Road                NaN
# 135                    Cnr Jones Bay & Pirrama Roads                NaN
#
#                    Billing_Suburb Billing_State Billing_Postcode  ...  \
# 0                      PARRAMATTA           NSW             2150  ...
# 1                         KOGARAH           NSW             2217  ...
# 9                 ELIZABETH DRIVE           NSW             2171  ...
# 10             THE ENTRANCE NORTH           NSW             2261  ...
# 11                     ABBOTSFORD           VIC             3067  ...
# 12                   NOTTING HILL           VIC             3168  ...
# 14                      MOOREBANK           NSW             2170  ...
# 15                  WOOLLOOMOOLOO           NSW             2011  ...
# 17                       BRISBANE           QLD             4000  ...
# 25            SYDNEY OLYMPIC PARK           NSW             2127  ...
# 26                     WARRIEWOOD           NSW             2102  ...
# 27                      CHATSWOOD           NSW             2067  ...
# 28                   NORTH SYDNEY           NSW             2060  ...
# 30                         SYDNEY           NSW             2000  ...
# 32                         BOTANY           NSW             2019  ...
# 33                     CAMBERWELL           VIC             3124  ...
# 34                 WEST FOOTSCRAY           VIC             3012  ...
# 35                         MILTON           QLD             4064  ...
# 38                 WEST MELBOURNE           VIC             3003  ...
# 39          PALM BEACH GOLD COAST           QLD             4221  ...
# 42                DANDENONG SOUTH           VIC             3175  ...
# 43                      PETERSHAM           NSW             2049  ...
# 44                        PYRMONT           NSW             2009  ...
# 45                      CHATSWOOD           NSW             2067  ...
# 49                 MACQUARIE PARK           NSW             2113  ...
# 50                RAYMOND TERRACE           NSW             2324  ...
# 51                        BURWOOD           NSW             2134  ...
# 52                        DICKSON           ACT             2602  ...
# 55                         EPPING           VIC             3076  ...
# 56                       LIDCOMBE           NSW             2141  ...
# 58                      SOUTHBANK           VIC             3006  ...
# 63                   NORTH SYDNEY           NSW             2060  ...
# 65         CENTENNIAL PARK SYDNEY           NSW             2021  ...
# 70      300 BARANGAROO AVE SYDNEY           NSW             2000  ...
# 71                 PORT MELBOURNE           VIC             3207  ...
# 72                      MOOREBANK           NSW             2170  ...
# 76   30 HICKENS RD, MILLER POINTS           NSW             2000  ...
# 79                  MILLERS POINT           NSW             2000  ...
# 84                        SEYMOUR           VIC             3660  ...
# 85                    GLADESVILLE           NSW             2111  ...
# 87                      ERMINGTON           NSW             2115  ...
# 97                        PYRMONT           NSW             2009  ...
# 100                     UNANDERRA           NSW             2526  ...
# 104    FORTITUDE VALLEY, BRISBANE           QLD             4006  ...
# 116                BONDI JUNCTION           NSW             2022  ...
# 126                    ALEXANDRIA           NSW             2015  ...
# 128                      HOMEBUSH           NSW             2140  ...
# 131                       DELAHEY           VIC             3037  ...
# 135                       PYRMONT           NSW             2009  ...
#
#     Delivery_ADR_Address_ID Delivery_Address Delivery_StreetNo  \
# 0                       NaN              NaN               NaN
# 1                       NaN              NaN               NaN
# 9                       NaN              NaN               NaN
# 10                      NaN              NaN               NaN
# 11                      NaN              NaN               NaN
# 12                      NaN              NaN               NaN
# 14                      NaN              NaN               NaN
# 15                      NaN              NaN               NaN
# 17                      NaN              NaN               NaN
# 25                      NaN              NaN               NaN
# 26                      NaN              NaN               NaN
# 27                      NaN              NaN               NaN
# 28                      NaN              NaN               NaN
# 30                      NaN              NaN               NaN
# 32                      NaN              NaN               NaN
# 33                      NaN              NaN               NaN
# 34                      NaN              NaN               NaN
# 35                      NaN              NaN               NaN
# 38                      NaN              NaN               NaN
# 39                      NaN              NaN               NaN
# 42                      NaN              NaN               NaN
# 43                      NaN              NaN               NaN
# 44                      NaN              NaN               NaN
# 45                      NaN              NaN               NaN
# 49                      NaN              NaN               NaN
# 50                      NaN              NaN               NaN
# 51                      NaN              NaN               NaN
# 52                      NaN              NaN               NaN
# 55                      NaN              NaN               NaN
# 56                      NaN              NaN               NaN
# 58                      NaN              NaN               NaN
# 63                      NaN              NaN               NaN
# 65                      NaN              NaN               NaN
# 70                      NaN              NaN               NaN
# 71                      NaN              NaN               NaN
# 72                      NaN              NaN               NaN
# 76                      NaN              NaN               NaN
# 79                      NaN              NaN               NaN
# 84                      NaN              NaN               NaN
# 85                      NaN              NaN               NaN
# 87                      NaN              NaN               NaN
# 97                      NaN              NaN               NaN
# 100                     NaN              NaN               NaN
# 104                     NaN              NaN               NaN
# 116                     NaN              NaN               NaN
# 126                     NaN              NaN               NaN
# 128                     NaN              NaN               NaN
# 131                     NaN              NaN               NaN
# 135                     NaN              NaN               NaN
#
#     Delivery_StreetName Delivery_StreetType Delivery_Suburb Delivery_State  \
# 0                   NaN                 NaN             NaN            NaN
# 1                   NaN                 NaN             NaN            NaN
# 9                   NaN                 NaN             NaN            NaN
# 10                  NaN                 NaN             NaN            NaN
# 11                  NaN                 NaN             NaN            NaN
# 12                  NaN                 NaN             NaN            NaN
# 14                  NaN                 NaN             NaN            NaN
# 15                  NaN                 NaN             NaN            NaN
# 17                  NaN                 NaN             NaN            NaN
# 25                  NaN                 NaN             NaN            NaN
# 26                  NaN                 NaN             NaN            NaN
# 27                  NaN                 NaN             NaN            NaN
# 28                  NaN                 NaN             NaN            NaN
# 30                  NaN                 NaN             NaN            NaN
# 32                  NaN                 NaN             NaN            NaN
# 33                  NaN                 NaN             NaN            NaN
# 34                  NaN                 NaN             NaN            NaN
# 35                  NaN                 NaN             NaN            NaN
# 38                  NaN                 NaN             NaN            NaN
# 39                  NaN                 NaN             NaN            NaN
# 42                  NaN                 NaN             NaN            NaN
# 43                  NaN                 NaN             NaN            NaN
# 44                  NaN                 NaN             NaN            NaN
# 45                  NaN                 NaN             NaN            NaN
# 49                  NaN                 NaN             NaN            NaN
# 50                  NaN                 NaN             NaN            NaN
# 51                  NaN                 NaN             NaN            NaN
# 52                  NaN                 NaN             NaN            NaN
# 55                  NaN                 NaN             NaN            NaN
# 56                  NaN                 NaN             NaN            NaN
# 58                  NaN                 NaN             NaN            NaN
# 63                  NaN                 NaN             NaN            NaN
# 65                  NaN                 NaN             NaN            NaN
# 70                  NaN                 NaN             NaN            NaN
# 71                  NaN                 NaN             NaN            NaN
# 72                  NaN                 NaN             NaN            NaN
# 76                  NaN                 NaN             NaN            NaN
# 79                  NaN                 NaN             NaN            NaN
# 84                  NaN                 NaN             NaN            NaN
# 85                  NaN                 NaN             NaN            NaN
# 87                  NaN                 NaN             NaN            NaN
# 97                  NaN                 NaN             NaN            NaN
# 100                 NaN                 NaN             NaN            NaN
# 104                 NaN                 NaN             NaN            NaN
# 116                 NaN                 NaN             NaN            NaN
# 126                 NaN                 NaN             NaN            NaN
# 128                 NaN                 NaN             NaN            NaN
# 131                 NaN                 NaN             NaN            NaN
# 135                 NaN                 NaN             NaN            NaN
#
#     Delivery_Postcode Delivery_Customisable_Value Delivery_Address2
# 0                 NaN                         NaN               NaN
# 1                 NaN                         NaN               NaN
# 9                 NaN                         NaN               NaN
# 10                NaN                         NaN               NaN
# 11                NaN                         NaN               NaN
# 12                NaN                         NaN               NaN
# 14                NaN                         NaN               NaN
# 15                NaN                         NaN               NaN
# 17                NaN                         NaN               NaN
# 25                NaN                         NaN               NaN
# 26                NaN                         NaN               NaN
# 27                NaN                         NaN               NaN
# 28                NaN                         NaN               NaN
# 30                NaN                         NaN               NaN
# 32                NaN                         NaN               NaN
# 33                NaN                         NaN               NaN
# 34                NaN                         NaN               NaN
# 35                NaN                         NaN               NaN
# 38                NaN                         NaN               NaN
# 39                NaN                         NaN               NaN
# 42                NaN                         NaN               NaN
# 43                NaN                         NaN               NaN
# 44                NaN                         NaN               NaN
# 45                NaN                         NaN               NaN
# 49                NaN                         NaN               NaN
# 50                NaN                         NaN               NaN
# 51                NaN                         NaN               NaN
# 52                NaN                         NaN               NaN
# 55                NaN                         NaN               NaN
# 56                NaN                         NaN               NaN
# 58                NaN                         NaN               NaN
# 63                NaN                         NaN               NaN
# 65                NaN                         NaN               NaN
# 70                NaN                         NaN               NaN
# 71                NaN                         NaN               NaN
# 72                NaN                         NaN               NaN
# 76                NaN                         NaN               NaN
# 79                NaN                         NaN               NaN
# 84                NaN                         NaN               NaN
# 85                NaN                         NaN               NaN
# 87                NaN                         NaN               NaN
# 97                NaN                         NaN               NaN
# 100               NaN                         NaN               NaN
# 104               NaN                         NaN               NaN
# 116               NaN                         NaN               NaN
# 126               NaN                         NaN               NaN
# 128               NaN                         NaN               NaN
# 131               NaN                         NaN               NaN
# 135               NaN                         NaN               NaN
#
# [49 rows x 22 columns]

# %% [markdown]
# ### Second Group: PO Box and Locked Bag

# %%
# Establish the connection with Windows authentication

#conn = pyodbc.connect(
#    f'DRIVER=ODBC Driver 17 for SQL Server;SERVER={server};DATABASE={database};UID={username};PWD={password};'
#)

# Create a cursor object to interact with the database

#cursor = conn.cursor()

select_billing_second = f"""

WITH UpdateSelection AS (

SELECT DISTINCT [Source_Id]
FROM [sample_database].[dbo].[VA_DBT_Master]
WHERE [Audited_Field] IN ('Billing_Address') 
AND Operation IN ('U', 'I')
AND Audit_DateTime > '{last_finish_date}'
AND Audit_User NOT LIKE 'TableauAdminAccess'

AND [After_Value] IS NOT NULL AND [After_Value] NOT LIKE 'TBA%' AND

([After_Value]  LIKE '%Locked Bag%' OR [After_Value] LIKE '%PO BOX%' OR [After_Value] LIKE '%P.O. BOX%' OR [After_Value] LIKE '%P.O BOX%'
 OR [After_Value] LIKE '%P O Box%' OR [After_Value] LIKE '%Private Bag%')

)

SELECT     
    [Customer_Code],
    [ID],
    REPLACE([Billing_Address],CHAR(13)+CHAR(10),'_') AS [Billing_Address]
FROM [sample_database].[dbo].[DBT_Master]

WHERE

[Billing_Address] IS NOT NULL AND [Billing_Address] NOT LIKE 'TBA%' AND

([Billing_Address]  LIKE '%Locked Bag%' OR [Billing_Address] LIKE '%PO BOX%' OR [Billing_Address] LIKE '%P.O. BOX%' OR [Billing_Address] LIKE '%P.O BOX%'
 OR [Billing_Address] LIKE '%P O Box%' OR [Billing_Address] LIKE '%Private Bag%')

AND [ID] IN (SELECT DISTINCT [Source_Id]
            FROM UpdateSelection)

        """
#df2 = pd.read_sql_query(select_billing_second, conn)

#cursor.close()
#conn.close()

df2 = pd.read_excel("Billing Address - PO Boxes.xlsx")

df2
# Out:
#                  Customer_Code     ID  \
# 0           9KMCTUNTYTSERVICES  11485
# 1               PBPHYIPLUMBING  11405
# 2        9WAHBNWPXZENGINEERING  11289
# 3     9EMKTVVGFJZXYUNWBUILDING  10999
# 4                       9BGRBF  10677
# 5     YIFIOTLKGHCYBENGINEERING  10273
# 6                 DCCGOOARUQFQ  10267
# 7             9EPDYNAUSERVICES  10209
# 8          SAMOQDVBTHXPROJECTS  10153
# 9               TAXPTQPROJECTS   9625
# 10        ZWWGFVULCXOHSERVICES   9384
# 11            FOSTLYRCPROJECTS   8954
# 12             ACAWCHFDFTLASGA   8839
# 13  LDONRWFLJVQKZQCONSTRUCTION   8683
# 14      AITPTHCJUMZKBDPLUMBING   7737
# 15       HIUMKMIIJVXOSOLUTIONS   7394
# 16                 9FUREPMBIIX   7353
# 17              PJFNSRXTBDHZEV   7112
# 18    9DXBWGRZXSXQCONSTRUCTION   7098
# 19               JYXYXSERVICES   7003
# 20       UECRDNBBAYENGINEERING   6935
# 21          JVOOBZBBTYPROJECTS   6559
# 22               NYULZQAGEEKPY   6519
# 23           LYOCOCONSTRUCTION   6411
# 24             TEYBYZEPLUMBING   6300
# 25                  9YEGUROKLO   6253
# 26           UZRTGWVFAKJYGROUP   5201
# 27              UNDHWRBUILDING   4795
# 28        9HXUANDYQXPIPROJECTS   4766
# 29               9HKLCDEYVTKQH   4511
# 30          ZLAAIUQSPLPLUMBING   4295
# 31                      TKNNXW   3958
# 32           YDXAFMYJQSERVICES   3828
# 33           LWNOMAXVHPLUMBING   3643
# 34            VQVTQBUBSERVICES   3628
# 35          9KHHGQKENGINEERING   2986
# 36            9FLRFUSTPLUMBING   2819
# 37            9DIGMGHGQMYGROUP   2520
# 38      DDBAQOQJYAWENGINEERING   2420
# 39          QTKNROZQXOPROJECTS   2375
# 40                     JBRZQUZ   2349
# 41        HMBDANGVUTNHPROJECTS   2157
# 42        WYPXHJBOCONSTRUCTION   2149
# 43                VFFWJPWIHRHT   1859
# 44            VKLLSIUWPLUMBING   1590
# 45   MCLODCWPGCQAEIENGINEERING   1368
# 46             PKHRMIJPROJECTS    439
#
#                                       Billing_Address
# 0                GPO Box 4311_Melbourne Victoria 3001
# 1                    PO Box 5485 _Wollongong NSW 2520
# 2               PO Box 1161 _Mountain Gate Vic 3165 _
# 3   T/As Odyssey Constructions & Fitout_PO Box 717...
# 4      PO BOX 13268_George Street_Queensland QLD 4003
# 5                        PO Box 9109_South Yarra 3141
# 6                       PO Box 130_Morphett Vale 5162
# 7                              PO Box 279_Batman 3058
# 8                     PO Box 1160_Altona Meadows 3028
# 9   Engineering Pty Ltd T/As CPB Ghella UGL JV_Att...
# 10                         PO Box 86_Pooraka SA 5095_
# 11                 PO Box 567_Carina Heights QLD 4152
# 12              PO Box 3828_Victoria Point West 4165_
# 13  Laing O'Rourke Australia Group Pty Ltd_Account...
# 14                       PO Box 2169_Taren Point 2229
# 15                PO Box 8101_Glenmore Park NSW 22145
# 16                      PO Box 280_Bribie Island 4507
# 17  Rail Pty Ltd T/As Acciona Coleman Rail Joint V...
# 18  PO Box 914_Port  Moresby NCD 121, PNG Wood PNG...
# 19            PO Box 2083_Grovedale East LPO_VIC 3216
# 20                         PO Box 3355_Darra QLD 4076
# 21                     PO Box 230_Baulkham Hills 1755
# 22                    P.O Box 1410_Beenleigh QLD 4207
# 23  Engineering P/L, Persal & Co Trading P/L , Per...
# 24                Rouse Hill LPO_PO Box 3255_NSW 2155
# 25                     PO Box 4337_Pittwater NSW 2756
# 26  M & I Samaras (No3) P/L_T/As Samaras Group Sam...
# 27                      PO Box 3346_Richmond VIC 3121
# 28            PO Box 334_Stanhope Gardens  NSSW  2768
# 29                      PO Box 3110_Lansvale NSW 2166
# 30                     PO Box 687_Gisborne  VIC  3437
# 31  P/L & Seymour Whyte Constructions P/L & UGL En...
# 32  PO Box 40_Picton  NSW  2571_Attention: Mathew ...
# 33     PO Box 5171_Hunter Region Mail Centre_NSW 2310
# 34  T/As Chronis Building & Design_PO Box 182_Kiam...
# 35  PO Box 13291_George Street  QLD  4003_Attentio...
# 36                     PO Box 919_Parramatta NSW 2150
# 37              PO Box 6924_Baulkham Hills  NSW  2153
# 38  Technical & Further Education Commission_Accou...
# 39  PO Box 2375_Dangar NSW 2309_Supplier No. 13800683
# 40                 PO Box 16151_Northpoint  QLD  4350
# 41                      GPO Box 399_Brisbane QLD 4001
# 42   PO Box 842_Port Moresby 121, NC_Papua New Guinea
# 43                     PO Box 2250_Niirabbub VIC 3189
# 44  PO Box 207_Carole Park QLD 4300_Attention: Acc...
# 45                         PO Box 185_Sans Souci 2219
# 46  PO Box 58_'Claim for Payment'_Glen Innes NSW 2370

# %%
billing_second_group = pd.DataFrame(columns=columns)

billing_second_group['Customer_Code'] = df2['Customer_Code']
billing_second_group['ID'] = df2['ID']
billing_second_group['Billing_Address'] = df2['Billing_Address']

billing_second_group
# Out:
#                  Customer_Code     ID Billing_ADR_Address_ID  \
# 0           9KMCTUNTYTSERVICES  11485                    NaN
# 1               PBPHYIPLUMBING  11405                    NaN
# 2        9WAHBNWPXZENGINEERING  11289                    NaN
# 3     9EMKTVVGFJZXYUNWBUILDING  10999                    NaN
# 4                       9BGRBF  10677                    NaN
# 5     YIFIOTLKGHCYBENGINEERING  10273                    NaN
# 6                 DCCGOOARUQFQ  10267                    NaN
# 7             9EPDYNAUSERVICES  10209                    NaN
# 8          SAMOQDVBTHXPROJECTS  10153                    NaN
# 9               TAXPTQPROJECTS   9625                    NaN
# 10        ZWWGFVULCXOHSERVICES   9384                    NaN
# 11            FOSTLYRCPROJECTS   8954                    NaN
# 12             ACAWCHFDFTLASGA   8839                    NaN
# 13  LDONRWFLJVQKZQCONSTRUCTION   8683                    NaN
# 14      AITPTHCJUMZKBDPLUMBING   7737                    NaN
# 15       HIUMKMIIJVXOSOLUTIONS   7394                    NaN
# 16                 9FUREPMBIIX   7353                    NaN
# 17              PJFNSRXTBDHZEV   7112                    NaN
# 18    9DXBWGRZXSXQCONSTRUCTION   7098                    NaN
# 19               JYXYXSERVICES   7003                    NaN
# 20       UECRDNBBAYENGINEERING   6935                    NaN
# 21          JVOOBZBBTYPROJECTS   6559                    NaN
# 22               NYULZQAGEEKPY   6519                    NaN
# 23           LYOCOCONSTRUCTION   6411                    NaN
# 24             TEYBYZEPLUMBING   6300                    NaN
# 25                  9YEGUROKLO   6253                    NaN
# 26           UZRTGWVFAKJYGROUP   5201                    NaN
# 27              UNDHWRBUILDING   4795                    NaN
# 28        9HXUANDYQXPIPROJECTS   4766                    NaN
# 29               9HKLCDEYVTKQH   4511                    NaN
# 30          ZLAAIUQSPLPLUMBING   4295                    NaN
# 31                      TKNNXW   3958                    NaN
# 32           YDXAFMYJQSERVICES   3828                    NaN
# 33           LWNOMAXVHPLUMBING   3643                    NaN
# 34            VQVTQBUBSERVICES   3628                    NaN
# 35          9KHHGQKENGINEERING   2986                    NaN
# 36            9FLRFUSTPLUMBING   2819                    NaN
# 37            9DIGMGHGQMYGROUP   2520                    NaN
# 38      DDBAQOQJYAWENGINEERING   2420                    NaN
# 39          QTKNROZQXOPROJECTS   2375                    NaN
# 40                     JBRZQUZ   2349                    NaN
# 41        HMBDANGVUTNHPROJECTS   2157                    NaN
# 42        WYPXHJBOCONSTRUCTION   2149                    NaN
# 43                VFFWJPWIHRHT   1859                    NaN
# 44            VKLLSIUWPLUMBING   1590                    NaN
# 45   MCLODCWPGCQAEIENGINEERING   1368                    NaN
# 46             PKHRMIJPROJECTS    439                    NaN
#
#                                       Billing_Address Billing_StreetNo  \
# 0                GPO Box 4311_Melbourne Victoria 3001              NaN
# 1                    PO Box 5485 _Wollongong NSW 2520              NaN
# 2               PO Box 1161 _Mountain Gate Vic 3165 _              NaN
# 3   T/As Odyssey Constructions & Fitout_PO Box 717...              NaN
# 4      PO BOX 13268_George Street_Queensland QLD 4003              NaN
# 5                        PO Box 9109_South Yarra 3141              NaN
# 6                       PO Box 130_Morphett Vale 5162              NaN
# 7                              PO Box 279_Batman 3058              NaN
# 8                     PO Box 1160_Altona Meadows 3028              NaN
# 9   Engineering Pty Ltd T/As CPB Ghella UGL JV_Att...              NaN
# 10                         PO Box 86_Pooraka SA 5095_              NaN
# 11                 PO Box 567_Carina Heights QLD 4152              NaN
# 12              PO Box 3828_Victoria Point West 4165_              NaN
# 13  Laing O'Rourke Australia Group Pty Ltd_Account...              NaN
# 14                       PO Box 2169_Taren Point 2229              NaN
# 15                PO Box 8101_Glenmore Park NSW 22145              NaN
# 16                      PO Box 280_Bribie Island 4507              NaN
# 17  Rail Pty Ltd T/As Acciona Coleman Rail Joint V...              NaN
# 18  PO Box 914_Port  Moresby NCD 121, PNG Wood PNG...              NaN
# 19            PO Box 2083_Grovedale East LPO_VIC 3216              NaN
# 20                         PO Box 3355_Darra QLD 4076              NaN
# 21                     PO Box 230_Baulkham Hills 1755              NaN
# 22                    P.O Box 1410_Beenleigh QLD 4207              NaN
# 23  Engineering P/L, Persal & Co Trading P/L , Per...              NaN
# 24                Rouse Hill LPO_PO Box 3255_NSW 2155              NaN
# 25                     PO Box 4337_Pittwater NSW 2756              NaN
# 26  M & I Samaras (No3) P/L_T/As Samaras Group Sam...              NaN
# 27                      PO Box 3346_Richmond VIC 3121              NaN
# 28            PO Box 334_Stanhope Gardens  NSSW  2768              NaN
# 29                      PO Box 3110_Lansvale NSW 2166              NaN
# 30                     PO Box 687_Gisborne  VIC  3437              NaN
# 31  P/L & Seymour Whyte Constructions P/L & UGL En...              NaN
# 32  PO Box 40_Picton  NSW  2571_Attention: Mathew ...              NaN
# 33     PO Box 5171_Hunter Region Mail Centre_NSW 2310              NaN
# 34  T/As Chronis Building & Design_PO Box 182_Kiam...              NaN
# 35  PO Box 13291_George Street  QLD  4003_Attentio...              NaN
# 36                     PO Box 919_Parramatta NSW 2150              NaN
# 37              PO Box 6924_Baulkham Hills  NSW  2153              NaN
# 38  Technical & Further Education Commission_Accou...              NaN
# 39  PO Box 2375_Dangar NSW 2309_Supplier No. 13800683              NaN
# 40                 PO Box 16151_Northpoint  QLD  4350              NaN
# 41                      GPO Box 399_Brisbane QLD 4001              NaN
# 42   PO Box 842_Port Moresby 121, NC_Papua New Guinea              NaN
# 43                     PO Box 2250_Niirabbub VIC 3189              NaN
# 44  PO Box 207_Carole Park QLD 4300_Attention: Acc...              NaN
# 45                         PO Box 185_Sans Souci 2219              NaN
# 46  PO Box 58_'Claim for Payment'_Glen Innes NSW 2370              NaN
#
#    Billing_StreetName Billing_StreetType Billing_Suburb Billing_State  \
# 0                 NaN                NaN            NaN           NaN
# 1                 NaN                NaN            NaN           NaN
# 2                 NaN                NaN            NaN           NaN
# 3                 NaN                NaN            NaN           NaN
# 4                 NaN                NaN            NaN           NaN
# 5                 NaN                NaN            NaN           NaN
# 6                 NaN                NaN            NaN           NaN
# 7                 NaN                NaN            NaN           NaN
# 8                 NaN                NaN            NaN           NaN
# 9                 NaN                NaN            NaN           NaN
# 10                NaN                NaN            NaN           NaN
# 11                NaN                NaN            NaN           NaN
# 12                NaN                NaN            NaN           NaN
# 13                NaN                NaN            NaN           NaN
# 14                NaN                NaN            NaN           NaN
# 15                NaN                NaN            NaN           NaN
# 16                NaN                NaN            NaN           NaN
# 17                NaN                NaN            NaN           NaN
# 18                NaN                NaN            NaN           NaN
# 19                NaN                NaN            NaN           NaN
# 20                NaN                NaN            NaN           NaN
# 21                NaN                NaN            NaN           NaN
# 22                NaN                NaN            NaN           NaN
# 23                NaN                NaN            NaN           NaN
# 24                NaN                NaN            NaN           NaN
# 25                NaN                NaN            NaN           NaN
# 26                NaN                NaN            NaN           NaN
# 27                NaN                NaN            NaN           NaN
# 28                NaN                NaN            NaN           NaN
# 29                NaN                NaN            NaN           NaN
# 30                NaN                NaN            NaN           NaN
# 31                NaN                NaN            NaN           NaN
# 32                NaN                NaN            NaN           NaN
# 33                NaN                NaN            NaN           NaN
# 34                NaN                NaN            NaN           NaN
# 35                NaN                NaN            NaN           NaN
# 36                NaN                NaN            NaN           NaN
# 37                NaN                NaN            NaN           NaN
# 38                NaN                NaN            NaN           NaN
# 39                NaN                NaN            NaN           NaN
# 40                NaN                NaN            NaN           NaN
# 41                NaN                NaN            NaN           NaN
# 42                NaN                NaN            NaN           NaN
# 43                NaN                NaN            NaN           NaN
# 44                NaN                NaN            NaN           NaN
# 45                NaN                NaN            NaN           NaN
# 46                NaN                NaN            NaN           NaN
#
#    Billing_Postcode  ... Delivery_ADR_Address_ID Delivery_Address  \
# 0               NaN  ...                     NaN              NaN
# 1               NaN  ...                     NaN              NaN
# 2               NaN  ...                     NaN              NaN
# 3               NaN  ...                     NaN              NaN
# 4               NaN  ...                     NaN              NaN
# 5               NaN  ...                     NaN              NaN
# 6               NaN  ...                     NaN              NaN
# 7               NaN  ...                     NaN              NaN
# 8               NaN  ...                     NaN              NaN
# 9               NaN  ...                     NaN              NaN
# 10              NaN  ...                     NaN              NaN
# 11              NaN  ...                     NaN              NaN
# 12              NaN  ...                     NaN              NaN
# 13              NaN  ...                     NaN              NaN
# 14              NaN  ...                     NaN              NaN
# 15              NaN  ...                     NaN              NaN
# 16              NaN  ...                     NaN              NaN
# 17              NaN  ...                     NaN              NaN
# 18              NaN  ...                     NaN              NaN
# 19              NaN  ...                     NaN              NaN
# 20              NaN  ...                     NaN              NaN
# 21              NaN  ...                     NaN              NaN
# 22              NaN  ...                     NaN              NaN
# 23              NaN  ...                     NaN              NaN
# 24              NaN  ...                     NaN              NaN
# 25              NaN  ...                     NaN              NaN
# 26              NaN  ...                     NaN              NaN
# 27              NaN  ...                     NaN              NaN
# 28              NaN  ...                     NaN              NaN
# 29              NaN  ...                     NaN              NaN
# 30              NaN  ...                     NaN              NaN
# 31              NaN  ...                     NaN              NaN
# 32              NaN  ...                     NaN              NaN
# 33              NaN  ...                     NaN              NaN
# 34              NaN  ...                     NaN              NaN
# 35              NaN  ...                     NaN              NaN
# 36              NaN  ...                     NaN              NaN
# 37              NaN  ...                     NaN              NaN
# 38              NaN  ...                     NaN              NaN
# 39              NaN  ...                     NaN              NaN
# 40              NaN  ...                     NaN              NaN
# 41              NaN  ...                     NaN              NaN
# 42              NaN  ...                     NaN              NaN
# 43              NaN  ...                     NaN              NaN
# 44              NaN  ...                     NaN              NaN
# 45              NaN  ...                     NaN              NaN
# 46              NaN  ...                     NaN              NaN
#
#    Delivery_StreetNo Delivery_StreetName Delivery_StreetType Delivery_Suburb  \
# 0                NaN                 NaN                 NaN             NaN
# 1                NaN                 NaN                 NaN             NaN
# 2                NaN                 NaN                 NaN             NaN
# 3                NaN                 NaN                 NaN             NaN
# 4                NaN                 NaN                 NaN             NaN
# 5                NaN                 NaN                 NaN             NaN
# 6                NaN                 NaN                 NaN             NaN
# 7                NaN                 NaN                 NaN             NaN
# 8                NaN                 NaN                 NaN             NaN
# 9                NaN                 NaN                 NaN             NaN
# 10               NaN                 NaN                 NaN             NaN
# 11               NaN                 NaN                 NaN             NaN
# 12               NaN                 NaN                 NaN             NaN
# 13               NaN                 NaN                 NaN             NaN
# 14               NaN                 NaN                 NaN             NaN
# 15               NaN                 NaN                 NaN             NaN
# 16               NaN                 NaN                 NaN             NaN
# 17               NaN                 NaN                 NaN             NaN
# 18               NaN                 NaN                 NaN             NaN
# 19               NaN                 NaN                 NaN             NaN
# 20               NaN                 NaN                 NaN             NaN
# 21               NaN                 NaN                 NaN             NaN
# 22               NaN                 NaN                 NaN             NaN
# 23               NaN                 NaN                 NaN             NaN
# 24               NaN                 NaN                 NaN             NaN
# 25               NaN                 NaN                 NaN             NaN
# 26               NaN                 NaN                 NaN             NaN
# 27               NaN                 NaN                 NaN             NaN
# 28               NaN                 NaN                 NaN             NaN
# 29               NaN                 NaN                 NaN             NaN
# 30               NaN                 NaN                 NaN             NaN
# 31               NaN                 NaN                 NaN             NaN
# 32               NaN                 NaN                 NaN             NaN
# 33               NaN                 NaN                 NaN             NaN
# 34               NaN                 NaN                 NaN             NaN
# 35               NaN                 NaN                 NaN             NaN
# 36               NaN                 NaN                 NaN             NaN
# 37               NaN                 NaN                 NaN             NaN
# 38               NaN                 NaN                 NaN             NaN
# 39               NaN                 NaN                 NaN             NaN
# 40               NaN                 NaN                 NaN             NaN
# 41               NaN                 NaN                 NaN             NaN
# 42               NaN                 NaN                 NaN             NaN
# 43               NaN                 NaN                 NaN             NaN
# 44               NaN                 NaN                 NaN             NaN
# 45               NaN                 NaN                 NaN             NaN
# 46               NaN                 NaN                 NaN             NaN
#
#    Delivery_State Delivery_Postcode Delivery_Customisable_Value  \
# 0             NaN               NaN                         NaN
# 1             NaN               NaN                         NaN
# 2             NaN               NaN                         NaN
# 3             NaN               NaN                         NaN
# 4             NaN               NaN                         NaN
# 5             NaN               NaN                         NaN
# 6             NaN               NaN                         NaN
# 7             NaN               NaN                         NaN
# 8             NaN               NaN                         NaN
# 9             NaN               NaN                         NaN
# 10            NaN               NaN                         NaN
# 11            NaN               NaN                         NaN
# 12            NaN               NaN                         NaN
# 13            NaN               NaN                         NaN
# 14            NaN               NaN                         NaN
# 15            NaN               NaN                         NaN
# 16            NaN               NaN                         NaN
# 17            NaN               NaN                         NaN
# 18            NaN               NaN                         NaN
# 19            NaN               NaN                         NaN
# 20            NaN               NaN                         NaN
# 21            NaN               NaN                         NaN
# 22            NaN               NaN                         NaN
# 23            NaN               NaN                         NaN
# 24            NaN               NaN                         NaN
# 25            NaN               NaN                         NaN
# 26            NaN               NaN                         NaN
# 27            NaN               NaN                         NaN
# 28            NaN               NaN                         NaN
# 29            NaN               NaN                         NaN
# 30            NaN               NaN                         NaN
# 31            NaN               NaN                         NaN
# 32            NaN               NaN                         NaN
# 33            NaN               NaN                         NaN
# 34            NaN               NaN                         NaN
# 35            NaN               NaN                         NaN
# 36            NaN               NaN                         NaN
# 37            NaN               NaN                         NaN
# 38            NaN               NaN                         NaN
# 39            NaN               NaN                         NaN
# 40            NaN               NaN                         NaN
# 41            NaN               NaN                         NaN
# 42            NaN               NaN                         NaN
# 43            NaN               NaN                         NaN
# 44            NaN               NaN                         NaN
# 45            NaN               NaN                         NaN
# 46            NaN               NaN                         NaN
#
#    Delivery_Address2
# 0                NaN
# 1                NaN
# 2                NaN
# 3                NaN
# 4                NaN
# 5                NaN
# 6                NaN
# 7                NaN
# 8                NaN
# 9                NaN
# 10               NaN
# 11               NaN
# 12               NaN
# 13               NaN
# 14               NaN
# 15               NaN
# 16               NaN
# 17               NaN
# 18               NaN
# 19               NaN
# 20               NaN
# 21               NaN
# 22               NaN
# 23               NaN
# 24               NaN
# 25               NaN
# 26               NaN
# 27               NaN
# 28               NaN
# 29               NaN
# 30               NaN
# 31               NaN
# 32               NaN
# 33               NaN
# 34               NaN
# 35               NaN
# 36               NaN
# 37               NaN
# 38               NaN
# 39               NaN
# 40               NaN
# 41               NaN
# 42               NaN
# 43               NaN
# 44               NaN
# 45               NaN
# 46               NaN
#
# [47 rows x 22 columns]

# %% [markdown]
# #### Post Code, State and Suburb

# %%
# testing if there's any row not in the pattern

error_reason = ''


for index, row in df2.iterrows():
    
    customer_ID = row['ID']
    
    ## attention with the ID 7112
    
    parts = row['Billing_Address'].strip('_').strip('.').split('_') # spliting the string by _ that represents a line break
    
    #tests if the lenght of the Billing address is less than 2 lines, if yes, the address is not complete and it skips the rest of the code
    
    if len(parts) < 2:
        Billing_IDs_To_Exclude.append(customer_ID)
        error_reason += 'Address is not complete. It should have at least 2 lines!\n'
        
        new_line = pd.DataFrame.from_records([{'Customer_Code': row['Customer_Code'],
                                                    'ID': customer_ID,
                                                    'Billing_Address': row['Billing_Address'].replace("_", "\n"),
                                                    'Billing Error Type': error_reason
                        }])
        
        Billing_Error_Report = pd.concat([Billing_Error_Report, new_line],ignore_index=True)
        
        error_reason = ''
        
        continue
        
    # if no, it tests if the last line, which should be the suburb details, have at least 3 elements, if yes, it gets the state and the code continues
    # case it's less than 3 elements, it skips the rest of the code 
        
    else:
    
        suburb_details = parts[-1].split() # the last part is usually where the Suburb, post code and state are 
        
        if len(suburb_details) > 2:
            state = suburb_details[-2].upper().strip(',').strip('`').strip('.')
        else:
            # Handle the case when the length is less than 3
            state = ''
            error_reason += 'Wrong Format. Please make sure the format looks like:\n{Address1}\n{Address2}\n{StreetNumber} {StreetName} {StreetType}\n{Suburb} {State} {Postcode}\n'
            Billing_IDs_To_Exclude.append(customer_ID)
            
            new_line = pd.DataFrame.from_records([{'Customer_Code': row['Customer_Code'],
                                                    'ID': customer_ID,
                                                    'Billing_Address': row['Billing_Address'].replace("_", "\n"),
                                                    'Billing Error Type': error_reason
                        }])
            
            Billing_Error_Report = pd.concat([Billing_Error_Report, new_line],ignore_index=True)
        
            error_reason = ''
        
            continue
            
           #----------------------------------------------------------------------------------------------------------------------------------------------------------# 
            

        post_code = suburb_details[-1].strip(',').strip('`').strip().strip('.') # the post code is normally the last word in the last line

        suburb = ' '.join(suburb_details[:-2]).upper().strip(',').strip('.') # suburb is the rest, it can be 2 or more words, so we join them with a space

        # Check if the post_code looks like 4 numbers
        is_post_code_valid = re.match(r'^\d{4}$', post_code) is not None

        # Check if the state looks like 3 or 2 letters
        is_state_valid = re.match(r'^[A-Za-z]{2,3}$', state) is not None
        
    
        keywords_to_exclude = ['Locked Bag', 'PO BOX', 'P.O. BOX', 'P.O BOX', 'P O Box', 'Private Bag']
            
        if any(keyword.upper() in suburb for keyword in keywords_to_exclude):
            Billing_IDs_To_Exclude.append(customer_ID)
            error_reason += 'Suburb contains address info.'
        
        if is_post_code_valid == False:
            
            Billing_IDs_To_Exclude.append(customer_ID)
            if isinstance(post_code, int):
                error_reason += 'Postcode invalid. It should be 4 numbers.\n'
                Billing_IDs_To_Exclude.append(customer_ID)
                
                
            if not any(re.match(r'^\d{4}$', str(item)) is not None for item in suburb_details):
                error_reason += 'Postcode Missing.\n'
                Billing_IDs_To_Exclude.append(customer_ID)
                
                if not any(state in suburb_details for state in states):
                    error_reason += 'State Missing.\n'
                    
                    
                new_line = pd.DataFrame.from_records([{'Customer_Code': row['Customer_Code'],
                                                        'ID': customer_ID,
                                                        'Billing_Address': row['Billing_Address'].replace("_", "\n"),
                                                        'Billing Error Type': error_reason
                            }])

                Billing_Error_Report = pd.concat([Billing_Error_Report, new_line],ignore_index=True)

                error_reason = ''
                
                continue

                
            else:
                
                if not any(state in suburb_details for state in states):
                    error_reason += 'State Missing.\n'
                    Billing_IDs_To_Exclude.append(customer_ID)
                    
                    new_line = pd.DataFrame.from_records([{'Customer_Code': row['Customer_Code'],
                                                    'ID': customer_ID,
                                                    'Billing_Address': row['Billing_Address'].replace("_", "\n"),
                                                    'Billing Error Type': error_reason
                        }])
            
                    Billing_Error_Report = pd.concat([Billing_Error_Report, new_line],ignore_index=True)
                
                    error_reason = ''
                    
                    continue
                else:
                    error_reason += 'Wrong Format. Please make sure the format looks like:\n{Address1}\n{Address2}\n{StreetNumber} {StreetName} {StreetType}\n{Suburb} {State} {Postcode}\n'
                    Billing_IDs_To_Exclude.append(customer_ID)
                    
                    new_line = pd.DataFrame.from_records([{'Customer_Code': row['Customer_Code'],
                                                    'ID': customer_ID,
                                                    'Billing_Address': row['Billing_Address'].replace("_", "\n"),
                                                    'Billing Error Type': error_reason
                        }])
            
                    Billing_Error_Report = pd.concat([Billing_Error_Report, new_line],ignore_index=True)
                
                    error_reason = ''
                    
                    continue
                    
                    
        
        if is_state_valid == False:
            if not any(state in suburb_details for state in states):
                error_reason += 'State Missing.\n'
                Billing_IDs_To_Exclude.append(customer_ID)
            else:
                Billing_IDs_To_Exclude.append(customer_ID)
                error_reason += 'State invalid. It should be 2 or 3 characters.\n'
            
        
        if suburb == '':
            error_reason += 'Suburb is Missing.'
            Billing_IDs_To_Exclude.append(customer_ID)
        
            
        if is_post_code_valid is False or is_state_valid is False or suburb == '' or any(keyword.upper() in suburb for keyword in keywords_to_exclude):
            new_line = pd.DataFrame.from_records([{'Customer_Code': row['Customer_Code'],
                                                    'ID': customer_ID,
                                                    'Billing_Address': row['Billing_Address'].replace("_", "\n"),
                                                    'Billing Error Type': error_reason
                        }])
            
            Billing_Error_Report = pd.concat([Billing_Error_Report, new_line],ignore_index=True)
                
        error_reason = ''

# %%
# Firt, we separate the Suburb, Post Code and State and put them into the new dataset

# The pattern we are looking for is: Condell Park NSW 2200 (Suburb State Post Code)

for index, row in df2.iterrows():
    
    customer_ID = row['ID']
    
    if customer_ID in Billing_IDs_To_Exclude:
        continue
        
    else:
    
        parts = row['Billing_Address'].strip('_').strip('.').split('_') # spliting the string by _ that represents a line break

        suburb_details = parts[-1].split() # the last part is usually where the Suburb, post code and state are 

        post_code = suburb_details[-1].strip(',').strip('`').strip().strip('.') # the post code is normally the last word in the last line

        state = suburb_details[-2].upper().strip(',').strip('`').strip('.') # the state is normally the second to last

        suburb = ' '.join(suburb_details[:-2]).upper().strip(',').strip('.') # suburb is the rest, it can be 2 or more words, so we join them with a space

        billing_second_group.loc[billing_second_group['ID'] == customer_ID, 'Billing_Postcode'] = post_code
        billing_second_group.loc[billing_second_group['ID'] == customer_ID, 'Billing_State'] = state
        billing_second_group.loc[billing_second_group['ID'] == customer_ID, 'Billing_Suburb'] = suburb

# %% [markdown]
# #### Billing Address 2
#
# It was the billing address 2 the field that would receive the values, but after some problems in converting quotes in Salesforce, this field was changed to Billing_StreetName.
#
# Reffer to this change in the TASK# 002370 - Split Billing Address - PO Box Cases (Baseplan)

# %%
for index, row in df2.iterrows():
    
    customer_ID = row['ID']
    
    if customer_ID in Billing_IDs_To_Exclude:
        continue
        
    else:
    
        parts = row['Billing_Address'].strip('_').strip('.').split('_') # spliting the string by _ that represents a line break

        trading_as = []
        adress2 = []
        streetname = []

        for part in parts[:-1]:
                if part.lower().startswith("t/a") or part.lower().startswith("t/as"):
                    trading_as.append(part.strip().strip(',').strip('.'))
                elif re.search(r'\bbox\b|\bbag\b', part, re.IGNORECASE):
                    streetname.append(part.strip().strip(',').strip('.'))
                else:                       
                    adress2.append(part.strip().strip(',').strip('.'))

        if len(adress2) > 0:
            billing_address2 = '\n'.join(adress2) # geting the second group of the split
            billing_address2 = billing_address2.strip('\n').strip().strip(',').strip('.')
            billing_second_group.loc[billing_second_group['ID'] == customer_ID, 'Billing_Address2'] = billing_address2
        
        if len(streetname) > 0:
            streetName = '\n'.join(streetname) # geting the second group of the split
            streetName.strip('\n').strip().strip(',').strip('.')            
            billing_second_group.loc[billing_second_group['ID'] == customer_ID, 'Billing_StreetName'] = streetname

        if len(trading_as) > 0:
            billing_ta = '\n'.join(trading_as)
            billing_ta = billing_ta.strip('\n').strip().strip(',').strip('.')
            billing_second_group.loc[billing_second_group['ID'] == customer_ID, 'Billing_Customisable_Value'] = billing_ta
            billing_ta = None

# %% [markdown]
# #### Updating the Billing Address

# %%
for index, row in df2.iterrows():
    
    customer_ID = row['ID']
    
    if customer_ID in Billing_IDs_To_Exclude:
        continue
        
    else:
    
        parts = row['Billing_Address'].strip('_').strip('.').split('_') # spliting the string by _ that represents a line break

        suburb_details = parts[-1].split() # the last part is usually where the Suburb, post code and state are

        post_code = suburb_details[-1].strip('.') # the post code is normally the last word in the last line

        state = suburb_details[-2].upper() # the state is normally the second to last

        suburb = ' '.join(suburb_details[:-2]).upper().strip(',').strip('.') # suburb is the rest, it can be 2 or more words, so we join them with a space

        billing_address = '\n'.join(parts[:-1])

        billing_address += f'\n{suburb} {state} {post_code}'

        billing_second_group.loc[billing_second_group['ID'] == customer_ID, 'Billing_Address'] = billing_address

# %%
billing_second_group = billing_second_group[~billing_second_group['ID'].isin(Billing_IDs_To_Exclude)]

billing_second_group
# Out:
#                  Customer_Code     ID Billing_ADR_Address_ID  \
# 1               PBPHYIPLUMBING  11405                    NaN
# 2        9WAHBNWPXZENGINEERING  11289                    NaN
# 3     9EMKTVVGFJZXYUNWBUILDING  10999                    NaN
# 4                       9BGRBF  10677                    NaN
# 9               TAXPTQPROJECTS   9625                    NaN
# 10        ZWWGFVULCXOHSERVICES   9384                    NaN
# 11            FOSTLYRCPROJECTS   8954                    NaN
# 13  LDONRWFLJVQKZQCONSTRUCTION   8683                    NaN
# 20       UECRDNBBAYENGINEERING   6935                    NaN
# 22               NYULZQAGEEKPY   6519                    NaN
# 23           LYOCOCONSTRUCTION   6411                    NaN
# 25                  9YEGUROKLO   6253                    NaN
# 27              UNDHWRBUILDING   4795                    NaN
# 29               9HKLCDEYVTKQH   4511                    NaN
# 30          ZLAAIUQSPLPLUMBING   4295                    NaN
# 36            9FLRFUSTPLUMBING   2819                    NaN
# 37            9DIGMGHGQMYGROUP   2520                    NaN
# 38      DDBAQOQJYAWENGINEERING   2420                    NaN
# 40                     JBRZQUZ   2349                    NaN
# 41        HMBDANGVUTNHPROJECTS   2157                    NaN
# 43                VFFWJPWIHRHT   1859                    NaN
# 46             PKHRMIJPROJECTS    439                    NaN
#
#                                       Billing_Address Billing_StreetNo  \
# 1                   PO Box 5485 \nWOLLONGONG NSW 2520              NaN
# 2                PO Box 1161 \nMOUNTAIN GATE VIC 3165              NaN
# 3   T/As Odyssey Constructions & Fitout\nPO Box 71...              NaN
# 4    PO BOX 13268\nGeorge Street\nQUEENSLAND QLD 4003              NaN
# 9   Engineering Pty Ltd T/As CPB Ghella UGL JV\nAt...              NaN
# 10                         PO Box 86\nPOORAKA SA 5095              NaN
# 11                PO Box 567\nCARINA HEIGHTS QLD 4152              NaN
# 13  Laing O'Rourke Australia Group Pty Ltd\nAccoun...              NaN
# 20                        PO Box 3355\nDARRA QLD 4076              NaN
# 22                   P.O Box 1410\nBEENLEIGH QLD 4207              NaN
# 23  Engineering P/L, Persal & Co Trading P/L , Per...              NaN
# 25                    PO Box 4337\nPITTWATER NSW 2756              NaN
# 27                     PO Box 3346\nRICHMOND VIC 3121              NaN
# 29                     PO Box 3110\nLANSVALE NSW 2166              NaN
# 30                      PO Box 687\nGISBORNE VIC 3437              NaN
# 36                    PO Box 919\nPARRAMATTA NSW 2150              NaN
# 37               PO Box 6924\nBAULKHAM HILLS NSW 2153              NaN
# 38  Technical & Further Education Commission\nAcco...              NaN
# 40                  PO Box 16151\nNORTHPOINT QLD 4350              NaN
# 41                     GPO Box 399\nBRISBANE QLD 4001              NaN
# 43                    PO Box 2250\nNIIRABBUB VIC 3189              NaN
# 46  PO Box 58\n'Claim for Payment'\nGLEN INNES NSW...              NaN
#
#    Billing_StreetName Billing_StreetType     Billing_Suburb Billing_State  \
# 1         PO Box 5485                NaN         WOLLONGONG           NSW
# 2         PO Box 1161                NaN      MOUNTAIN GATE           VIC
# 3         PO Box 7179                NaN  WETHERILL PARK BC           NSW
# 4        PO BOX 13268                NaN         QUEENSLAND           QLD
# 9         PO Box 7261                NaN         ALEXANDRIA           NSW
# 10          PO Box 86                NaN            POORAKA            SA
# 11         PO Box 567                NaN     CARINA HEIGHTS           QLD
# 13       GPO Box 5094                NaN           BRISBANE           QLD
# 20        PO Box 3355                NaN              DARRA           QLD
# 22       P.O Box 1410                NaN          BEENLEIGH           QLD
# 23         PO Box 494                NaN         HERVEY BAY           QLD
# 25        PO Box 4337                NaN          PITTWATER           NSW
# 27        PO Box 3346                NaN           RICHMOND           VIC
# 29        PO Box 3110                NaN           LANSVALE           NSW
# 30         PO Box 687                NaN           GISBORNE           VIC
# 36         PO Box 919                NaN         PARRAMATTA           NSW
# 37        PO Box 6924                NaN     BAULKHAM HILLS           NSW
# 38       GPO Box 4037                NaN             SYDNEY           NSW
# 40       PO Box 16151                NaN         NORTHPOINT           QLD
# 41        GPO Box 399                NaN           BRISBANE           QLD
# 43        PO Box 2250                NaN          NIIRABBUB           VIC
# 46          PO Box 58                NaN         GLEN INNES           NSW
#
#    Billing_Postcode  ... Delivery_ADR_Address_ID Delivery_Address  \
# 1              2520  ...                     NaN              NaN
# 2              3165  ...                     NaN              NaN
# 3              2164  ...                     NaN              NaN
# 4              4003  ...                     NaN              NaN
# 9              2016  ...                     NaN              NaN
# 10             5095  ...                     NaN              NaN
# 11             4152  ...                     NaN              NaN
# 13             4001  ...                     NaN              NaN
# 20             4076  ...                     NaN              NaN
# 22             4207  ...                     NaN              NaN
# 23             4655  ...                     NaN              NaN
# 25             2756  ...                     NaN              NaN
# 27             3121  ...                     NaN              NaN
# 29             2166  ...                     NaN              NaN
# 30             3437  ...                     NaN              NaN
# 36             2150  ...                     NaN              NaN
# 37             2153  ...                     NaN              NaN
# 38             2001  ...                     NaN              NaN
# 40             4350  ...                     NaN              NaN
# 41             4001  ...                     NaN              NaN
# 43             3189  ...                     NaN              NaN
# 46             2370  ...                     NaN              NaN
#
#    Delivery_StreetNo Delivery_StreetName Delivery_StreetType Delivery_Suburb  \
# 1                NaN                 NaN                 NaN             NaN
# 2                NaN                 NaN                 NaN             NaN
# 3                NaN                 NaN                 NaN             NaN
# 4                NaN                 NaN                 NaN             NaN
# 9                NaN                 NaN                 NaN             NaN
# 10               NaN                 NaN                 NaN             NaN
# 11               NaN                 NaN                 NaN             NaN
# 13               NaN                 NaN                 NaN             NaN
# 20               NaN                 NaN                 NaN             NaN
# 22               NaN                 NaN                 NaN             NaN
# 23               NaN                 NaN                 NaN             NaN
# 25               NaN                 NaN                 NaN             NaN
# 27               NaN                 NaN                 NaN             NaN
# 29               NaN                 NaN                 NaN             NaN
# 30               NaN                 NaN                 NaN             NaN
# 36               NaN                 NaN                 NaN             NaN
# 37               NaN                 NaN                 NaN             NaN
# 38               NaN                 NaN                 NaN             NaN
# 40               NaN                 NaN                 NaN             NaN
# 41               NaN                 NaN                 NaN             NaN
# 43               NaN                 NaN                 NaN             NaN
# 46               NaN                 NaN                 NaN             NaN
#
#    Delivery_State Delivery_Postcode Delivery_Customisable_Value  \
# 1             NaN               NaN                         NaN
# 2             NaN               NaN                         NaN
# 3             NaN               NaN                         NaN
# 4             NaN               NaN                         NaN
# 9             NaN               NaN                         NaN
# 10            NaN               NaN                         NaN
# 11            NaN               NaN                         NaN
# 13            NaN               NaN                         NaN
# 20            NaN               NaN                         NaN
# 22            NaN               NaN                         NaN
# 23            NaN               NaN                         NaN
# 25            NaN               NaN                         NaN
# 27            NaN               NaN                         NaN
# 29            NaN               NaN                         NaN
# 30            NaN               NaN                         NaN
# 36            NaN               NaN                         NaN
# 37            NaN               NaN                         NaN
# 38            NaN               NaN                         NaN
# 40            NaN               NaN                         NaN
# 41            NaN               NaN                         NaN
# 43            NaN               NaN                         NaN
# 46            NaN               NaN                         NaN
#
#    Delivery_Address2
# 1                NaN
# 2                NaN
# 3                NaN
# 4                NaN
# 9                NaN
# 10               NaN
# 11               NaN
# 13               NaN
# 20               NaN
# 22               NaN
# 23               NaN
# 25               NaN
# 27               NaN
# 29               NaN
# 30               NaN
# 36               NaN
# 37               NaN
# 38               NaN
# 40               NaN
# 41               NaN
# 43               NaN
# 46               NaN
#
# [22 rows x 22 columns]

# %% [markdown]
# ## Delivery Address
#
# ### First Group: the standard data

# %%
# Establish the connection with Windows authentication

#conn = pyodbc.connect(
#    f'DRIVER=ODBC Driver 17 for SQL Server;SERVER={server};DATABASE={database};UID={username};PWD={password};'
#)

# Create a cursor object to interact with the database
#cursor = conn.cursor()


select_delivery_first = f"""

WITH UpdateSelection AS (

SELECT DISTINCT [Source_Id]
FROM [sample_database].[dbo].[VA_DBT_Master]
WHERE [Audited_Field] IN ('Delivery_Address') 
AND Operation IN ('U', 'I') 
AND Audit_DateTime > '{last_finish_date}' 
AND Audit_User NOT LIKE 'TableauAdminAccess'

AND [After_Value] IS NOT NULL AND [After_Value] NOT LIKE 'TBA%' AND NOT

([After_Value]  LIKE '%Locked Bag%' OR [After_Value] LIKE '%PO BOX%' OR [After_Value] LIKE '%P.O. BOX%' OR [After_Value] LIKE '%P.O BOX%'
 OR [After_Value] LIKE '%P O Box%' OR [After_Value] LIKE '%Private Bag%')

)

SELECT     
    [Customer_Code],
    [ID],
    REPLACE([Delivery_Address],CHAR(13)+CHAR(10),'_') AS [Delivery_Address]
FROM [sample_database].[dbo].[DBT_Master]

WHERE 

[Delivery_Address] IS NOT NULL AND [Delivery_Address] NOT LIKE 'TBA%' AND NOT

([Delivery_Address]  LIKE '%Locked Bag%' OR [Delivery_Address] LIKE '%PO BOX%' OR [Delivery_Address] LIKE '%P.O. BOX%' OR [Delivery_Address] LIKE '%P.O BOX%'
 OR [Delivery_Address] LIKE '%P O Box%' OR [Delivery_Address] LIKE '%Private Bag%')

AND [ID] IN (SELECT DISTINCT [Source_Id]
            FROM UpdateSelection)
                    
"""

#df3 = pd.read_sql_query(select_delivery_first, conn)

#cursor.close()
#conn.close()

df3 = pd.read_excel("Delivery Address.xlsx")

df3
# Out:
#             Customer_Code     ID  \
# 0    PORTADELAIDECONSTRUC  11669
# 1        9CRONULLAFERRIES  11660
# 2          9AMTGRANDHOMES  11551
# 3                9BLUZONE  11505
# 4                  9HPOTS  11503
# ..                    ...    ...
# 215        9JECCONCRETING    160
# 216           9GROUPACONS    145
# 217         9FORMPROJECTS    136
# 218         9BUILDABILITY     71
# 219           9AGEMACONST     15
#
#                                       Delivery_Address
# 0           Cnr Jetty & Elder Road_Largs North SA 5016
# 1        Public Wharf, Tonkin Street_Cronulla NSW 2230
# 2    Suite 4, Level 1, 374 Church Street _Parramatt...
# 3    Suite 802, Level 8, 24 Montgomery Street _Koga...
# 4          McFarlane Street Extended_Cessnock NSW 2325
# ..                                                 ...
# 215                        27 Telopea Street_Punchbowl
# 216                   15 Erang Street _CARSS PARK 2221
# 217                   Bells Line Road_Kurmond NSW 2757
# 218                         108/55 Jones Street_ULTIMO
# 219            Unit 2, 89 Derby Street_Silverwater NSW
#
# [220 rows x 3 columns]

# %%
delivery_first_group = pd.DataFrame(columns=columns)

delivery_first_group['Customer_Code'] = df3['Customer_Code']
delivery_first_group['ID'] = df3['ID']
delivery_first_group['Delivery_Address'] = df3['Delivery_Address']

delivery_first_group
# Out:
#             Customer_Code     ID Billing_ADR_Address_ID Billing_Address  \
# 0    PORTADELAIDECONSTRUC  11669                    NaN             NaN
# 1        9CRONULLAFERRIES  11660                    NaN             NaN
# 2          9AMTGRANDHOMES  11551                    NaN             NaN
# 3                9BLUZONE  11505                    NaN             NaN
# 4                  9HPOTS  11503                    NaN             NaN
# ..                    ...    ...                    ...             ...
# 215        9JECCONCRETING    160                    NaN             NaN
# 216           9GROUPACONS    145                    NaN             NaN
# 217         9FORMPROJECTS    136                    NaN             NaN
# 218         9BUILDABILITY     71                    NaN             NaN
# 219           9AGEMACONST     15                    NaN             NaN
#
#     Billing_StreetNo Billing_StreetName Billing_StreetType Billing_Suburb  \
# 0                NaN                NaN                NaN            NaN
# 1                NaN                NaN                NaN            NaN
# 2                NaN                NaN                NaN            NaN
# 3                NaN                NaN                NaN            NaN
# 4                NaN                NaN                NaN            NaN
# ..               ...                ...                ...            ...
# 215              NaN                NaN                NaN            NaN
# 216              NaN                NaN                NaN            NaN
# 217              NaN                NaN                NaN            NaN
# 218              NaN                NaN                NaN            NaN
# 219              NaN                NaN                NaN            NaN
#
#     Billing_State Billing_Postcode  ... Delivery_ADR_Address_ID  \
# 0             NaN              NaN  ...                     NaN
# 1             NaN              NaN  ...                     NaN
# 2             NaN              NaN  ...                     NaN
# 3             NaN              NaN  ...                     NaN
# 4             NaN              NaN  ...                     NaN
# ..            ...              ...  ...                     ...
# 215           NaN              NaN  ...                     NaN
# 216           NaN              NaN  ...                     NaN
# 217           NaN              NaN  ...                     NaN
# 218           NaN              NaN  ...                     NaN
# 219           NaN              NaN  ...                     NaN
#
#                                       Delivery_Address Delivery_StreetNo  \
# 0           Cnr Jetty & Elder Road_Largs North SA 5016               NaN
# 1        Public Wharf, Tonkin Street_Cronulla NSW 2230               NaN
# 2    Suite 4, Level 1, 374 Church Street _Parramatt...               NaN
# 3    Suite 802, Level 8, 24 Montgomery Street _Koga...               NaN
# 4          McFarlane Street Extended_Cessnock NSW 2325               NaN
# ..                                                 ...               ...
# 215                        27 Telopea Street_Punchbowl               NaN
# 216                   15 Erang Street _CARSS PARK 2221               NaN
# 217                   Bells Line Road_Kurmond NSW 2757               NaN
# 218                         108/55 Jones Street_ULTIMO               NaN
# 219            Unit 2, 89 Derby Street_Silverwater NSW               NaN
#
#     Delivery_StreetName Delivery_StreetType Delivery_Suburb Delivery_State  \
# 0                   NaN                 NaN             NaN            NaN
# 1                   NaN                 NaN             NaN            NaN
# 2                   NaN                 NaN             NaN            NaN
# 3                   NaN                 NaN             NaN            NaN
# 4                   NaN                 NaN             NaN            NaN
# ..                  ...                 ...             ...            ...
# 215                 NaN                 NaN             NaN            NaN
# 216                 NaN                 NaN             NaN            NaN
# 217                 NaN                 NaN             NaN            NaN
# 218                 NaN                 NaN             NaN            NaN
# 219                 NaN                 NaN             NaN            NaN
#
#     Delivery_Postcode Delivery_Customisable_Value Delivery_Address2
# 0                 NaN                         NaN               NaN
# 1                 NaN                         NaN               NaN
# 2                 NaN                         NaN               NaN
# 3                 NaN                         NaN               NaN
# 4                 NaN                         NaN               NaN
# ..                ...                         ...               ...
# 215               NaN                         NaN               NaN
# 216               NaN                         NaN               NaN
# 217               NaN                         NaN               NaN
# 218               NaN                         NaN               NaN
# 219               NaN                         NaN               NaN
#
# [220 rows x 22 columns]

# %% [markdown]
# #### Post Code, State and Suburb

# %%
# testing if there's any row not in the pattern

Delivery_IDs_To_Exclude = []

error_reason = ''

for index, row in df3.iterrows():
    
    customer_ID = row['ID']
    
    parts = str(row['Delivery_Address']).strip('_').strip('.').split('_') # spliting the string by _ that represents a line break
    
    
    #tests if the lenght of the Billing address is less than 2 lines, if yes, the address is not complete and it skips the rest of the code

    if len(parts) < 2:
        Delivery_IDs_To_Exclude.append(customer_ID)
        error_reason += 'Address is not complete. It should have at least 2 lines!\n'
        
        new_line = pd.DataFrame.from_records([{'Customer_Code': row['Customer_Code'],
                                                    'ID': customer_ID,
                                                    'Delivery_Address': row['Delivery_Address'].replace("_", "\n"),
                                                    'Delivery Error Type': error_reason
                        }])
        
        Delivery_Error_Report = pd.concat([Delivery_Error_Report, new_line],ignore_index=True)
        
        error_reason = ''
        
        continue
        
    else:
    
        suburb_details = parts[-1].split() # the last part is usually where the Suburb, post code and state are
        
        if len(suburb_details) >= 2:
            state = suburb_details[-2].upper().strip(',').strip('`').strip('.') # the state is normally the second to last
        else:
            # Handle the case when the length is less than 2
            state = ''
            error_reason += 'Wrong Format. Please make sure the format looks like:\n{Address1}\n{Address2}\n{StreetNumber} {StreetName} {StreetType}\n{Suburb} {State} {Postcode}\n'
            Delivery_IDs_To_Exclude.append(customer_ID)
            
            new_line = pd.DataFrame.from_records([{'Customer_Code': row['Customer_Code'],
                                                    'ID': customer_ID,
                                                    'Delivery_Address': row['Delivery_Address'].replace("_", "\n"),
                                                    'Delivery Error Type': error_reason
                        }])
            
            Delivery_Error_Report = pd.concat([Delivery_Error_Report, new_line],ignore_index=True)
        
            error_reason = ''
        
            continue
            
           #----------------------------------------------------------------------------------------------------------------------------------------------------------# 

        post_code = suburb_details[-1].strip(',').strip('`').strip().strip('.').strip('.') # the post code is normally the last word in the last line

        suburb = ' '.join(suburb_details[:-2]).upper().strip(',').strip('.') # suburb is the rest, it can be 2 or more words, so we join them with a space

        # Check if the post_code looks like 4 numbers
        is_post_code_valid = re.match(r'^\d{4}$', post_code) is not None

        # Check if the state looks like 3 or 2 letters
        is_state_valid = re.match(r'^[A-Za-z]{2,3}$', state) is not None
        
            
        if is_post_code_valid == False:
            if isinstance(post_code, int):
                error_reason += 'Postcode invalid. It should be 4 numbers.\n'
                Delivery_IDs_To_Exclude.append(customer_ID)
                
                
            if not any(re.match(r'^\d{4}$', str(item)) is not None for item in suburb_details):
                error_reason += 'Postcode Missing.\n'
                Delivery_IDs_To_Exclude.append(customer_ID)
                
                if not any(state in suburb_details for state in states):
                    error_reason += 'State Missing.\n'
                    
                    
                new_line = pd.DataFrame.from_records([{'Customer_Code': row['Customer_Code'],
                                                    'ID': customer_ID,
                                                    'Delivery_Address': row['Delivery_Address'].replace("_", "\n"),
                                                    'Delivery Error Type': error_reason
                        }])
            
                Delivery_Error_Report = pd.concat([Delivery_Error_Report, new_line],ignore_index=True)

                error_reason = ''
                
                continue

                
            else:
                
                if not any(state in suburb_details for state in states):
                    error_reason += 'State Missing.\n'
                    Delivery_IDs_To_Exclude.append(customer_ID)
                    
                    new_line = pd.DataFrame.from_records([{'Customer_Code': row['Customer_Code'],
                                                    'ID': customer_ID,
                                                    'Delivery_Address': row['Delivery_Address'].replace("_", "\n"),
                                                    'Delivery Error Type': error_reason
                        }])
            
                    Delivery_Error_Report = pd.concat([Delivery_Error_Report, new_line],ignore_index=True)

                    error_reason = ''
                    
                    continue
                    
                else:
                    error_reason += 'Wrong Format. Please make sure the format looks like:\n{Address1}\n{Address2}\n{StreetNumber} {StreetName} {StreetType}\n{Suburb} {State} {Postcode}\n'
                    Delivery_IDs_To_Exclude.append(customer_ID)
                    
                    new_line = pd.DataFrame.from_records([{'Customer_Code': row['Customer_Code'],
                                                    'ID': customer_ID,
                                                    'Delivery_Address': row['Delivery_Address'].replace("_", "\n"),
                                                    'Delivery Error Type': error_reason
                        }])
            
                    Delivery_Error_Report = pd.concat([Delivery_Error_Report, new_line],ignore_index=True)

                    error_reason = ''
                    
                    continue
                    
        
        if is_state_valid == False:
            
            if not any(state in suburb_details for state in states):
                error_reason += 'State Missing.\n'
                Delivery_IDs_To_Exclude.append(customer_ID)
            else:
                Delivery_IDs_To_Exclude.append(customer_ID)
                error_reason += 'State invalid. It should be 2 or 3 characters.\n'
                
        
        if suburb == '':
            error_reason += 'Suburb is Missing.'
            Delivery_IDs_To_Exclude.append(customer_ID)
            
            
        if is_post_code_valid is False or is_state_valid is False or suburb == '':
            new_line = pd.DataFrame.from_records([{'Customer_Code': row['Customer_Code'],
                                                    'ID': customer_ID,
                                                    'Delivery_Address': row['Delivery_Address'].replace("_", "\n"),
                                                    'Delivery Error Type': error_reason
                        }])
            
            Delivery_Error_Report = pd.concat([Delivery_Error_Report, new_line],ignore_index=True)
                
        error_reason = ''

# %%
# Firt, we separate the Suburb, Post Code and State and put them into the new dataset

# The pattern we are looking for is: Condell Park NSW 2200 (Suburb State Post Code)

for index, row in df3.iterrows():
    
    customer_ID = row['ID']
    
    if customer_ID in Delivery_IDs_To_Exclude:
        continue
        
    else:
    
        parts = row['Delivery_Address'].strip('_').strip('.').split('_') # spliting the string by _ that represents a line break

        suburb_details = parts[-1].strip('.').split() # the last part is usually where the Suburb, post code and state are 

        post_code = suburb_details[-1].strip(',').strip('`').strip().strip('.') # the post code is normally the last word in the last line

        state = suburb_details[-2].upper().strip(',').strip('`').strip('.') # the state is normally the second to last

        suburb = ' '.join(suburb_details[:-2]).upper().strip(',').strip('.') # suburb is the rest, it can be 2 or more words, so we join them with a space

        delivery_first_group.loc[delivery_first_group['ID'] == customer_ID, 'Delivery_Postcode'] = post_code
        delivery_first_group.loc[delivery_first_group['ID'] == customer_ID, 'Delivery_State'] = state
        delivery_first_group.loc[delivery_first_group['ID'] == customer_ID, 'Delivery_Suburb'] = suburb

# %% [markdown]
# #### Street Number and Street Name

# %%
# testing if the street number is empty, in case it if, it's not in the pattern

error_reason = ''

for index, row in df3.iterrows():
    
    customer_ID = row['ID']
    
    if customer_ID in Delivery_IDs_To_Exclude:
        continue
        
    else:
    
        parts = row['Delivery_Address'].strip('_').strip('.').split('_')

        street_details = parts[-2] # geting the second group of the split

        last_index = find_last_number_index(street_details) # geting the index of the last number, which represents the street number

        street_no = street_details[:last_index+1].strip(',').strip('.') # street no is everything until the index of the last number

        street_name = street_details[last_index+1:] # street name starts right after the last number

        street_name = street_name.strip(',').strip('`').strip().strip('.').title()

        if street_no == '':
            
            if not ("Cnr" in street_details or "Corner" in street_details):
                Delivery_IDs_To_Exclude.append(customer_ID)
                error_reason += 'No street number found!\n'
            else:
                street_no = 'NULL'

        if street_name == '':
            Delivery_IDs_To_Exclude.append(customer_ID)
            error_reason += 'No street name found!\n'


        if street_no == '' or street_name == '':
            new_line = pd.DataFrame.from_records([{'Customer_Code': row['Customer_Code'],
                                                    'ID': customer_ID,
                                                    'Delivery_Address': row['Delivery_Address'].replace("_", "\n"),
                                                    'Delivery Error Type': error_reason
                        }])

            Delivery_Error_Report = pd.concat([Delivery_Error_Report, new_line],ignore_index=True)

        error_reason = ''

# %%
# Second, we get the street detail, that is normally the second group of the split

for index, row in df3.iterrows():
    
    customer_ID = row['ID']
    
    if customer_ID in Delivery_IDs_To_Exclude:
        continue
        
    else:
    
        parts = row['Delivery_Address'].strip('_').strip('.').split('_')

        street_details = parts[-2] # geting the second group of the split

        last_index = find_last_number_index(street_details) # geting the index of the last number, which represents the street number

        street_no = street_details[:last_index+1].strip(',').strip('.') # street no is everything until the index of the last number

        street_name = street_details[last_index+1:] # street name starts right after the last number

        street_name = street_name.strip(',').strip('`').strip().strip('.')

        delivery_first_group.loc[delivery_first_group['ID'] == customer_ID, 'Delivery_StreetNo'] = street_no
        delivery_first_group.loc[delivery_first_group['ID'] == customer_ID, 'Delivery_StreetName'] = street_name

# %% [markdown]
# #### Billing Address 2

# %%
# Third, we get what we have in the tird group for those who have something and put in the Billing Address 2 column
for index, row in df3.iterrows():
    
    customer_ID = row['ID']
    
    if customer_ID in Delivery_IDs_To_Exclude:
        continue
        
    else:
    
        parts = row['Delivery_Address'].strip('_').strip('.').split('_')

        trading_as = []
        adress2 = []

        if len(parts) > 2:

            for part in parts[:-2]:
                if part.lower().startswith("t/a") or part.lower().startswith("t/as"):
                    trading_as.append(part.strip().strip(',').strip('.'))
                else:
                    adress2.append(part.strip().strip(',').strip('.'))


            if len(adress2) > 0:
                delivery_address2 = '\n'.join(adress2) # geting the second group of the split
                delivery_address2 = delivery_address2.strip('\n').strip('.')
                delivery_first_group.loc[delivery_first_group['ID'] == customer_ID, 'Delivery_Address2'] = delivery_address2

            if len(trading_as) > 0:
                delivery_ta = '\n'.join(trading_as)
                delivery_ta = delivery_ta.strip().strip(',')
                delivery_first_group.loc[delivery_first_group['ID'] == customer_ID, 'Delivery_Customisable_Value'] = delivery_ta
                delivery_ta = None

# %% [markdown]
# #### Updating the Delivery Address

# %%
for index, row in df3.iterrows():
    
    customer_ID = row['ID']
    
    if customer_ID in Delivery_IDs_To_Exclude:
        continue
        
    else:
    
        parts = row['Delivery_Address'].strip('_').strip('.').split('_') # spliting the string by _ that represents a line break

        suburb_details = parts[-1].split() # the last part is usually where the Suburb, post code and state are 

        post_code = suburb_details[-1].strip().strip(',').strip('.') # the post code is normally the last word in the last line

        state = suburb_details[-2].upper().strip().strip(',').strip('.') # the state is normally the second to last

        suburb = ' '.join(suburb_details[:-2]).upper().strip(',').strip('.') # suburb is the rest, it can be 2 or more words, so we join them with a space

        delivery_address = '\n'.join(parts[:-1])

        delivery_address += f'\n{suburb} {state} {post_code}'

        delivery_first_group.loc[delivery_first_group['ID'] == customer_ID, 'Delivery_Address'] = delivery_address

# %%
delivery_first_group = delivery_first_group[~delivery_first_group['ID'].isin(Delivery_IDs_To_Exclude)]

delivery_first_group[['Customer_Code', 'ID', 'Delivery_Address', 'Delivery_Customisable_Value']]
# Out:
#             Customer_Code     ID  \
# 0    PORTADELAIDECONSTRUC  11669
# 2          9AMTGRANDHOMES  11551
# 3                9BLUZONE  11505
# 7        9PORTWARATAHCOAL  11486
# 15            9KNOWITCONS  11426
# ..                    ...    ...
# 200             BROADCAST    596
# 202            BALLYHOOLY    554
# 206                  ICMP    371
# 209             9QUACKHOU    327
# 210     DEPTOFTRANSNERANG    298
#
#                                       Delivery_Address  \
# 0          Cnr Jetty & Elder Road\nLARGS NORTH SA 5016
# 2    Suite 4, Level 1, 374 Church Street \nPARRAMAT...
# 3    Suite 802, Level 8, 24 Montgomery Street \nKOG...
# 7    Cnr Port Waratah Drive and Elizabeth Street\nC...
# 15            4/32 Liney Avenue\nCLEMTON PARK NSW 2206
# ..                                                 ...
# 200  C/-Broadcast Australia Transmitting Station\nF...
# 202          2388 Silverdale Road\nSILVERDALE NSW 2752
# 206    Cnr Jones Bay & Pirrama Roads\nPYRMONT NSW 2009
# 209  Cnr Stockton & Dredge Avenues\nMOOREBANK NSW 2170
# 210  Ground Floor, Coombabah Depot\n186/200 Banyula...
#
#     Delivery_Customisable_Value
# 0                           NaN
# 2                           NaN
# 3                           NaN
# 7                           NaN
# 15                          NaN
# ..                          ...
# 200                         NaN
# 202                         NaN
# 206                         NaN
# 209                         NaN
# 210                         NaN
#
# [111 rows x 4 columns]

# %% [markdown]
# ### Second Group: PO Box and Locked Bag

# %%
# Establish the connection with Windows authentication

#conn = pyodbc.connect(
#    f'DRIVER=ODBC Driver 17 for SQL Server;SERVER={server};DATABASE={database};UID={username};PWD={password};'
#)

# Create a cursor object to interact with the database

#cursor = conn.cursor()


select_delivery_second = f"""

WITH UpdateSelection AS (

SELECT DISTINCT [Source_Id]
FROM [sample_database].[dbo].[VA_DBT_Master]
WHERE [Audited_Field] IN ('Delivery_Address') 
AND Operation IN ('U', 'I')
AND Audit_DateTime > '{last_finish_date}'
AND Audit_User NOT LIKE 'TableauAdminAccess'

AND [After_Value] IS NOT NULL AND [After_Value] NOT LIKE 'TBA%' AND

([After_Value]  LIKE '%Locked Bag%' OR [After_Value] LIKE '%PO BOX%' OR [After_Value] LIKE '%P.O. BOX%' OR [After_Value] LIKE '%P.O BOX%'
 OR [After_Value] LIKE '%P O Box%' OR [After_Value] LIKE '%Private Bag%')

)

SELECT     
    [Customer_Code],
    [ID],
    REPLACE([Delivery_Address],CHAR(13)+CHAR(10),'_') AS [Delivery_Address]
FROM [sample_database].[dbo].[DBT_Master]

WHERE 

[Delivery_Address] IS NOT NULL AND [Delivery_Address] NOT LIKE 'TBA%' AND

([Delivery_Address]  LIKE '%Locked Bag%' OR [Delivery_Address] LIKE '%PO BOX%' OR [Delivery_Address] LIKE '%P.O. BOX%' OR [Delivery_Address] LIKE '%P.O BOX%'
 OR [Delivery_Address] LIKE '%P O Box%' OR [Delivery_Address] LIKE '%Private Bag%')

AND [ID] IN (SELECT DISTINCT [Source_Id]
            FROM UpdateSelection)
            
"""

#df4 = pd.read_sql_query(select_delivery_second, conn)

#cursor.close()
#conn.close()

df4 = pd.read_excel("Delivery Address - PO Boxes.xlsx")

df4
# Out:
# Empty DataFrame
# Columns: [Customer_Code, ID, Delivery_Address]
# Index: []

# %%
delivery_second_group = pd.DataFrame(columns=columns)

delivery_second_group['Customer_Code'] = df4['Customer_Code']
delivery_second_group['ID'] = df4['ID']
delivery_second_group['Delivery_Address'] = df4['Delivery_Address']

delivery_second_group
# Out:
# Empty DataFrame
# Columns: [Customer_Code, ID, Billing_ADR_Address_ID, Billing_Address, Billing_StreetNo, Billing_StreetName, Billing_StreetType, Billing_Suburb, Billing_State, Billing_Postcode, Billing_Customisable_Value, Billing_Address2, Delivery_ADR_Address_ID, Delivery_Address, Delivery_StreetNo, Delivery_StreetName, Delivery_StreetType, Delivery_Suburb, Delivery_State, Delivery_Postcode, Delivery_Customisable_Value, Delivery_Address2]
# Index: []
#
# [0 rows x 22 columns]

# %% [markdown]
# #### Post Code, State and Suburb

# %%
# testing if there's any row not in the pattern

error_reason = ''

for index, row in df4.iterrows():
    
    customer_ID = row['ID']
    
    parts = row['Delivery_Address'].strip('_').strip('.').split('_') # spliting the string by _ that represents a line break
    
    if len(parts) < 2:
        Delivery_IDs_To_Exclude.append(customer_ID)
        error_reason += 'Address is not complete. It should have at least 2 lines!\n'
        
        new_line = pd.DataFrame.from_records([{'Customer_Code': row['Customer_Code'],
                                                    'ID': customer_ID,
                                                    'Billing_Address': row['Billing_Address'].replace("_", "\n"),
                                                    'Billing Error Type': error_reason
                        }])
        
        Delivery_Error_Report = pd.concat([Delivery_Error_Report, new_line],ignore_index=True)
        
        error_reason = ''
        
        continue
        
    else:
    
        suburb_details = parts[-1].split() # the last part is usually where the Suburb, post code and state are 
        
        if len(suburb_details) >= 2:
            state = suburb_details[-2].upper().strip(',').strip('`').strip('.') # the state is normally the second to last
        else:
            # Handle the case when the length is less than 2
            state = ''
            error_reason += 'Wrong Format. Please make sure the format looks like:\n{Address1}\n{Address2}\n{StreetNumber} {StreetName} {StreetType}\n{Suburb} {State} {Postcode}\n'
            Delivery_IDs_To_Exclude.append(customer_ID)
            
            new_line = pd.DataFrame.from_records([{'Customer_Code': row['Customer_Code'],
                                                    'ID': customer_ID,
                                                    'Delivery_Address': row['Delivery_Address'].replace("_", "\n"),
                                                    'Delivery Error Type': error_reason
                        }])
            
            Delivery_Error_Report = pd.concat([Delivery_Error_Report, new_line],ignore_index=True)
        
            error_reason = ''
        
            continue
            
           #----------------------------------------------------------------------------------------------------------------------------------------------------------# 

        post_code = suburb_details[-1].strip(',').strip('`').strip().strip('.') # the post code is normally the last word in the last line

        suburb = ' '.join(suburb_details[:-2]).upper().strip(',').strip('.') # suburb is the rest, it can be 2 or more words, so we join them with a space

        # Check if the post_code looks like 4 numbers
        is_post_code_valid = re.match(r'^\d{4}$', post_code) is not None

        # Check if the state looks like 3 or 2 letters
        is_state_valid = re.match(r'^[A-Za-z]{2,3}$', state) is not None
        
        keywords_to_exclude = ['Locked Bag', 'PO BOX', 'P.O. BOX', 'P.O BOX', 'P O Box', 'Private Bag']
            
            
        if any(keyword.upper() in suburb for keyword in keywords_to_exclude):
            Delivery_IDs_To_Exclude.append(customer_ID)
            error_reason += 'Suburb contains address words.'


        
        if is_post_code_valid == False:
            if isinstance(post_code, int):
                error_reason += 'Postcode invalid. It should be 4 numbers.\n'
                Delivery_IDs_To_Exclude.append(customer_ID)
                
                
            if not any(re.match(r'^\d{4}$', str(item)) is not None for item in suburb_details):
                error_reason += 'Postcode Missing.\n'
                Delivery_IDs_To_Exclude.append(customer_ID)
                
                if not any(state in suburb_details for state in states):
                    error_reason += 'State Missing.\n'
                    
                    
                new_line = pd.DataFrame.from_records([{'Customer_Code': row['Customer_Code'],
                                                    'ID': customer_ID,
                                                    'Delivery_Address': row['Delivery_Address'].replace("_", "\n"),
                                                    'Delivery Error Type': error_reason
                        }])
            
                Delivery_Error_Report = pd.concat([Delivery_Error_Report, new_line],ignore_index=True)

                error_reason = ''
                
                continue

                
            else:
                
                if not any(state in suburb_details for state in states):
                    error_reason += 'State Missing.\n'
                    Delivery_IDs_To_Exclude.append(customer_ID)
                    
                    new_line = pd.DataFrame.from_records([{'Customer_Code': row['Customer_Code'],
                                                    'ID': customer_ID,
                                                    'Delivery_Address': row['Delivery_Address'].replace("_", "\n"),
                                                    'Delivery Error Type': error_reason
                        }])
            
                    Delivery_Error_Report = pd.concat([Delivery_Error_Report, new_line],ignore_index=True)

                    error_reason = ''
                    
                    continue
                    
                else:
                    error_reason += 'Wrong Format. Please make sure the format looks like:\n{Address1}\n{Address2}\n{StreetNumber} {StreetName} {StreetType}\n{Suburb} {State} {Postcode}\n'
                    Delivery_IDs_To_Exclude.append(customer_ID)
                    
                    new_line = pd.DataFrame.from_records([{'Customer_Code': row['Customer_Code'],
                                                    'ID': customer_ID,
                                                    'Delivery_Address': row['Delivery_Address'].replace("_", "\n"),
                                                    'Delivery Error Type': error_reason
                        }])
            
                    Delivery_Error_Report = pd.concat([Delivery_Error_Report, new_line],ignore_index=True)

                    error_reason = ''
                    
                    continue
        
        
        
        if is_state_valid == False:
            
            if not any(state in suburb_details for state in states):
                error_reason += 'State Missing.\n'
                Delivery_IDs_To_Exclude.append(customer_ID)
            else:
                Delivery_IDs_To_Exclude.append(customer_ID)
                error_reason += 'State invalid. It should be 2 or 3 characters.\n'
            
        
        if suburb == '':
            error_reason += 'Suburb is Missing.'
            Delivery_IDs_To_Exclude.append(customer_ID)
        
            
        if is_post_code_valid is False or is_state_valid is False or suburb == '' or any(keyword.upper() in suburb for keyword in keywords_to_exclude):
            new_line = pd.DataFrame.from_records([{'Customer_Code': row['Customer_Code'],
                                                    'ID': customer_ID,
                                                    'Delivery_Address': row['Delivery_Address'].replace("_", "\n"),
                                                    'Delivery Error Type': error_reason
                        }])
            
            Delivery_Error_Report = pd.concat([Delivery_Error_Report, new_line],ignore_index=True)
                
        error_reason = ''

# %%
# Firt, we separate the Suburb, Post Code and State and put them into the new dataset

# The pattern we are looking for is: Condell Park NSW 2200 (Suburb State Post Code)

for index, row in df4.iterrows():
    
    customer_ID = row['ID']
    
    if customer_ID in Delivery_IDs_To_Exclude:
        continue
        
    else:
    
        parts = row['Delivery_Address'].strip('_').strip('.').split('_') # spliting the string by _ that represents a line break

        suburb_details = parts[-1].split() # the last part is usually where the Suburb, post code and state are 

        post_code = suburb_details[-1].strip(',').strip('`').strip().strip('.') # the post code is normally the last word in the last line

        state = suburb_details[-2].upper().strip(',').strip('`').strip('.') # the state is normally the second to last

        suburb = ' '.join(suburb_details[:-2]).upper().strip(',').strip('.') # suburb is the rest, it can be 2 or more words, so we join them with a space

        delivery_second_group.loc[delivery_second_group['ID'] == customer_ID, 'Delivery_Postcode'] = post_code
        delivery_second_group.loc[delivery_second_group['ID'] == customer_ID, 'Delivery_State'] = state
        delivery_second_group.loc[delivery_second_group['ID'] == customer_ID, 'Delivery_Suburb'] = suburb

# %% [markdown]
# #### Billing Address 2
#
# It was the billing address 2 the field that would receive the values, but after some problems in converting quotes in Salesforce, this field was changed to Billing_StreetName.
#
# Reffer to this change in the TASK# 002370 - Split Billing Address - PO Box Cases (Baseplan)

# %%
for index, row in df4.iterrows():
    
    customer_ID = row['ID']
    
    if customer_ID in Delivery_IDs_To_Exclude:
        continue
        
    else:
    
        parts = row['Delivery_Address'].strip('_').strip('.').split('_') # spliting the string by _ that represents a line break

        trading_as = []
        adress2 = []
        streetname = []

        for part in parts[:-1]:
                if part.lower().startswith("t/a") or part.lower().startswith("t/as"):
                    trading_as.append(part.strip().strip(',').strip('.'))
                elif re.search(r'\bbox\b|\bbag\b', part, re.IGNORECASE):
                    streetname.append(part.strip().strip(',').strip('.'))
                else:                       
                    adress2.append(part.strip().strip(',').strip('.'))

        if len(adress2) > 0:
            delivery_address2 = '\n'.join(adress2) # geting the second group of the split
            delivery_address2 = delivery_address2.strip('\n').strip('.')
            delivery_second_group.loc[delivery_second_group['ID'] == customer_ID, 'Delivery_Address2'] = delivery_address2
            
        if len(streetname) > 0:
            delivery_streetName = '\n'.join(streetname) # geting the second group of the split
            delivery_streetName.strip('\n').strip().strip(',').strip('.')
            delivery_second_group.loc[delivery_second_group['ID'] == customer_ID, 'Delivery_StreetName'] = streetname

        if len(trading_as) > 0:
            delivery_ta = '\n'.join(trading_as)
            delivery_ta = delivery_ta.strip().strip(',')
            delivery_second_group.loc[delivery_second_group['ID'] == customer_ID, 'Delivery_Customisable_Value'] = delivery_ta
            delivery_ta = None

# %% [markdown]
# #### Updating the Delivery Address

# %%
for index, row in df4.iterrows():
    
    customer_ID = row['ID']
    
    if customer_ID in Delivery_IDs_To_Exclude:
        continue
        
    else:
    
        parts = row['Delivery_Address'].strip('_').strip('.').split('_') # spliting the string by _ that represents a line break

        suburb_details = parts[-1].split() # the last part is usually where the Suburb, post code and state are 

        post_code = suburb_details[-1].strip().strip(',').strip('.') # the post code is normally the last word in the last line

        state = suburb_details[-2].upper().strip().strip(',').strip('.') # the state is normally the second to last

        suburb = ' '.join(suburb_details[:-2]).upper().strip(',').strip('.') # suburb is the rest, it can be 2 or more words, so we join them with a space

        delivery_address = '\n'.join(parts[:-1])

        delivery_address += f'\n{suburb} {state} {post_code}'

        delivery_second_group.loc[delivery_second_group['ID'] == customer_ID, 'Delivery_Address'] = delivery_address

# %%
delivery_second_group = delivery_second_group[~delivery_second_group['ID'].isin(Delivery_IDs_To_Exclude)]

delivery_second_group
# Out:
# Empty DataFrame
# Columns: [Customer_Code, ID, Billing_ADR_Address_ID, Billing_Address, Billing_StreetNo, Billing_StreetName, Billing_StreetType, Billing_Suburb, Billing_State, Billing_Postcode, Billing_Customisable_Value, Billing_Address2, Delivery_ADR_Address_ID, Delivery_Address, Delivery_StreetNo, Delivery_StreetName, Delivery_StreetType, Delivery_Suburb, Delivery_State, Delivery_Postcode, Delivery_Customisable_Value, Delivery_Address2]
# Index: []
#
# [0 rows x 22 columns]

# %%
values_before_df = pd.concat([df, df2, df3, df4], ignore_index=True)

values_before_df
# Out:
#               Customer_Code     ID  \
# 0    9NBRZAGLJDHKHFBUILDING  11551
# 1                   9UNFBFE  11505
# 2          9JZYZDTADNEKEACJ  11493
# 3       9LVRNBVZENGPROJECTS  11480
# 4       9ENWOUWMENGINEERING  11479
# ..                      ...    ...
# 403          9JECCONCRETING    160
# 404             9GROUPACONS    145
# 405           9FORMPROJECTS    136
# 406           9BUILDABILITY     71
# 407             9AGEMACONST     15
#
#                                        Billing_Address  \
# 0    Suite 4, Level 1, 374 Church Street _Parramatt...
# 1    Suite 802, Level 8, 24 Montgomery Street _Koga...
# 2                     Saltspray Close_Redhead NSW 2290
# 3                   50 Fitzroy Street_Carrington, 2294
# 4    Level 18 Darling Park_2/201 Sussex Street_ Syd...
# ..                                                 ...
# 403                                                NaN
# 404                                                NaN
# 405                                                NaN
# 406                                                NaN
# 407                                                NaN
#
#                             Delivery_Address
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
# ..                                       ...
# 403              27 Telopea Street_Punchbowl
# 404         15 Erang Street _CARSS PARK 2221
# 405         Bells Line Road_Kurmond NSW 2757
# 406               108/55 Jones Street_ULTIMO
# 407  Unit 2, 89 Derby Street_Silverwater NSW
#
# [408 rows x 4 columns]

# %% [markdown]
# # Uniting the dataframes

# %%
# Establish the connection with Windows authentication

#conn = pyodbc.connect(
#    f'DRIVER=ODBC Driver 17 for SQL Server;SERVER={server};DATABASE={database};UID={username};PWD={password};'
#)

# Create a cursor object to interact with the database

#cursor = conn.cursor()

select_all_ids = """
SELECT     
	[Customer_Code],
    [ID]
FROM [sample_database].[dbo].[DBT_Master]
ORDER BY ID
"""

#Addresses_Complete = pd.read_sql_query(select_all_ids, conn)

#cursor.close()
#conn.close()

Addresses_Complete = pd.read_excel("All Customers.xlsx")

for col in columns[2:]:
    Addresses_Complete[col] = None


Addresses_Complete
# Out:
#                 Customer_Code     ID Billing_ADR_Address_ID Billing_Address  \
# 0          9KMCTUNTYTSERVICES  11485                   None            None
# 1              PBPHYIPLUMBING  11405                   None            None
# 2       9WAHBNWPXZENGINEERING  11289                   None            None
# 3    9EMKTVVGFJZXYUNWBUILDING  10999                   None            None
# 4                      9BGRBF  10677                   None            None
# ..                        ...    ...                    ...             ...
# 300                R32SY39X77    160                   None            None
# 301                I8K2LHX3VO    145                   None            None
# 302                SEV3K1AXTE    136                   None            None
# 303                49ZLTVKUB5     71                   None            None
# 304                PO4QIG0URT     15                   None            None
#
#     Billing_StreetNo Billing_StreetName Billing_StreetType Billing_Suburb  \
# 0               None               None               None           None
# 1               None               None               None           None
# 2               None               None               None           None
# 3               None               None               None           None
# 4               None               None               None           None
# ..               ...                ...                ...            ...
# 300             None               None               None           None
# 301             None               None               None           None
# 302             None               None               None           None
# 303             None               None               None           None
# 304             None               None               None           None
#
#     Billing_State Billing_Postcode  ... Delivery_ADR_Address_ID  \
# 0            None             None  ...                    None
# 1            None             None  ...                    None
# 2            None             None  ...                    None
# 3            None             None  ...                    None
# 4            None             None  ...                    None
# ..            ...              ...  ...                     ...
# 300          None             None  ...                    None
# 301          None             None  ...                    None
# 302          None             None  ...                    None
# 303          None             None  ...                    None
# 304          None             None  ...                    None
#
#     Delivery_Address Delivery_StreetNo Delivery_StreetName  \
# 0               None              None                None
# 1               None              None                None
# 2               None              None                None
# 3               None              None                None
# 4               None              None                None
# ..               ...               ...                 ...
# 300             None              None                None
# 301             None              None                None
# 302             None              None                None
# 303             None              None                None
# 304             None              None                None
#
#     Delivery_StreetType Delivery_Suburb Delivery_State Delivery_Postcode  \
# 0                  None            None           None              None
# 1                  None            None           None              None
# 2                  None            None           None              None
# 3                  None            None           None              None
# 4                  None            None           None              None
# ..                  ...             ...            ...               ...
# 300                None            None           None              None
# 301                None            None           None              None
# 302                None            None           None              None
# 303                None            None           None              None
# 304                None            None           None              None
#
#     Delivery_Customisable_Value Delivery_Address2
# 0                          None              None
# 1                          None              None
# 2                          None              None
# 3                          None              None
# 4                          None              None
# ..                          ...               ...
# 300                        None              None
# 301                        None              None
# 302                        None              None
# 303                        None              None
# 304                        None              None
#
# [305 rows x 22 columns]

# %%
for index, row in Addresses_Complete.iterrows():
    
    customer_id = row['ID']
    
    # Find the corresponding row in the other DataFrames based on 'ID'
    billing_first_row = billing_first_group[billing_first_group['ID'] == customer_id]
    billing_second_row = billing_second_group[billing_second_group['ID'] == customer_id]
    delivery_first_row = delivery_first_group[delivery_first_group['ID'] == customer_id]
    delivery_second_row = delivery_second_group[delivery_second_group['ID'] == customer_id]
    
    # Check if there are matching rows in the DataFrames
    if not billing_first_row.empty:
        for column in columns[2:]:
            value = billing_first_row[column].values[0]
            if pd.isna(value):
                continue
            else:
                Addresses_Complete.at[index, column] = value

    if not billing_second_row.empty:
        for column in columns[2:]:
            value = billing_second_row[column].values[0]
            if pd.isna(value):
                continue
            else:
                Addresses_Complete.at[index, column] = value

    if not delivery_first_row.empty:
        for column in columns[2:]:
            value = delivery_first_row[column].values[0]
            if pd.isna(value):
                continue
            else:
                Addresses_Complete.at[index, column] = value

    if not delivery_second_row.empty:
        for column in columns[2:]:
            value = delivery_second_row[column].values[0]
            if pd.isna(value):
                continue
            else:
                Addresses_Complete.at[index, column] = value

# %%
# Dropping the line where all values are null
Addresses_Complete = Addresses_Complete.dropna(subset = Addresses_Complete.columns[2:], how='all')

Addresses_Complete.reset_index(drop = True, inplace = True)

Addresses_Complete
# Out:
#                 Customer_Code     ID Billing_ADR_Address_ID  \
# 0              PBPHYIPLUMBING  11405                   None
# 1       9WAHBNWPXZENGINEERING  11289                   None
# 2    9EMKTVVGFJZXYUNWBUILDING  10999                   None
# 3                      9BGRBF  10677                   None
# 4              TAXPTQPROJECTS   9625                   None
# ..                        ...    ...                    ...
# 126                A1MYY3VUE1   1024                   None
# 127                NSNVUW4LWO    781                   None
# 128                BKBHQFGT54    554                   None
# 129                FH9YG6L9UT    327                   None
# 130                IBFRXNN34E    298                   None
#
#                                        Billing_Address Billing_StreetNo  \
# 0                    PO Box 5485 \nWOLLONGONG NSW 2520             None
# 1                 PO Box 1161 \nMOUNTAIN GATE VIC 3165             None
# 2    T/As Odyssey Constructions & Fitout\nPO Box 71...             None
# 3     PO BOX 13268\nGeorge Street\nQUEENSLAND QLD 4003             None
# 4    Engineering Pty Ltd T/As CPB Ghella UGL JV\nAt...             None
# ..                                                 ...              ...
# 126                                               None             None
# 127                                               None             None
# 128                                               None             None
# 129                                               None             None
# 130                                               None             None
#
#     Billing_StreetName Billing_StreetType     Billing_Suburb Billing_State  \
# 0          PO Box 5485               None         WOLLONGONG           NSW
# 1          PO Box 1161               None      MOUNTAIN GATE           VIC
# 2          PO Box 7179               None  WETHERILL PARK BC           NSW
# 3         PO BOX 13268               None         QUEENSLAND           QLD
# 4          PO Box 7261               None         ALEXANDRIA           NSW
# ..                 ...                ...                ...           ...
# 126               None               None               None          None
# 127               None               None               None          None
# 128               None               None               None          None
# 129               None               None               None          None
# 130               None               None               None          None
#
#     Billing_Postcode  ... Delivery_ADR_Address_ID  \
# 0               2520  ...                    None
# 1               3165  ...                    None
# 2               2164  ...                    None
# 3               4003  ...                    None
# 4               2016  ...                    None
# ..               ...  ...                     ...
# 126             None  ...                    None
# 127             None  ...                    None
# 128             None  ...                    None
# 129             None  ...                    None
# 130             None  ...                    None
#
#                                       Delivery_Address      Delivery_StreetNo  \
# 0    Suite 1, Level 6, 288 Forest Road  \nHURSTVILL...  Suite 1, Level 6, 288
# 1    Suite 2, Level 11/555 Lonsdale Street \nMELBOU...  Suite 2, Level 11/555
# 2    T/As Odyssey Constructions & Fitout\nSuite 1E ...  Suite 1E Level 1 1345
# 3                                                 None                   None
# 4    Engineering Pty Ltd T/As CPB Ghella UGL JV\nLe...        Level 7 197-201
# ..                                                 ...                    ...
# 126  Cnr Five Islands & Flinders Street\nPORT KEMBL...
# 127       Cnr of Kerr & Aero Roads\nINGLEBURN NSW 2565
# 128          2388 Silverdale Road\nSILVERDALE NSW 2752                   2388
# 129  Cnr Stockton & Dredge Avenues\nMOOREBANK NSW 2170
# 130  Ground Floor, Coombabah Depot\n186/200 Banyula...                186/200
#
#                     Delivery_StreetName Delivery_StreetType Delivery_Suburb  \
# 0                           Forest Road                None      HURSTVILLE
# 1                       Lonsdale Street                None       MELBOURNE
# 2                     The Horsley Drive                None  WETHERILL PARK
# 3                                  None                None            None
# 4                         Coward Street                None          MASCOT
# ..                                  ...                 ...             ...
# 126  Cnr Five Islands & Flinders Street                None     PORT KEMBLA
# 127            Cnr of Kerr & Aero Roads                None       INGLEBURN
# 128                     Silverdale Road                None      SILVERDALE
# 129       Cnr Stockton & Dredge Avenues                None       MOOREBANK
# 130                       Banyula Drive                None          NERANG
#
#     Delivery_State Delivery_Postcode          Delivery_Customisable_Value  \
# 0              NSW              2220                                 None
# 1              VIC              3000                                 None
# 2              NSW              2164  T/As Odyssey Constructions & Fitout
# 3             None              None                                 None
# 4              NSW              2020                                 None
# ..             ...               ...                                  ...
# 126            NSW              2505                                 None
# 127            NSW              2565                                 None
# 128            NSW              2752                                 None
# 129            NSW              2170                                 None
# 130            QLD              4211                                 None
#
#                               Delivery_Address2
# 0                                          None
# 1                                          None
# 2                                          None
# 3                                          None
# 4    Engineering Pty Ltd T/As CPB Ghella UGL JV
# ..                                          ...
# 126                                        None
# 127                                        None
# 128                                        None
# 129                                        None
# 130               Ground Floor, Coombabah Depot
#
# [131 rows x 22 columns]

# %% [markdown]
# # Updating the database

# %% [markdown]
# This part gets the list of all suburbs from the system.

# %%
# Establish the connection with Windows authentication

#conn = pyodbc.connect(
#    f'DRIVER=ODBC Driver 17 for SQL Server;SERVER={server};DATABASE={database};UID={username};PWD={password};'
#)

# Create a cursor object to interact with the database
#cursor = conn.cursor()

select_suburb_details = """
SELECT SUB.[Id]
      ,[SuburbName]
	  ,STA.[StateName]
      ,[StateID]
      ,[Postcode]
  FROM [sample_database].[dbo].[ADR_Suburb] SUB
	LEFT JOIN [sample_database].[dbo].[ADR_State] STA
		ON SUB.[StateID] = STA.[Id]
"""

#suburbs = pd.read_sql_query(select_suburb_details, conn)

#cursor.close()
#conn.close()

suburbs = pd.read_excel("Suburbs List.xlsx")

suburbs
# Out:
#           Id                      SuburbName StateName  StateID  Postcode
# 0          1                           ACTON       ACT        1      2601
# 1          2                         AINSLIE       ACT        1      2602
# 2          3                          AMAROO       ACT        1      2914
# 3          4                          ARANDA       ACT        1      2614
# 4          5  AUSTRALIAN NATIONAL UNIVERSITY       ACT        1       200
# ...      ...                             ...       ...      ...       ...
# 19651  16767                 YOURDAMUNG LAKE        WA        8      6225
# 19652  19648                            YUIN        WA        8      6635
# 19653  16768                            YUNA        WA        8      6532
# 19654  16769                         ZANTHUS        WA        8      6434
# 19655  16770                        ZUYTDORP        WA        8      6536
#
# [19656 rows x 5 columns]

# %%
# Select the columns for billing information and 'Customer_Code' and 'ID'
billing_columns = ['Customer_Code', 'ID', 'Billing_Address', 'Billing_StreetNo', 'Billing_StreetName', 'Billing_StreetType',
                   'Billing_Suburb', 'Billing_State', 'Billing_Postcode', 'Billing_Customisable_Value', 'Billing_Address2']

billing_df = Addresses_Complete[billing_columns]

# Select the columns for delivery information and 'Customer_Code' and 'ID'
delivery_columns = ['Customer_Code', 'ID', 'Delivery_Address', 'Delivery_StreetNo', 'Delivery_StreetName', 'Delivery_StreetType',
                    'Delivery_Suburb', 'Delivery_State', 'Delivery_Postcode', 'Delivery_Customisable_Value', 'Delivery_Address2']

delivery_df = Addresses_Complete[delivery_columns]

# %%
billing_df = billing_df.dropna(subset=billing_df.columns[2:], how='all')

billing_df
# Out:
#                Customer_Code     ID  \
# 0             PBPHYIPLUMBING  11405
# 1      9WAHBNWPXZENGINEERING  11289
# 2   9EMKTVVGFJZXYUNWBUILDING  10999
# 3                     9BGRBF  10677
# 4             TAXPTQPROJECTS   9625
# ..                       ...    ...
# 66      BRVPHIKKHWVHPROJECTS    887
# 67    DXFCKJUZMKIENGINEERING    777
# 68             ODCUJVZZGROUP    688
# 69     NAGBHADCFDENGINEERING    596
# 70   PTPJMOKHYBBWENGINEERING    371
#
#                                       Billing_Address       Billing_StreetNo  \
# 0                   PO Box 5485 \nWOLLONGONG NSW 2520                   None
# 1                PO Box 1161 \nMOUNTAIN GATE VIC 3165                   None
# 2   T/As Odyssey Constructions & Fitout\nPO Box 71...                   None
# 3    PO BOX 13268\nGeorge Street\nQUEENSLAND QLD 4003                   None
# 4   Engineering Pty Ltd T/As CPB Ghella UGL JV\nAt...                   None
# ..                                                ...                    ...
# 66  Tower 2/ Level 21 101 Grafton St     \nBONDI J...  Tower 2/ Level 21 101
# 67  Suite 1, Level 1, 290 Botany Road\nALEXANDRIA ...  Suite 1, Level 1, 290
# 68  (Receivers & Managers Appointed) (in Liquidati...         Unit 32, 11-21
# 69  C/-Broadcast Australia Transmitting Station\nF...                  2-148
# 70    Cnr Jones Bay & Pirrama Roads\nPYRMONT NSW 2009
#
#                Billing_StreetName Billing_StreetType     Billing_Suburb  \
# 0                     PO Box 5485               None         WOLLONGONG
# 1                     PO Box 1161               None      MOUNTAIN GATE
# 2                     PO Box 7179               None  WETHERILL PARK BC
# 3                    PO BOX 13268               None         QUEENSLAND
# 4                     PO Box 7261               None         ALEXANDRIA
# ..                            ...                ...                ...
# 66                     Grafton St               None     BONDI JUNCTION
# 67                    Botany Road               None         ALEXANDRIA
# 68                 Underwood Road               None           HOMEBUSH
# 69                  Sydenham Road               None            DELAHEY
# 70  Cnr Jones Bay & Pirrama Roads               None            PYRMONT
#
#    Billing_State Billing_Postcode           Billing_Customisable_Value  \
# 0            NSW             2520                                 None
# 1            VIC             3165                                 None
# 2            NSW             2164  T/As Odyssey Constructions & Fitout
# 3            QLD             4003                                 None
# 4            NSW             2016                                 None
# ..           ...              ...                                  ...
# 66           NSW             2022                                 None
# 67           NSW             2015                                 None
# 68           NSW             2140                                 None
# 69           VIC             3037                                 None
# 70           NSW             2009                                 None
#
#                                      Billing_Address2
# 0                                                None
# 1                                                None
# 2                                                None
# 3                                       George Street
# 4   Engineering Pty Ltd T/As CPB Ghella UGL JV\nAt...
# ..                                                ...
# 66                                               None
# 67                                               None
# 68  (Receivers & Managers Appointed) (in Liquidati...
# 69  C/-Broadcast Australia Transmitting Station\nF...
# 70                                               None
#
# [71 rows x 11 columns]

# %% [markdown]
# ## Inserting the addresses and retrieving the IDs

# %% [markdown]
# ### Billing Addresses

# %% [markdown]
# This part checks if the suburb, postcode and state inserted by the user exists using the created functions explained before.

# %%
# Testing to see if the suburb and postcode macthes

billing_insert_statments = ''

check_file = ''

Billing_IDs_To_Skip = []

error_reason = ''

for index, row in billing_df.iterrows():
    
    suburb = row['Billing_Suburb']
    original_suburb = row['Billing_Suburb']
    postcode = row['Billing_Postcode']
    original_postcode = row['Billing_Postcode']
    state = row['Billing_State']
    customer_id = row['ID']
    
    
    if suburb == 'HRMC':
        suburb = 'HUNTER REGION MC'
    elif suburb == 'GCMC' or suburb == 'GCMC BUNDALL':
        suburb = 'GOLD COAST MC'
    elif suburb == 'QVB':
        suburb = 'QUEEN VICTORIA BUILDING'
    
    filtered_suburbs = suburbs[(suburbs['SuburbName'].str.upper() == suburb) & (suburbs['Postcode'] == postcode)]
    
    
    if filtered_suburbs.empty:
        
        filtered_suburbs = suburbs[(suburbs['SuburbName'].str.upper() == suburb) & (suburbs['StateName'] == state)]
        
        if len(filtered_suburbs)>1:
            best_postcode_diff = float('inf')
            best_match = None
            
            for _, current_row in filtered_suburbs.iterrows():
                current_postcode = current_row['Postcode']
                postcode_diff = abs(int(current_postcode) - int(original_postcode))

                if postcode_diff < best_postcode_diff:
                    best_postcode_diff = postcode_diff
                    suburb = current_row['SuburbName']
                    postcode = current_row['Postcode']
            
            filtered_suburbs = suburbs[(suburbs['SuburbName'].str.upper() == suburb) & (suburbs['Postcode'] == postcode)]
            check_file += f'\nCheck 1\n'
        
        elif filtered_suburbs.empty:
            matching_suburb = find_matching_suburb(suburb, postcode, suburbs)
        
            if matching_suburb:
                suburb = matching_suburb
                filtered_suburbs = suburbs[(suburbs['SuburbName'].str.upper() == suburb.upper()) & (suburbs['Postcode'] == postcode)]
                check_file += f'\nCheck 2\n'

            else:
                suburb = original_suburb
                matching_split = find_matching_suburb_split(suburb, postcode, suburbs)

                if matching_split:
                    suburb = matching_split
                    filtered_suburbs = suburbs[(suburbs['SuburbName'].str.upper() == suburb.upper()) & (suburbs['Postcode'] == postcode)]
                    check_file += f'\nCheck 3\n'

                else:
                    suburb = original_suburb
                    matching_split_state = find_matching_suburb_split_state(suburb, state, postcode, suburbs)

                    if matching_split_state[0]:
                        suburb = matching_split_state[0]
                        postcode = matching_split_state[1]

                        filtered_suburbs = suburbs[(suburbs['SuburbName'].str.upper()== suburb.upper()) & (suburbs['Postcode'] == postcode)]
                        check_file += f'\nCheck 4\n'
            
            
            
    if filtered_suburbs.empty:
        check_file += f'\n {index}---{customer_id} --- {original_suburb} --- !!!!!!!!!!!!!!!! EMPTY !!!!!!!!!!!!!!!!! \n'
        Billing_IDs_To_Skip.append(customer_id)
        error_reason += 'Postcode and Suburb does not match.\n'
        
        
    else:
        suburb_id = filtered_suburbs['Id'].values[0]
        state_id = filtered_suburbs['StateID'].values[0]
        postcode = filtered_suburbs['Postcode'].values[0]
        suburb = filtered_suburbs['SuburbName'].values[0]
        
        # Getting the new postcode and suburb to update the billing address
        
        parts = row['Billing_Address'].split('\n') # spliting the string by _ that represents a line break
    
        billing_address = '\n'.join(parts[:-1])

        billing_address += f'\n{suburb} {state} {postcode}'
        
        
        street_number = row['Billing_StreetNo']
        
        if street_number is not None:
            len_stnumber = len(street_number)
            street_number = street_number.replace("'", "''") 
            street_number = street_number.replace("\n", "'+char(13)+char(10)+'")
            street_number = f"'{street_number}'"
        else:
            street_number = 'NULL'
            len_stnumber = len(street_number)

        
        street_name = row['Billing_StreetName']
        if street_name is not None:
            len_stname = len(street_name)
            street_name = street_name.replace("'", "''")
            street_name = street_name.replace("\n", "'+char(13)+char(10)+'")
            street_name = f"'{street_name}'"
        else:
            street_name = 'NULL'
            len_stname = len(street_name)
        
        address = billing_address
        if address is not None:
            len_add = len(address)
            address = address.replace("'", "''")
            address = address.replace("\n", "'+char(13)+char(10)+'")
        else:
            address = 'NULL'
            len_add = len(address)

        address1 = row['Billing_Customisable_Value']
        if address1 is not None:
            len_add1 = len(address1)
            address1 = address1.replace("'", "''")
            address1 = address1.replace("\n", "'+char(13)+char(10)+'")
            address1 = f"'{address1}'"
        else:
            address1 = 'NULL'
            len_add1 = len(address1)
            

        address2 = row['Billing_Address2']
        if address2 is not None:
            len_add2 = len(address2)
            address2 = address2.replace("'", "''")
            address2 = address2.replace("\n", "'+char(13)+char(10)+'")
            address2 = f"'{address2}'"
        else:
            address2 = 'NULL'
            len_add2 = len(address2)

        
        
        if postcode != original_postcode or suburb != original_suburb:
            check_file += f'\n!!!DIFFERENT!!!\nOriginal Suburb: {original_suburb} --- Original Postcode: {original_postcode}\nIndex: {index} \nMatching Sub: {suburb}\nPostcode: {postcode}\nID: {customer_id} \n'
        
        else:
            check_file += f'\nOriginal Suburb: {original_suburb} --- Original Postcode: {original_postcode}\nIndex: {index} \nMatching Sub: {suburb}\nPostcode: {postcode}\nID: {customer_id} \n'
    
        insert = f"""
        INSERT INTO [sample_database].[dbo].[ADR_Address]
          ([Address]
          ,[Address1]
          ,[StreetNumber]
          ,[StreetName]
          ,[Address2]
          ,[SuburbID]
          ,[StateID]
          ,[CountryID]
          ,[Postcode])
         VALUES
               ('{address}' ---- {f'Greater {customer_id}' if len_add > 1000 else 'Smaller'}
               ,{address1} ---- {f'Greater {customer_id}' if len_add1 > 250 else 'Smaller'}
               ,{street_number} ---- {f'Greater {customer_id}' if len_stnumber > 20 else 'Smaller'}
               ,{street_name} ---- {f'Greater {customer_id}' if len_stname > 100 else 'Smaller'}
               ,{address2} ---- {f'Greater {customer_id}' if len_add2 > 70 else 'Smaller'}
               ,{suburb_id}
               ,{state_id}
               ,36
               ,{postcode})
        """
        
        billing_insert_statments += insert
        
        
        if len_add > 1000:
            Billing_IDs_To_Skip.append(customer_id)
            error_reason += 'Lenght of the Billing_Address is longer than 1000 characters.\n'
        
        if len_add1 > 250:
            Billing_IDs_To_Skip.append(customer_id)
            error_reason += 'Lenght of the Billing_Customisable_Value is longer than 250 characters.\n'
        
        if len_stnumber > 20:
            Billing_IDs_To_Skip.append(customer_id)
            error_reason += 'Lenght of the StreetNumber is longer than 20 characters.\n'
        
        if len_stname > 100:
            Billing_IDs_To_Skip.append(customer_id)
            error_reason += 'Lenght of the StreetName is longer than 100 characters.\n'
            
        if len_add2 > 70:
            Billing_IDs_To_Skip.append(customer_id)
            error_reason += 'Lenght of the Address2 is longer than 70 characters.\n'
            
            
        if any([len_add > 1000, len_add1 > 250, len_stnumber > 20, len_stname > 100, len_stname > 100, len_add2 > 70]):
            new_line = pd.DataFrame.from_records([{'Customer_Code': row['Customer_Code'],
                                                    'ID': customer_id,
                                                    'Billing_Address': row['Billing_Address'].replace("_", "\n"),
                                                    'Billing Error Type': error_reason
                        }])
            
            Billing_Error_Report = pd.concat([Billing_Error_Report, new_line],ignore_index=True)
                
        error_reason = ''

# %%
# Get the current date and time as a string
date_time = datetime.now().strftime("%Y%m%d_%H%M%S")

# %% [markdown]
# This part saves the values as they were before the modifications just in case we need to come back to them.

# %%
folder_path = f'\\\choose\\your\\path{date_time}'

#file_path = os.path.join(folder_path, f'Values_Before.xlsx')

#values_before_df.to_excel(file_path, index=False)

# %% [markdown]
# After the checks, the code inserts into the addresses table the fixed customer addresses and gets the generated ID to use in the next step.

# %%
# Establish the connection with Windows authentication

#conn = pyodbc.connect(
#    f'DRIVER=ODBC Driver 17 for SQL Server;SERVER={server};DATABASE={database};UID={username};PWD={password};'
#)

# Create a cursor object to interact with the database
#cursor = conn.cursor()

billing_insert_statments = ''

check_file = ''


for index, row in billing_df.iterrows():
    
    
    suburb = row['Billing_Suburb']
    original_suburb = row['Billing_Suburb']
    postcode = row['Billing_Postcode']
    original_postcode = row['Billing_Postcode']
    state = row['Billing_State']
    customer_id = row['ID']
    
    if customer_id in Billing_IDs_To_Skip:
        continue
    
    if suburb == 'HRMC':
        suburb = 'HUNTER REGION MC'
    elif suburb == 'GCMC' or suburb == 'GCMC BUNDALL':
        suburb = 'GOLD COAST MC'
    elif suburb == 'QVB':
        suburb = 'QUEEN VICTORIA BUILDING'
    
    filtered_suburbs = suburbs[(suburbs['SuburbName'].str.upper() == suburb) & (suburbs['Postcode'] == postcode)]
    
    
    if filtered_suburbs.empty:
        
        filtered_suburbs = suburbs[(suburbs['SuburbName'].str.upper() == suburb) & (suburbs['StateName'] == state)]
        
        if len(filtered_suburbs)>1:
            best_postcode_diff = float('inf')
            best_match = None
            
            for _, current_row in filtered_suburbs.iterrows():
                current_postcode = current_row['Postcode']
                postcode_diff = abs(int(current_postcode) - int(original_postcode))

                if postcode_diff < best_postcode_diff:
                    best_postcode_diff = postcode_diff
                    suburb = current_row['SuburbName']
                    postcode = current_row['Postcode']
            
            filtered_suburbs = suburbs[(suburbs['SuburbName'].str.upper() == suburb) & (suburbs['Postcode'] == postcode)]
        
        elif filtered_suburbs.empty:
            matching_suburb = find_matching_suburb(suburb, postcode, suburbs)
        
            if matching_suburb:
                suburb = matching_suburb
                filtered_suburbs = suburbs[(suburbs['SuburbName'].str.upper() == suburb.upper()) & (suburbs['Postcode'] == postcode)]

            else:
                suburb = original_suburb
                matching_split = find_matching_suburb_split(suburb, postcode, suburbs)

                if matching_split:
                    suburb = matching_split
                    filtered_suburbs = suburbs[(suburbs['SuburbName'].str.upper() == suburb.upper()) & (suburbs['Postcode'] == postcode)]

                else:
                    suburb = original_suburb
                    matching_split_state = find_matching_suburb_split_state(suburb, state, postcode, suburbs)

                    if matching_split_state[0]:
                        suburb = matching_split_state[0]
                        postcode = matching_split_state[1]

                        filtered_suburbs = suburbs[(suburbs['SuburbName'].str.upper()== suburb.upper()) & (suburbs['Postcode'] == postcode)]
            
            
    if filtered_suburbs.empty:
        continue
        
        
    else:
        suburb_id = filtered_suburbs['Id'].values[0]
        state_id = filtered_suburbs['StateID'].values[0]
        postcode = filtered_suburbs['Postcode'].values[0]
        suburb = filtered_suburbs['SuburbName'].values[0]
        
        # Getting the new postcode and suburb to update the billing address
        
        parts = row['Billing_Address'].split('\n') # spliting the string by _ that represents a line break
    
        billing_address = '\n'.join(parts[:-1])

        billing_address += f'\n{suburb} {state} {postcode}'
        
        
        street_number = row['Billing_StreetNo']
        
        if street_number is not None:
            street_number = street_number.replace("'", "''") 
            street_number = street_number.replace("\n", "'+char(13)+char(10)+'")
            street_number = f"'{street_number}'"
        else:
            street_number = 'NULL'
            len_stnumber = len(street_number)

        
        street_name = row['Billing_StreetName']
        if street_name is not None:
            street_name = street_name.replace("'", "''") 
            street_name = street_name.replace("\n", "'+char(13)+char(10)+'")
            street_name = f"'{street_name}'"
        else:
            street_name = 'NULL'
            len_stname = len(street_name)
        
        address = billing_address
        if address is not None:
            address = address.replace("'", "''")
            address = address.replace("\n", "'+char(13)+char(10)+'")
        else:
            address = 'NULL'

        address1 = row['Billing_Customisable_Value']
        if address1 is not None:
            address1 = address1.replace("'", "''")
            address1 = address1.replace("\n", "'+char(13)+char(10)+'")
            address1 = f"'{address1}'"
        else:
            address1 = 'NULL'
            len_add1 = len(address1)
            

        address2 = row['Billing_Address2']
        if address2 is not None:
            address2 = address2.replace("'", "''")
            address2 = address2.replace("\n", "'+char(13)+char(10)+'")
            address2 = f"'{address2}'"
        else:
            address2 = 'NULL'
            len_add2 = len(address2)

        
       
        insert = f"""
        INSERT INTO [sample_database].[dbo].[ADR_Address]
          ([Address]
          ,[Address1]
          ,[StreetNumber]
          ,[StreetName]
          ,[Address2]
          ,[SuburbID]
          ,[StateID]
          ,[CountryID]
          ,[Postcode])
         VALUES
               ('{address}'
               ,{address1} 
               ,{street_number} 
               ,{street_name}
               ,{address2}
               ,{suburb_id}
               ,{state_id}
               ,36
               ,{postcode})
        """
        
        billing_insert_statments += insert
        
        # Execute each SQL query in the list
        #cursor.execute(insert)

        #conn.commit()
        
        
        select_id = """
SELECT MAX([ID])
FROM [sample_database].[dbo].[ADR_Address]
        """
        # Execute the select_id query
        #cursor.execute(select_id)
        
        # Fetch the result and extract the ID
        #new_id = cursor.fetchone()[0]
        
        #Addresses_Complete.loc[Addresses_Complete['ID'] == customer_id, 'Billing_ADR_Address_ID'] = new_id
        Addresses_Complete.loc[Addresses_Complete['ID'] == customer_id, 'Billing_Suburb'] = suburb
        Addresses_Complete.loc[Addresses_Complete['ID'] == customer_id, 'Billing_Postcode'] = postcode
        Addresses_Complete.loc[Addresses_Complete['ID'] == customer_id, 'Billing_Address'] = billing_address
       
    
# print(new_id)

# Close the cursor and connection
#cursor.close()
#conn.close()

# %% [markdown]
# ### Delivery Addresses

# %%
delivery_df = delivery_df.dropna(subset=delivery_df.columns[2:], how='all')

delivery_df
# Out:
#                 Customer_Code     ID  \
# 0              PBPHYIPLUMBING  11405
# 1       9WAHBNWPXZENGINEERING  11289
# 2    9EMKTVVGFJZXYUNWBUILDING  10999
# 4              TAXPTQPROJECTS   9625
# 5        ZWWGFVULCXOHSERVICES   9384
# ..                        ...    ...
# 126                A1MYY3VUE1   1024
# 127                NSNVUW4LWO    781
# 128                BKBHQFGT54    554
# 129                FH9YG6L9UT    327
# 130                IBFRXNN34E    298
#
#                                       Delivery_Address  \
# 0    Suite 1, Level 6, 288 Forest Road  \nHURSTVILL...
# 1    Suite 2, Level 11/555 Lonsdale Street \nMELBOU...
# 2    T/As Odyssey Constructions & Fitout\nSuite 1E ...
# 4    Engineering Pty Ltd T/As CPB Ghella UGL JV\nLe...
# 5    Endeavour House, 11-15 Fourth Avenue\nMAWSON L...
# ..                                                 ...
# 126  Cnr Five Islands & Flinders Street\nPORT KEMBL...
# 127       Cnr of Kerr & Aero Roads\nINGLEBURN NSW 2565
# 128          2388 Silverdale Road\nSILVERDALE NSW 2752
# 129  Cnr Stockton & Dredge Avenues\nMOOREBANK NSW 2170
# 130  Ground Floor, Coombabah Depot\n186/200 Banyula...
#
#           Delivery_StreetNo                 Delivery_StreetName  \
# 0     Suite 1, Level 6, 288                         Forest Road
# 1     Suite 2, Level 11/555                     Lonsdale Street
# 2     Suite 1E Level 1 1345                   The Horsley Drive
# 4           Level 7 197-201                       Coward Street
# 5    Endeavour House, 11-15                       Fourth Avenue
# ..                      ...                                 ...
# 126                          Cnr Five Islands & Flinders Street
# 127                                    Cnr of Kerr & Aero Roads
# 128                    2388                     Silverdale Road
# 129                               Cnr Stockton & Dredge Avenues
# 130                 186/200                       Banyula Drive
#
#     Delivery_StreetType Delivery_Suburb Delivery_State Delivery_Postcode  \
# 0                  None      HURSTVILLE            NSW              2220
# 1                  None       MELBOURNE            VIC              3000
# 2                  None  WETHERILL PARK            NSW              2164
# 4                  None          MASCOT            NSW              2020
# 5                  None    MAWSON LAKES             SA              5095
# ..                  ...             ...            ...               ...
# 126                None     PORT KEMBLA            NSW              2505
# 127                None       INGLEBURN            NSW              2565
# 128                None      SILVERDALE            NSW              2752
# 129                None       MOOREBANK            NSW              2170
# 130                None          NERANG            QLD              4211
#
#              Delivery_Customisable_Value  \
# 0                                   None
# 1                                   None
# 2    T/As Odyssey Constructions & Fitout
# 4                                   None
# 5                                   None
# ..                                   ...
# 126                                 None
# 127                                 None
# 128                                 None
# 129                                 None
# 130                                 None
#
#                               Delivery_Address2
# 0                                          None
# 1                                          None
# 2                                          None
# 4    Engineering Pty Ltd T/As CPB Ghella UGL JV
# 5                                          None
# ..                                          ...
# 126                                        None
# 127                                        None
# 128                                        None
# 129                                        None
# 130               Ground Floor, Coombabah Depot
#
# [111 rows x 11 columns]

# %%
delivery_insert_statments = ''

delivery_check_file = ''

Delivery_IDs_To_Skip = []

error_reason = ''

for index, row in delivery_df.iterrows():
    
    suburb = row['Delivery_Suburb']
    original_suburb = row['Delivery_Suburb']
    postcode = row['Delivery_Postcode']
    original_postcode = row['Delivery_Postcode']
    state = row['Delivery_State']
    customer_id = row['ID']
    
    if suburb == 'HRMC':
        suburb = 'HUNTER REGION MC'
    elif suburb == 'GCMC' or suburb == 'GCMC BUNDALL':
        suburb = 'GOLD COAST MC'
    elif suburb == 'QVB':
        suburb = 'QUEEN VICTORIA BUILDING'
        
    
    filtered_suburbs = suburbs[(suburbs['SuburbName'].str.upper() == suburb) & (suburbs['Postcode'] == postcode)]
    
    
    if filtered_suburbs.empty:
        
        filtered_suburbs = suburbs[(suburbs['SuburbName'].str.upper() == suburb) & (suburbs['StateName'] == state)]
        
        if len(filtered_suburbs)>1:
            best_postcode_diff = float('inf')
            best_match = None
            
            for _, current_row in filtered_suburbs.iterrows():
                current_postcode = current_row['Postcode']
                postcode_diff = abs(int(current_postcode) - int(original_postcode))

                if postcode_diff < best_postcode_diff:
                    best_postcode_diff = postcode_diff
                    suburb = current_row['SuburbName']
                    postcode = current_row['Postcode']
            
            filtered_suburbs = suburbs[(suburbs['SuburbName'].str.upper() == suburb) & (suburbs['Postcode'] == postcode)]
            delivery_check_file += f'\nCheck 1\n'
        
        elif filtered_suburbs.empty:
            matching_suburb = find_matching_suburb(suburb, postcode, suburbs)
        
            if matching_suburb:
                suburb = matching_suburb
                filtered_suburbs = suburbs[(suburbs['SuburbName'].str.upper() == suburb.upper()) & (suburbs['Postcode'] == postcode)]
                delivery_check_file += f'\nCheck 2\n'

            else:
                suburb = original_suburb
                matching_split = find_matching_suburb_split(suburb, postcode, suburbs)

                if matching_split:
                    suburb = matching_split
                    filtered_suburbs = suburbs[(suburbs['SuburbName'].str.upper() == suburb.upper()) & (suburbs['Postcode'] == postcode)]
                    delivery_check_file += f'\nCheck 3\n'

                else:
                    suburb = original_suburb
                    matching_split_state = find_matching_suburb_split_state(suburb, state, postcode, suburbs)

                    if matching_split_state[0]:
                        suburb = matching_split_state[0]
                        postcode = matching_split_state[1]

                        filtered_suburbs = suburbs[(suburbs['SuburbName'].str.upper()== suburb.upper()) & (suburbs['Postcode'] == postcode)]
                        delivery_check_file += f'\nCheck 4\n'
            
            
            
    if filtered_suburbs.empty:
        delivery_check_file += f'\n {index}---{customer_id} --- {original_suburb} --- !!!!!!!!!!!!!!!! EMPTY !!!!!!!!!!!!!!!!! \n'
        Delivery_IDs_To_Skip.append(customer_id)
        error_reason += 'Postcode and Suburb does not match.\n'
        
        
    else:
        suburb_id = filtered_suburbs['Id'].values[0]
        state_id = filtered_suburbs['StateID'].values[0]
        postcode = filtered_suburbs['Postcode'].values[0]
        suburb = filtered_suburbs['SuburbName'].values[0]
        
        # Getting the new postcode and suburb to update the billing address
        
        parts = row['Delivery_Address'].split('\n') # spliting the string by _ that represents a line break
    
        delivery_address = '\n'.join(parts[:-1])

        delivery_address += f'\n{suburb} {state} {postcode}'
        
        
        street_number = row['Delivery_StreetNo']
        
        if street_number is not None:
            len_stnumber = len(street_number)
            street_number = street_number.replace("'", "''") 
            street_number = street_number.replace("\n", "'+char(13)+char(10)+'")
            street_number = f"'{street_number}'"
        else:
            street_number = 'NULL'
            len_stnumber = len(street_number)
        
        street_name = row['Delivery_StreetName']
        if street_name is not None:
            len_stname = len(street_name)
            street_name = street_name.replace("'", "''") 
            street_name = street_name.replace("\n", "'+char(13)+char(10)+'")
            street_name = f"'{street_name}'"
        else:
            street_name = 'NULL'
            len_stname = len(street_name)
        
        address = delivery_address
        if address is not None:
            len_add = len(address)
            address = address.replace("'", "''")
            address = address.replace("\n", "'+char(13)+char(10)+'")
        else:
            address = 'NULL'
            len_add = len(address)

        address1 = row['Delivery_Customisable_Value']
        if address1 is not None:
            len_add1 = len(address1)
            address1 = address1.replace("'", "''")
            address1 = address1.replace("\n", "'+char(13)+char(10)+'")
            address1 = f"'{address1}'"
        else:
            address1 = 'NULL'
            len_add1 = len(address1)

        address2 = row['Delivery_Address2']
        if address2 is not None:
            len_add2 = len(address2)
            address2 = address2.replace("'", "''")
            address2 = address2.replace("\n", "'+char(13)+char(10)+'")
            address2 = f"'{address2}'"
        else:
            address2 = 'NULL'
            len_add2 = len(address2)

        
        
        if postcode != original_postcode or suburb != original_suburb:
            delivery_check_file += f'\n!!!DIFFERENT!!!\nOriginal Suburb: {original_suburb} --- Original Postcode: {original_postcode}\nIndex: {index} \nMatching Sub: {suburb}\nPostcode: {postcode}\nID: {customer_id} \n'
        
        else:
            delivery_check_file += f'\nOriginal Suburb: {original_suburb} --- Original Postcode: {original_postcode}\nIndex: {index} \nMatching Sub: {suburb}\nPostcode: {postcode}\nID: {customer_id} \n'
    
        insert = f"""
        INSERT INTO [sample_database].[dbo].[ADR_Address]
          ([Address]
          ,[Address1]
          ,[StreetNumber]
          ,[StreetName]
          ,[Address2]
          ,[SuburbID]
          ,[StateID]
          ,[CountryID]
          ,[Postcode])
         VALUES
               ('{address}' ---- {f'Greater {customer_id}' if len(address) > 1000 else 'Smaller'}
               ,{address1} ---- {f'Greater {customer_id}' if len_add1 > 250 else 'Smaller'}
               ,{street_number} ---- {f'Greater {customer_id}' if len_stnumber > 20 else 'Smaller'}
               ,{street_name} ---- {f'Greater {customer_id}' if len_stname > 100 else 'Smaller'}
               ,{address2} ---- {f'Greater {customer_id}' if len_add2 > 70 else 'Smaller'}
               ,{suburb_id}
               ,{state_id}
               ,36
               ,{postcode})
        """
        
        delivery_insert_statments += insert
             
        
        if len_add > 1000:
            Delivery_IDs_To_Skip.append(customer_id)
            error_reason += 'Lenght of the Billing_Address is longer than 1000 characters.\n'
        
        if len_add1 > 250:
            Delivery_IDs_To_Skip.append(customer_id)
            error_reason += 'Lenght of the Billing_Customisable_Value is longer than 250 characters.\n'
        
        if len_stnumber > 20:
            Delivery_IDs_To_Skip.append(customer_id)
            error_reason += 'Lenght of the StreetNumber is longer than 20 characters.\n'
        
        if len_stname > 100:
            Delivery_IDs_To_Skip.append(customer_id)
            error_reason += 'Lenght of the StreetName is longer than 100 characters.\n'
            
        if len_add2 > 70:
            Delivery_IDs_To_Skip.append(customer_id)
            error_reason += 'Lenght of the Address2 is longer than 70 characters.\n'
            
            
        if any([len_add > 1000, len_add1 > 250, len_stnumber > 20, len_stname > 100, len_stname > 100, len_add2 > 70]):
            new_line = pd.DataFrame.from_records([{'Customer_Code': row['Customer_Code'],
                                                    'ID': customer_id,
                                                    'Delivery_Address': row['Delivery_Address'].replace("_", "\n"),
                                                    'Delivery Error Type': error_reason
                        }])
            
            Delivery_Error_Report = pd.concat([Delivery_Error_Report, new_line],ignore_index=True)
                
        error_reason = ''

# %% [markdown]
# This part was commented because it only works when a file is saved.
#
# It saves the Error Report in an Excel file so it can be checked after what happened in each customer.

# %%
folder_path = f'\\\choose\\your\\path\\{date_time}'

'''
file_path = os.path.join(folder_path, f'Error_Report.xlsx')

Error_Report = pd.merge(Billing_Error_Report, Delivery_Error_Report, on=['Customer_Code', 'ID'], how='outer')

error_report_columns = ['Customer_Code', 'ID'] + [col for col in Error_Report.columns if col not in ['Customer_Code', 'ID']]
Error_Report = Error_Report[error_report_columns]

Error_Report.to_excel(file_path, index=False)

# Create ExcelWriter and write DataFrame to Excel
with pd.ExcelWriter(file_path, engine='xlsxwriter') as writer:
    Error_Report.to_excel(writer, index=False, sheet_name='Sheet1')

    # Access the xlsxwriter workbook and worksheet objects from the ExcelWriter object.
    workbook = writer.book
    worksheet = writer.sheets['Sheet1']

    # Add a text wrap format.
    text_wrap_format = workbook.add_format({'text_wrap': True, 'align': 'center'})
    
    # Set the width of column 'A' to 26
    worksheet.set_column('A:A', 26)
    
    # Set the width of column 'B' to 10
    worksheet.set_column('B:B', 10)
    
    # Set the width of columns 'C' to 'F' to 55
    worksheet.set_column('C:F', 55, text_wrap_format)

'''
# Out:
# "\nfile_path = os.path.join(folder_path, f'Error_Report.xlsx')\n\nError_Report = pd.merge(Billing_Error_Report, Delivery_Error_Report, on=['Customer_Code', 'ID'], how='outer')\n\nerror_report_columns = ['Customer_Code', 'ID'] + [col for col in Error_Report.columns if col not in ['Customer_Code', 'ID']]\nError_Report = Error_Report[error_report_columns]\n\nError_Report.to_excel(file_path, index=False)\n\n# Create ExcelWriter and write DataFrame to Excel\nwith pd.ExcelWriter(file_path, engine='xlsxwriter') as writer:\n    Error_Report.to_excel(writer, index=False, sheet_name='Sheet1')\n\n    # Access the xlsxwriter workbook and worksheet objects from the ExcelWriter object.\n    workbook = writer.book\n    worksheet = writer.sheets['Sheet1']\n\n    # Add a text wrap format.\n    text_wrap_format = workbook.add_format({'text_wrap': True, 'align': 'center'})\n    \n    # Set the width of column 'A' to 26\n    worksheet.set_column('A:A', 26)\n    \n    # Set the width of column 'B' to 10\n    worksheet.set_column('B:B', 10)\n    \n    # Set the width of columns 'C' to 'F' to 55\n    worksheet.set_column('C:F', 55, text_wrap_format)\n\n"

# %% [markdown]
# The next part will open the Error Report dataset and check if there's any line.
#
# Case there are error lines, the code sends a request to a link an activate a PowerAutomate flow that get the error report file and sends via email to the responsible users.

# %%
# Check if the Error_Report DataFrame has any lines

'''
if not Error_Report.empty:
    # The DataFrame has lines, proceed with further actions
    folder_path = f'\\\choose\\your\\path\\Error Report'
    
    #file_path = os.path.join(folder_path, f'Error_Report.xlsx')

    error_report_columns = ['Customer_Code', 'ID'] + [col for col in Error_Report.columns if col not in ['Customer_Code', 'ID']]
    Error_Report = Error_Report[error_report_columns]

    Error_Report.to_excel(file_path, index=False)

    # Create ExcelWriter and write DataFrame to Excel
    with pd.ExcelWriter(file_path, engine='xlsxwriter') as writer:
        Error_Report.to_excel(writer, index=False, sheet_name='Sheet1')

        # Access the xlsxwriter workbook and worksheet objects from the ExcelWriter object.
        workbook = writer.book
        worksheet = writer.sheets['Sheet1']

        # Add a text wrap format.
        text_wrap_format = workbook.add_format({'text_wrap': True, 'align': 'center'})
        
        # Set the width of column 'A' to 26
        worksheet.set_column('A:A', 26)
        
        # Set the width of column 'B' to 10
        worksheet.set_column('B:B', 10)
        
        # Set the width of columns 'C' to 'F' to 55
        worksheet.set_column('C:F', 55, text_wrap_format)
        
    time.sleep(5)
        
    url = 'write here the power automate flow link to activate the flow'

    # Send POST request to Power Automate flow
    requests.post(url)
    
'''
# Out:
# "\nif not Error_Report.empty:\n    # The DataFrame has lines, proceed with further actions\n    folder_path = f'\\\\choose\\your\\path\\Error Report'\n    \n    #file_path = os.path.join(folder_path, f'Error_Report.xlsx')\n\n    error_report_columns = ['Customer_Code', 'ID'] + [col for col in Error_Report.columns if col not in ['Customer_Code', 'ID']]\n    Error_Report = Error_Report[error_report_columns]\n\n    Error_Report.to_excel(file_path, index=False)\n\n    # Create ExcelWriter and write DataFrame to Excel\n    with pd.ExcelWriter(file_path, engine='xlsxwriter') as writer:\n        Error_Report.to_excel(writer, index=False, sheet_name='Sheet1')\n\n        # Access the xlsxwriter workbook and worksheet objects from the ExcelWriter object.\n        workbook = writer.book\n        worksheet = writer.sheets['Sheet1']\n\n        # Add a text wrap format.\n        text_wrap_format = workbook.add_format({'text_wrap': True, 'align': 'center'})\n        \n        # Set the width of column 'A' to 26\n        worksheet.set_column('A:A', 26)\n        \n        # Set the width of column 'B' to 10\n        worksheet.set_column('B:B', 10)\n        \n        # Set the width of columns 'C' to 'F' to 55\n        worksheet.set_column('C:F', 55, text_wrap_format)\n        \n    time.sleep(5)\n        \n    url = 'write here the power automate flow link to activate the flow'\n\n    # Send POST request to Power Automate flow\n    requests.post(url)\n    \n"

# %% [markdown]
# Now it inserts the delivery addresses values into the addresses table and gets the generated id to use in the next step.

# %%
# Establish the connection with Windows authentication

#conn = pyodbc.connect(
#    f'DRIVER=ODBC Driver 17 for SQL Server;SERVER={server};DATABASE={database};UID={username};PWD={password};'
#)

# Create a cursor object to interact with the database
#cursor = conn.cursor()

delivery_insert_statments = ''

delivery_check_file = ''


for index, row in delivery_df.iterrows():
    
    
    suburb = row['Delivery_Suburb']
    original_suburb = row['Delivery_Suburb']
    postcode = row['Delivery_Postcode']
    original_postcode = row['Delivery_Postcode']
    state = row['Delivery_State']
    customer_id = row['ID']
    
    if customer_id in Delivery_IDs_To_Skip:
        continue
    
    if suburb == 'HRMC':
        suburb = 'HUNTER REGION MC'
    elif suburb == 'GCMC' or suburb == 'GCMC BUNDALL':
        suburb = 'GOLD COAST MC'
    elif suburb == 'QVB':
        suburb = 'QUEEN VICTORIA BUILDING'
    
    filtered_suburbs = suburbs[(suburbs['SuburbName'].str.upper() == suburb) & (suburbs['Postcode'] == postcode)]
    
    
    if filtered_suburbs.empty:
        
        filtered_suburbs = suburbs[(suburbs['SuburbName'].str.upper() == suburb) & (suburbs['StateName'] == state)]
        
        if len(filtered_suburbs)>1:
            best_postcode_diff = float('inf')
            best_match = None
            
            for _, current_row in filtered_suburbs.iterrows():
                current_postcode = current_row['Postcode']
                postcode_diff = abs(int(current_postcode) - int(original_postcode))

                if postcode_diff < best_postcode_diff:
                    best_postcode_diff = postcode_diff
                    suburb = current_row['SuburbName']
                    postcode = current_row['Postcode']
            
            filtered_suburbs = suburbs[(suburbs['SuburbName'].str.upper() == suburb) & (suburbs['Postcode'] == postcode)]
        
        elif filtered_suburbs.empty:
            matching_suburb = find_matching_suburb(suburb, postcode, suburbs)
        
            if matching_suburb:
                suburb = matching_suburb
                filtered_suburbs = suburbs[(suburbs['SuburbName'].str.upper() == suburb.upper()) & (suburbs['Postcode'] == postcode)]

            else:
                suburb = original_suburb
                matching_split = find_matching_suburb_split(suburb, postcode, suburbs)

                if matching_split:
                    suburb = matching_split
                    filtered_suburbs = suburbs[(suburbs['SuburbName'].str.upper() == suburb.upper()) & (suburbs['Postcode'] == postcode)]

                else:
                    suburb = original_suburb
                    matching_split_state = find_matching_suburb_split_state(suburb, state, postcode, suburbs)

                    if matching_split_state[0]:
                        suburb = matching_split_state[0]
                        postcode = matching_split_state[1]

                        filtered_suburbs = suburbs[(suburbs['SuburbName'].str.upper()== suburb.upper()) & (suburbs['Postcode'] == postcode)]
            
            
            
    if filtered_suburbs.empty:
        continue
        
    else:
        suburb_id = filtered_suburbs['Id'].values[0]
        state_id = filtered_suburbs['StateID'].values[0]
        postcode = filtered_suburbs['Postcode'].values[0]
        suburb = filtered_suburbs['SuburbName'].values[0]
        
        # Getting the new postcode and suburb to update the billing address
        
        parts = row['Delivery_Address'].split('\n') # spliting the string by _ that represents a line break
    
        delivery_address = '\n'.join(parts[:-1])

        delivery_address += f'\n{suburb} {state} {postcode}'
        
        
        street_number = row['Delivery_StreetNo']
        
        if street_number is not None:
            len_stnumber = len(street_number)
            street_number = street_number.replace("'", "''") 
            street_number = street_number.replace("\n", "'+char(13)+char(10)+'")
            street_number = f"'{street_number}'"
        else:
            street_number = 'NULL'
            len_stnumber = len(street_number)
        
        street_name = row['Delivery_StreetName']
        if street_name is not None:
            len_stname = len(street_name)
            street_name = street_name.replace("'", "''") 
            street_name = street_name.replace("\n", "'+char(13)+char(10)+'")
            street_name = f"'{street_name}'"
        else:
            street_name = 'NULL'
            len_stname = len(street_name)
        
        address = delivery_address
        if address is not None:
            address = address.replace("'", "''")
            address = address.replace("\n", "'+char(13)+char(10)+'")
        else:
            address = 'NULL'

        address1 = row['Delivery_Customisable_Value']
        if address1 is not None:
            len_add1 = len(address1)
            address1 = address1.replace("'", "''")
            address1 = address1.replace("\n", "'+char(13)+char(10)+'")
            address1 = f"'{address1}'"
        else:
            address1 = 'NULL'
            len_add1 = len(address1)

        address2 = row['Delivery_Address2']
        if address2 is not None:
            len_add2 = len(address2)
            address2 = address2.replace("'", "''")
            address2 = address2.replace("\n", "'+char(13)+char(10)+'")
            address2 = f"'{address2}'"
        else:
            address2 = 'NULL'
            len_add2 = len(address2)

        
        
        
        insert = f"""
        INSERT INTO [sample_database].[dbo].[ADR_Address]
          ([Address]
          ,[Address1]
          ,[StreetNumber]
          ,[StreetName]
          ,[Address2]
          ,[SuburbID]
          ,[StateID]
          ,[CountryID]
          ,[Postcode])
         VALUES
               ('{address}'
               ,{address1}
               ,{street_number}
               ,{street_name}
               ,{address2}
               ,{suburb_id}
               ,{state_id}
               ,36
               ,{postcode})
        """
        
        delivery_insert_statments += insert
        
        # Execute each SQL query in the list
        
        #cursor.execute(insert)

        #conn.commit()
        
        
        select_id = """
SELECT MAX([ID])
FROM [sample_database].[dbo].[ADR_Address]
        """
        # Execute the select_id query
        #cursor.execute(select_id)
        
        # Fetch the result and extract the ID
        #new_id = cursor.fetchone()[0]
        
        #Addresses_Complete.loc[Addresses_Complete['ID'] == customer_id, 'Delivery_ADR_Address_ID'] = new_id
        Addresses_Complete.loc[Addresses_Complete['ID'] == customer_id, 'Delivery_Suburb'] = suburb
        Addresses_Complete.loc[Addresses_Complete['ID'] == customer_id, 'Delivery_Postcode'] = postcode
        Addresses_Complete.loc[Addresses_Complete['ID'] == customer_id, 'Delivery_Address'] = delivery_address
        
#print(new_id)

# Close the cursor and connection

#cursor.close()
#conn.close()

# %%
# Set billing columns to None if ID is in Billing_IDs_To_Skip
Addresses_Complete.loc[Addresses_Complete['ID'].isin(Billing_IDs_To_Skip), [
    'Billing_ADR_Address_ID', 'Billing_Address', 'Billing_StreetNo',
    'Billing_StreetName', 'Billing_StreetType', 'Billing_Suburb',
    'Billing_State', 'Billing_Postcode', 'Billing_Customisable_Value',
    'Billing_Address2'
]] = None

# Set delivery columns to None if ID is in Delivery_IDs_To_Skip
Addresses_Complete.loc[Addresses_Complete['ID'].isin(Delivery_IDs_To_Skip), [
    'Delivery_ADR_Address_ID', 'Delivery_Address', 'Delivery_StreetNo',
    'Delivery_StreetName', 'Delivery_StreetType', 'Delivery_Suburb',
    'Delivery_State', 'Delivery_Postcode', 'Delivery_Customisable_Value',
    'Delivery_Address2'
]] = None


Addresses_Complete = Addresses_Complete.dropna(subset = Addresses_Complete.columns[2:], how='all')

Addresses_Complete.reset_index(drop = True, inplace = True)

# %% [markdown]
# Next steo saves the complete addresses table just for consultation if needed.

# %%
folder_path = f'\\\choose\\your\\path\\{date_time}'

#file_path = os.path.join(folder_path, f'Addresses_Complete_Auto.xlsx')

#Addresses_Complete.to_excel(file_path, index=False)

# %% [markdown]
# ## Updating the Master table

# %% [markdown]
# ### Billing Fields

# %%
billing_columns2 = ['Customer_Code', 'ID', 'Billing_ADR_Address_ID', 'Billing_Address', 'Billing_StreetNo', 'Billing_StreetName', 'Billing_StreetType',
                   'Billing_Suburb', 'Billing_State', 'Billing_Postcode', 'Billing_Customisable_Value', 'Billing_Address2']

# Select the columns for delivery information and 'Customer_Code' and 'ID'
delivery_columns2 = ['Customer_Code', 'ID', 'Delivery_ADR_Address_ID', 'Delivery_Address', 'Delivery_StreetNo', 'Delivery_StreetName', 'Delivery_StreetType',
                    'Delivery_Suburb', 'Delivery_State', 'Delivery_Postcode', 'Delivery_Customisable_Value', 'Delivery_Address2']

# %%
Addresses_Complete_Billing = Addresses_Complete[billing_columns2]

Addresses_Complete_Billing = Addresses_Complete_Billing.dropna(subset = Addresses_Complete_Billing.columns[2:], how='all')

Addresses_Complete_Billing.reset_index(drop = True, inplace = True)

# %%
Addresses_Complete_Billing
# Out:
#                   Customer_Code     ID Billing_ADR_Address_ID  \
# 0                PBPHYIPLUMBING  11405                   None
# 1         9WAHBNWPXZENGINEERING  11289                   None
# 2      9EMKTVVGFJZXYUNWBUILDING  10999                   None
# 3                        9BGRBF  10677                   None
# 4          ZWWGFVULCXOHSERVICES   9384                   None
# 5              FOSTLYRCPROJECTS   8954                   None
# 6         UECRDNBBAYENGINEERING   6935                   None
# 7                 NYULZQAGEEKPY   6519                   None
# 8                UNDHWRBUILDING   4795                   None
# 9                 9HKLCDEYVTKQH   4511                   None
# 10           ZLAAIUQSPLPLUMBING   4295                   None
# 11             9FLRFUSTPLUMBING   2819                   None
# 12             9DIGMGHGQMYGROUP   2520                   None
# 13                      JBRZQUZ   2349                   None
# 14         HMBDANGVUTNHPROJECTS   2157                   None
# 15              PKHRMIJPROJECTS    439                   None
# 16              MKGCMMEBAEIFSHB  11307                   None
# 17                     INNRSECW  11283                   None
# 18     9ISWLNDMKQPXHMKXPROJECTS  10718                   None
# 19             XSZNYDXNBUILDING  10547                   None
# 20                SPOMZPLUMBING   8750                   None
# 21            HJINCDHPQBUILDING   8209                   None
# 22  9KRNMYEUQCFYHVUCONSTRUCTION   6800                   None
# 23               WQCLWPMVWWVTXD   5905                   None
# 24                   NLRLLGROUP   4810                   None
# 25              EFSJLESOLUTIONS   4715                   None
# 26              QXZWIFABUILDING   4530                   None
# 27   YVUYCRVUVBKQAQCONSTRUCTION   4524                   None
# 28          9OREOMBLFFHLXDGROUP   4038                   None
# 29              9JMCKFTBUILDING   3259                   None
# 30           PQXCGOSXPLBUILDING   2597                   None
# 31    CRIMJNYAORSSBCONSTRUCTION   2432                   None
# 32                    9GQBPTOSR   2317                   None
# 33                   CNNMOGTJEW   2161                   None
# 34      CRHKCFLCOYLQENGINEERING   1841                   None
# 35                FOXJVBUILDING   1556                   None
# 36     ALQRRTTFNMJDCONSTRUCTION    992                   None
# 37                    WNWLQNMMM    978                   None
# 38      PTPJMOKHYBBWENGINEERING    371                   None
#
#                                       Billing_Address  Billing_StreetNo  \
# 0                   PO Box 5485 \nWOLLONGONG NSW 2520              None
# 1                PO Box 1161 \nMOUNTAIN GATE VIC 3156              None
# 2   T/As Odyssey Constructions & Fitout\nPO Box 71...              None
# 3   PO BOX 13268\nGeorge Street\nQueensland Univer...              None
# 4                          PO Box 86\nPOORAKA SA 5095              None
# 5                 PO Box 567\nCARINA HEIGHTS QLD 4152              None
# 6                         PO Box 3355\nDARRA QLD 4076              None
# 7                    P.O Box 1410\nBEENLEIGH QLD 4207              None
# 8                      PO Box 3346\nRICHMOND VIC 3121              None
# 9                      PO Box 3110\nLANSVALE NSW 2166              None
# 10                      PO Box 687\nGISBORNE VIC 3437              None
# 11                    PO Box 919\nPARRAMATTA NSW 2150              None
# 12               PO Box 6924\nBAULKHAM HILLS NSW 2153              None
# 13                PO Box 16151\nBANORA POINT QLD 2486              None
# 14                     GPO Box 399\nBRISBANE QLD 4001              None
# 15  PO Box 58\n'Claim for Payment'\nGLEN INNES NSW...              None
# 16     145A Hutton Road \nTHE ENTRANCE NORTH NSW 2261              145A
# 17  P/L & GS Engineering & Constructions Australia...  Level 1, 436-438
# 18      Cnr Stockton & Dredge Ave\nMOOREBANK NSW 2170
# 19  Ferrovial Agroman (Australia) Pty Ltd\nT/As Ne...        Level 9/32
# 20                5/1 Vuko Place\nWARRIEWOOD NSW 2102               5/1
# 21                   491 Kent Street\nSYDNEY NSW 2000               491
# 22                  3 Twelth Ave\nPALM BEACH QLD 4221                 3
# 23      20-26 Produce Drive\nDANDENONG SOUTH VIC 3175             20-26
# 24  T/As JHCPB JV, Canberra Metro Construction, NR...                22
# 25  Adminstration Building\n116 Adelaide Street (O...               116
# 26  C & T Corporation T/As CPB Samsung John Hollan...       Level 2, 52
# 27  T/As JHCPB JV, Canberra Metro Construction, NR...               330
# 28  Cnr Great Broome Road & Alahambra Drive\nEPPIN...
# 29            9 Furber Road\nCENTENNIAL PARK NSW 2021                 9
# 30  Level 14 International Towers Exchange Place T...          Level 14
# 31       4/52 Wirraway Drive\nPORT MELBOURNE VIC 3207              4/52
# 32  Cnr Stockton Ave & Dredge Ave\nMOOREBANK NSW 2170
# 33  Financial Transaction Services/Accounts\n14B, ...           14B, 30
# 34   Cnr Highlands & Delatite Roads\nSEYMOUR VIC 3660
# 35  Cnr Hope Street & Hughes Avenue\nERMINGTON NSW...
# 36  Cnr Northcliffe Drive & Princes Highway\nUNAND...
# 37  T/As Select Plant Hire \nAtt: Select Plant Hir...               825
# 38    Cnr Jones Bay & Pirrama Roads\nPYRMONT NSW 2009
#
#                                  Billing_StreetName Billing_StreetType  \
# 0                                       PO Box 5485               None
# 1                                       PO Box 1161               None
# 2                                       PO Box 7179               None
# 3                                      PO BOX 13268               None
# 4                                         PO Box 86               None
# 5                                        PO Box 567               None
# 6                                       PO Box 3355               None
# 7                                      P.O Box 1410               None
# 8                                       PO Box 3346               None
# 9                                       PO Box 3110               None
# 10                                       PO Box 687               None
# 11                                       PO Box 919               None
# 12                                      PO Box 6924               None
# 13                                     PO Box 16151               None
# 14                                      GPO Box 399               None
# 15                                        PO Box 58               None
# 16                                      Hutton Road               None
# 17                                  Johnston Street               None
# 18                        Cnr Stockton & Dredge Ave               None
# 19                                    Turbot Street               None
# 20                                       Vuko Place               None
# 21                                      Kent Street               None
# 22                                       Twelth Ave               None
# 23                                    Produce Drive               None
# 24                                     Giffnock Ave               None
# 25            Adelaide Street (Old Pacific Highway)               None
# 26                                   Railway Parade               None
# 27                                  Northbourne Ave               None
# 28          Cnr Great Broome Road & Alahambra Drive               None
# 29                                      Furber Road               None
# 30  International Towers Exchange Place Tower Three               None
# 31                                   Wirraway Drive               None
# 32                    Cnr Stockton Ave & Dredge Ave               None
# 33                                         The Bond               None
# 34                   Cnr Highlands & Delatite Roads               None
# 35                  Cnr Hope Street & Hughes Avenue               None
# 36          Cnr Northcliffe Drive & Princes Highway               None
# 37                                       Ann Street               None
# 38                    Cnr Jones Bay & Pirrama Roads               None
#
#                    Billing_Suburb Billing_State Billing_Postcode  \
# 0                      WOLLONGONG           NSW             2520
# 1                   MOUNTAIN GATE           VIC             3156
# 2                  WETHERILL PARK           NSW             2164
# 3   Queensland University of Tech           QLD             4000
# 4                         POORAKA            SA             5095
# 5                  CARINA HEIGHTS           QLD             4152
# 6                           DARRA           QLD             4076
# 7                       BEENLEIGH           QLD             4207
# 8                        RICHMOND           VIC             3121
# 9                        LANSVALE           NSW             2166
# 10                       GISBORNE           VIC             3437
# 11                     PARRAMATTA           NSW             2150
# 12                 BAULKHAM HILLS           NSW             2153
# 13                   BANORA POINT           QLD             2486
# 14                       BRISBANE           QLD             4001
# 15                     GLEN INNES           NSW             2370
# 16             THE ENTRANCE NORTH           NSW             2261
# 17                     ABBOTSFORD           VIC             3067
# 18                      MOOREBANK           NSW             2170
# 19                       BRISBANE           QLD             4000
# 20                     WARRIEWOOD           NSW             2102
# 21                         SYDNEY           NSW             2000
# 22                     PALM BEACH           QLD             4221
# 23                DANDENONG SOUTH           VIC             3175
# 24                 MACQUARIE PARK           NSW             2113
# 25                RAYMOND TERRACE           NSW             2324
# 26                        BURWOOD           NSW             2134
# 27                        DICKSON           ACT             2602
# 28                         EPPING           VIC             3076
# 29                CENTENNIAL PARK           NSW             2021
# 30                     BARANGAROO           NSW             2000
# 31                 PORT MELBOURNE           VIC             3207
# 32                      MOOREBANK           NSW             2170
# 33                         MILLER           NSW             2168
# 34                        SEYMOUR           VIC             3660
# 35                      ERMINGTON           NSW             2115
# 36                      UNANDERRA           NSW             2526
# 37               FORTITUDE VALLEY           QLD             4006
# 38                        PYRMONT           NSW             2009
#
#                            Billing_Customisable_Value  \
# 0                                                None
# 1                                                None
# 2                 T/As Odyssey Constructions & Fitout
# 3                                                None
# 4                                                None
# 5                                                None
# 6                                                None
# 7                                                None
# 8                                                None
# 9                                                None
# 10                                               None
# 11                                               None
# 12                                               None
# 13                                               None
# 14                                               None
# 15                                               None
# 16                                               None
# 17                               T/As Spark NEL DC JV
# 18                                               None
# 19                                T/As Nexus Delivery
# 20                                               None
# 21                                               None
# 22                                               None
# 23                                               None
# 24  T/As JHCPB JV, Canberra Metro Construction, NR...
# 25                                               None
# 26                                               None
# 27  T/As JHCPB JV, Canberra Metro Construction, NR...
# 28                                               None
# 29                                               None
# 30                                               None
# 31                                               None
# 32                                               None
# 33                                               None
# 34                                               None
# 35                                               None
# 36                                               None
# 37                             T/As Select Plant Hire
# 38                                               None
#
#                                      Billing_Address2
# 0                                                None
# 1                                                None
# 2                                                None
# 3                                       George Street
# 4                                                None
# 5                                                None
# 6                                                None
# 7                                                None
# 8                                                None
# 9                                                None
# 10                                               None
# 11                                               None
# 12                                               None
# 13                                               None
# 14                                               None
# 15                                'Claim for Payment'
# 16                                               None
# 17  P/L & GS Engineering & Constructions Australia...
# 18                                               None
# 19              Ferrovial Agroman (Australia) Pty Ltd
# 20                                               None
# 21                                               None
# 22                                               None
# 23                                               None
# 24                             Level 6 South Building
# 25                             Adminstration Building
# 26  C & T Corporation T/As CPB Samsung John Hollan...
# 27                                               None
# 28                                               None
# 29                                               None
# 30                                               None
# 31                                               None
# 32                                               None
# 33            Financial Transaction Services/Accounts
# 34                                               None
# 35                                               None
# 36                                               None
# 37            Att: Select Plant Hire Accounts Payable
# 38                                               None

# %% [markdown]
# After all changes and fixes, the code updates the customer table in SQL to reflect the correct values.

# %%
'''
# Establish the connection with Windows authentication
conn = pyodbc.connect(
    f'DRIVER=ODBC Driver 17 for SQL Server;SERVER={server};DATABASE={database};UID={username};PWD={password};'
)

# Create a cursor object to interact with the database
cursor = conn.cursor()

all_statments = ''


for index, row in Addresses_Complete_Billing.iterrows():
    
    customer_id = row['ID']

    if customer_id in (Billing_IDs_To_Skip + Billing_IDs_To_Exclude):
        continue
    
    update_string = ''
    count = 0
    
    for column in billing_columns2[2:]:
        
        value = Addresses_Complete_Billing.at[index, column]

        if value is not None:
            value = str(value)
            value = value.replace("'", "''")  # Escape single quotes
            value = value.replace("\n", "'+char(13)+char(10)+'")
    
            
            if count == 0:
                update_string += f"[{column}] = '{value}'\n"
                count += 1
            else:
                update_string += f",[{column}] = '{value}'\n"
                count += 1
    
    update_beginning = """UPDATE [sample_database].[dbo].[DBT_Master]
SET
 """
    
    update_end = f""",[Billing_Country] = 'Australia'
    WHERE [ID] = {customer_id};
    """
    
    
    sql_query = update_beginning + update_string + update_end
    
    all_statments += sql_query
    
    # Execute each SQL query in the list
    cursor.execute(sql_query)

    conn.commit()
    
# Close the cursor and connection
cursor.close()
conn.close()
'''
# Out:
# '\n# Establish the connection with Windows authentication\nconn = pyodbc.connect(\n    f\'DRIVER=ODBC Driver 17 for SQL Server;SERVER={server};DATABASE={database};UID={username};PWD={password};\'\n)\n\n# Create a cursor object to interact with the database\ncursor = conn.cursor()\n\nall_statments = \'\'\n\n\nfor index, row in Addresses_Complete_Billing.iterrows():\n    \n    customer_id = row[\'ID\']\n\n    if customer_id in (Billing_IDs_To_Skip + Billing_IDs_To_Exclude):\n        continue\n    \n    update_string = \'\'\n    count = 0\n    \n    for column in billing_columns2[2:]:\n        \n        value = Addresses_Complete_Billing.at[index, column]\n\n        if value is not None:\n            value = str(value)\n            value = value.replace("\'", "\'\'")  # Escape single quotes\n            value = value.replace("\n", "\'+char(13)+char(10)+\'")\n    \n            \n            if count == 0:\n                update_string += f"[{column}] = \'{value}\'\n"\n                count += 1\n            else:\n                update_string += f",[{column}] = \'{value}\'\n"\n                count += 1\n    \n    update_beginning = """UPDATE [sample_database].[dbo].[DBT_Master]\nSET\n """\n    \n    update_end = f""",[Billing_Country] = \'Australia\'\n    WHERE [ID] = {customer_id};\n    """\n    \n    \n    sql_query = update_beginning + update_string + update_end\n    \n    all_statments += sql_query\n    \n    # Execute each SQL query in the list\n    cursor.execute(sql_query)\n\n    conn.commit()\n    \n# Close the cursor and connection\ncursor.close()\nconn.close()\n'

# %% [markdown]
# ### Delivery Fields

# %%
Addresses_Complete_Delivery = Addresses_Complete[delivery_columns2]

Addresses_Complete_Delivery = Addresses_Complete_Delivery.dropna(subset = Addresses_Complete_Delivery.columns[2:], how='all')

Addresses_Complete_Delivery.reset_index(drop = True, inplace = True)

# %%
'''
# Establish the connection with Windows authentication
conn = pyodbc.connect(
    f'DRIVER=ODBC Driver 17 for SQL Server;SERVER={server};DATABASE={database};UID={username};PWD={password};'
)

# Create a cursor object to interact with the database
cursor = conn.cursor()


for index, row in Addresses_Complete_Delivery.iterrows():
    
    customer_id = row['ID']

    if customer_id in (Delivery_IDs_To_Skip + Delivery_IDs_To_Exclude):
        continue
    
    update_string = ''
    count = 0
    
    for column in delivery_columns2[2:]:
        
        value = Addresses_Complete_Delivery.at[index, column]

        if value is not None:
            value = str(value)
            value = value.replace("'", "''")  # Escape single quotes
            value = value.replace("\n", "'+char(13)+char(10)+'")
    
            
            if count == 0:
                update_string += f"[{column}] = '{value}'\n"
                count += 1
            else:
                update_string += f",[{column}] = '{value}'\n"
                count += 1
    
    update_beginning = """UPDATE [sample_database].[dbo].[DBT_Master]
SET
 """
    
    update_end = f""",[Delivery_Country] = 'Australia'
    WHERE [ID] = {customer_id};
    """
    
    
    sql_query = update_beginning + update_string + update_end
    
    all_statments += sql_query
    
    # Execute each SQL query in the list
    cursor.execute(sql_query)

    conn.commit()
    
# Close the cursor and connection
cursor.close()
conn.close()
'''
# Out:
# '\n# Establish the connection with Windows authentication\nconn = pyodbc.connect(\n    f\'DRIVER=ODBC Driver 17 for SQL Server;SERVER={server};DATABASE={database};UID={username};PWD={password};\'\n)\n\n# Create a cursor object to interact with the database\ncursor = conn.cursor()\n\n\nfor index, row in Addresses_Complete_Delivery.iterrows():\n    \n    customer_id = row[\'ID\']\n\n    if customer_id in (Delivery_IDs_To_Skip + Delivery_IDs_To_Exclude):\n        continue\n    \n    update_string = \'\'\n    count = 0\n    \n    for column in delivery_columns2[2:]:\n        \n        value = Addresses_Complete_Delivery.at[index, column]\n\n        if value is not None:\n            value = str(value)\n            value = value.replace("\'", "\'\'")  # Escape single quotes\n            value = value.replace("\n", "\'+char(13)+char(10)+\'")\n    \n            \n            if count == 0:\n                update_string += f"[{column}] = \'{value}\'\n"\n                count += 1\n            else:\n                update_string += f",[{column}] = \'{value}\'\n"\n                count += 1\n    \n    update_beginning = """UPDATE [sample_database].[dbo].[DBT_Master]\nSET\n """\n    \n    update_end = f""",[Delivery_Country] = \'Australia\'\n    WHERE [ID] = {customer_id};\n    """\n    \n    \n    sql_query = update_beginning + update_string + update_end\n    \n    all_statments += sql_query\n    \n    # Execute each SQL query in the list\n    cursor.execute(sql_query)\n\n    conn.commit()\n    \n# Close the cursor and connection\ncursor.close()\nconn.close()\n'

# %%
# Set the finish date and time to the current moment
finish_date = datetime.now()

# Calculate the time spent
time_spent = finish_date - start_date

# Format dates and times as strings in the desired format
start_date_str = start_date.strftime('%d/%m/%y %H:%M:%S')
finish_date_str = finish_date.strftime('%d/%m/%y %H:%M:%S')

# %% [markdown]
# Lastly, it inserts into the log table the information of this run.

# %%
'''
# Establish the connection with Windows authentication
conn = pyodbc.connect(
    f'DRIVER=ODBC Driver 17 for SQL Server;SERVER={server};DATABASE={database};UID={username};PWD={password};'
)

# Create a cursor object to interact with the database
cursor = conn.cursor()

start_date_SQL = start_date.strftime('%Y-%m-%d %H:%M:%S')
finish_date_SQL = finish_date.strftime('%Y-%m-%d %H:%M:%S')

if last_modified_date:
    last_modified = last_modified_date
    
else:
    last_modified = last_finish_date

no_rows = Addresses_Complete.shape[0]

insert_log = f"""

INSERT INTO [sample_database].[dbo].[TBL_DBT_Address_Updates_Log] (StartDate, FinishDate, TotalTime, No_Rows, Last_Modified_Date)
VALUES ('{start_date_SQL}', '{finish_date_SQL}', '{time_spent}', {no_rows}, '{last_modified}');

"""

cursor.execute(insert_log)

conn.commit()

# Close the cursor and connection
cursor.close()
conn.close()
'''
# Out:
# '\n# Establish the connection with Windows authentication\nconn = pyodbc.connect(\n    f\'DRIVER=ODBC Driver 17 for SQL Server;SERVER={server};DATABASE={database};UID={username};PWD={password};\'\n)\n\n# Create a cursor object to interact with the database\ncursor = conn.cursor()\n\nstart_date_SQL = start_date.strftime(\'%Y-%m-%d %H:%M:%S\')\nfinish_date_SQL = finish_date.strftime(\'%Y-%m-%d %H:%M:%S\')\n\nif last_modified_date:\n    last_modified = last_modified_date\n    \nelse:\n    last_modified = last_finish_date\n\nno_rows = Addresses_Complete.shape[0]\n\ninsert_log = f"""\n\nINSERT INTO [sample_database].[dbo].[TBL_DBT_Address_Updates_Log] (StartDate, FinishDate, TotalTime, No_Rows, Last_Modified_Date)\nVALUES (\'{start_date_SQL}\', \'{finish_date_SQL}\', \'{time_spent}\', {no_rows}, \'{last_modified}\');\n\n"""\n\ncursor.execute(insert_log)\n\nconn.commit()\n\n# Close the cursor and connection\ncursor.close()\nconn.close()\n'
